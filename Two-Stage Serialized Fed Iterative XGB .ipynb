# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
# Import the time module
import time

# Record the start time
start_time = time.time()

# Read data from Excel file
file_path = ''
df = pd.read_excel(file_path)

# Convert 'iranidate' to datetime and drop rows with invalid dates
df['iranidate'] = pd.to_datetime(df['iranidate'], errors='coerce')
df = df.dropna(subset=['iranidate'])

# Function to convert date values to numeric representation
def convert_to_numeric_date(date):
    base_date = datetime(2000, 1, 1)
    return (date - base_date).days

df['iranidate'] = df['iranidate'].apply(convert_to_numeric_date)

# Encode 'node' column
label_encoder = LabelEncoder()
df['node_encoded'] = label_encoder.fit_transform(df['node'])

# Handling NaN values by finding the nearest non-empty cells in the same column 
for col in ['CO', 'O3', 'SO2', 'PM10', 'PM2.5', 'AQI']:
    for idx, value in df[col].items():
        if pd.isnull(value):
            upper_cell = df[col].iloc[:idx].last_valid_index()
            lower_cell = df[col].iloc[idx + 1:].first_valid_index()
            if upper_cell is not None and lower_cell is not None:
                avg = (df.at[upper_cell, col] + df.at[lower_cell, col]) / 2
                df.at[idx, col] = avg

# Check sample threshold
your_threshold_value = 100
if len(df) < your_threshold_value:
    print("Insufficient samples in the dataset.")
else:
    output_columns = ['CO', 'O3', 'NO2', 'SO2', 'PM10', 'PM2.5', 'AQI', 'Highest tempreture: 12pm', 'Wind:km/h']
    unique_nodes = df['node'].unique()  

    # Dictionary to store weighted predictions for each node and column
    weighted_predictions = {}

    for node_value in unique_nodes:
        node_df = df[df['node'] == node_value]  
        
        # Dictionary to store predictions and true values for each column
        columns_data = {}

        for output_column in output_columns:
            if node_df[output_column].isnull().any():
                print(f"NaN values found in {output_column} for Node {node_value}. Handle missing values before modeling.")
            else:
                X = node_df[['iranidate', 'node_encoded']]
                Y = node_df[[output_column]]  
                X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
                
                # XGBoost model as the first model
                xgb_model_1 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.1, max_depth=5, alpha=10, n_estimators=100)
                xgb_model_1.fit(X_train, Y_train)
                Y1_pred_xgb = xgb_model_1.predict(X_test)

                # XGBoost model as the secondary model, taking Y1_pred_xgb as input
                xgb_model_2 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.1, max_depth=5, alpha=10, n_estimators=100)
                xgb_model_2.fit(np.concatenate((X_test, Y1_pred_xgb.reshape(-1, 1)), axis=1), Y_test)
                Y2_pred_xgb = xgb_model_2.predict(np.concatenate((X_test, Y1_pred_xgb.reshape(-1, 1)), axis=1))

                # Calculate errors for the third XGBoost model
                mse_xgb_1 = mean_squared_error(Y_test, Y1_pred_xgb)
                mse_xgb_2 = mean_squared_error(Y_test, Y2_pred_xgb)
                rmse_xgb_2 = np.sqrt(mse_xgb_2)
                r2_xgb_2 = r2_score(Y_test, Y2_pred_xgb)
                evs_xgb_2 = explained_variance_score(Y_test, Y2_pred_xgb)

                # Store predictions and true values for each column in the dictionary
                columns_data[output_column] = (Y2_pred_xgb, Y_test)

                # Output results for the local model with weighted predictions
                print(f"Local Model Results for Node {node_value} - {output_column} with Weighted Predictions:")
                print(f"MSE for XGB_1: {mse_xgb_1}")
                print(f"MSE for XGB_2: {mse_xgb_2}")
                print(f"RMSE for XGB_2: {rmse_xgb_2}")
                print(f"R2 for XGB_2: {r2_xgb_2}")
                print(f"EVS for XGB_2: {evs_xgb_2}")

                # Store weighted predictions for each node and column
                if node_value not in weighted_predictions:
                    weighted_predictions[node_value] = {output_column: (Y2_pred_xgb, Y_test)}
                else:
                    weighted_predictions[node_value][output_column] = (Y2_pred_xgb, Y_test)

# Aggregate predictions for the global model using weighted average
global_X_test = []
global_Y_test = []

for node, columns in weighted_predictions.items():
    for column, (node_prediction, Y_test) in columns.items():
        global_X_test.extend(node_prediction * r2_xgb_2)  # Apply weights using the R2 score from the third XGBoost model
        global_Y_test.extend(Y_test.values)

# Create and train the global model (Random Forest)
global_model = RandomForestRegressor(random_state=42)
global_model.fit(np.array(global_X_test).reshape(-1, 1), global_Y_test)  # Reshape for RF

# Predict using the global model
global_Y_pred = global_model.predict(np.array(global_X_test).reshape(-1, 1))
global_mse = mean_squared_error(global_Y_test, global_Y_pred)

# Print results for the global model
print("Global Model Results:")
print(f"Mean Squared Error (MSE) for Global Model: {global_mse}")

# Record the end time
end_time = time.time()

# Calculate the duration of the program execution
duration_seconds = end_time - start_time

# Print the duration of the program execution
print(f"Duration of the program execution: {duration_seconds} seconds")
# Out:
# 2024-02-27 00:03:51.417456: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Local Model Results for Node اقدسیه.منطقه1 - CO with Weighted Predictions:
# MSE for XGB_1: 52.2541058549973
# MSE for XGB_2: 15.116398722483718
# RMSE for XGB_2: 3.887981317146948
# R2 for XGB_2: 0.812856840779131
# EVS for XGB_2: 0.8128932616389081
# Local Model Results for Node اقدسیه.منطقه1 - O3 with Weighted Predictions:
# MSE for XGB_1: 337.4835357256914
# MSE for XGB_2: 23.880381419412664
# RMSE for XGB_2: 4.886755715135827
# R2 for XGB_2: 0.980440297992009
# EVS for XGB_2: 0.9804469685305613
# Local Model Results for Node اقدسیه.منطقه1 - NO2 with Weighted Predictions:
# MSE for XGB_1: 444.4083255603937
# MSE for XGB_2: 42.09529000349086
# RMSE for XGB_2: 6.4880883165606535
# R2 for XGB_2: 0.9307326944281319
# EVS for XGB_2: 0.9307328126846613
# Local Model Results for Node اقدسیه.منطقه1 - SO2 with Weighted Predictions:
# MSE for XGB_1: 46.29400070561974
# MSE for XGB_2: 9.333661788075924
# RMSE for XGB_2: 3.0551042188566866
# R2 for XGB_2: 0.8737062161007625
# EVS for XGB_2: 0.8737207582559169
# Local Model Results for Node اقدسیه.منطقه1 - PM10 with Weighted Predictions:
# MSE for XGB_1: 133.61824715387297
# MSE for XGB_2: 20.237526908857017
# RMSE for XGB_2: 4.4986138875054635
# R2 for XGB_2: 0.9101177330173023
# EVS for XGB_2: 0.910126523682864
# Local Model Results for Node اقدسیه.منطقه1 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 382.2537478921528
# MSE for XGB_2: 26.50026092701083
# RMSE for XGB_2: 5.147840413902788
# R2 for XGB_2: 0.9674165407966497
# EVS for XGB_2: 0.9674185229212562
# Local Model Results for Node اقدسیه.منطقه1 - AQI with Weighted Predictions:
# MSE for XGB_1: 537.7630985502299
# MSE for XGB_2: 40.58639899303782
# RMSE for XGB_2: 6.370745560218036
# R2 for XGB_2: 0.944946488852092
# EVS for XGB_2: 0.9449481342790006
# Local Model Results for Node اقدسیه.منطقه1 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node اقدسیه.منطقه1 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شریف.منطقه2 - CO with Weighted Predictions:
# MSE for XGB_1: 206.2997846735461
# MSE for XGB_2: 24.28379811338498
# RMSE for XGB_2: 4.927859384497997
# R2 for XGB_2: 0.8546172869202907
# EVS for XGB_2: 0.8546179884899208
# Local Model Results for Node شریف.منطقه2 - O3 with Weighted Predictions:
# MSE for XGB_1: 148.88872795904345
# MSE for XGB_2: 17.65167203768812
# RMSE for XGB_2: 4.201389298516399
# R2 for XGB_2: 0.9664390127029471
# EVS for XGB_2: 0.9664392759702716
# Local Model Results for Node شریف.منطقه2 - NO2 with Weighted Predictions:
# MSE for XGB_1: 180.21848269129515
# MSE for XGB_2: 21.99646635558118
# RMSE for XGB_2: 4.690039056935579
# R2 for XGB_2: 0.9580803448426864
# EVS for XGB_2: 0.9580810469306973
# Local Model Results for Node شریف.منطقه2 - SO2 with Weighted Predictions:
# MSE for XGB_1: 132.70518033954795
# MSE for XGB_2: 19.577746991262362
# RMSE for XGB_2: 4.424674789322077
# R2 for XGB_2: 0.8989792719643883
# EVS for XGB_2: 0.8990076496953818
# Local Model Results for Node شریف.منطقه2 - PM10 with Weighted Predictions:
# MSE for XGB_1: 378.65733543891207
# MSE for XGB_2: 25.620913433682684
# RMSE for XGB_2: 5.061710524485046
# R2 for XGB_2: 0.9578763445217089
# EVS for XGB_2: 0.9578813522716869
# Local Model Results for Node شریف.منطقه2 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 474.739434692012
# MSE for XGB_2: 31.135782586163653
# RMSE for XGB_2: 5.579944675905278
# R2 for XGB_2: 0.9600051734344899
# EVS for XGB_2: 0.9600188102077033
# Local Model Results for Node شریف.منطقه2 - AQI with Weighted Predictions:
# MSE for XGB_1: 462.41748416680934
# MSE for XGB_2: 30.521511251583924
# RMSE for XGB_2: 5.524627702531992
# R2 for XGB_2: 0.9653448854088897
# EVS for XGB_2: 0.9653491872783604
# Local Model Results for Node شریف.منطقه2 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شریف.منطقه2 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node پاسداران.منطقه3 - CO with Weighted Predictions:
# MSE for XGB_1: 60.40690991809444
# MSE for XGB_2: 17.332184683268142
# RMSE for XGB_2: 4.1631940482360585
# R2 for XGB_2: 0.8067707094749533
# EVS for XGB_2: 0.8067727988190699
# Local Model Results for Node پاسداران.منطقه3 - O3 with Weighted Predictions:
# MSE for XGB_1: 274.48914833760193
# MSE for XGB_2: 21.16631048286519
# RMSE for XGB_2: 4.600685870918073
# R2 for XGB_2: 0.9788022345501273
# EVS for XGB_2: 0.9788052451718869
# Local Model Results for Node پاسداران.منطقه3 - NO2 with Weighted Predictions:
# MSE for XGB_1: 121.28713787443986
# MSE for XGB_2: 24.594589376236243
# RMSE for XGB_2: 4.959293233540062
# R2 for XGB_2: 0.8726614999370517
# EVS for XGB_2: 0.8726732910763677
# Local Model Results for Node پاسداران.منطقه3 - SO2 with Weighted Predictions:
# MSE for XGB_1: 61.20464757823452
# MSE for XGB_2: 10.011064003268059
# RMSE for XGB_2: 3.164026549077624
# R2 for XGB_2: 0.9394766090644145
# EVS for XGB_2: 0.9394785693156362
# Local Model Results for Node پاسداران.منطقه3 - PM10 with Weighted Predictions:
# MSE for XGB_1: 133.61824715387297
# MSE for XGB_2: 20.237526908857017
# RMSE for XGB_2: 4.4986138875054635
# R2 for XGB_2: 0.9101177330173023
# EVS for XGB_2: 0.910126523682864
# Local Model Results for Node پاسداران.منطقه3 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 420.0396553755279
# MSE for XGB_2: 32.742219269287546
# RMSE for XGB_2: 5.722081725149296
# R2 for XGB_2: 0.95892838526992
# EVS for XGB_2: 0.9589284656705729
# Local Model Results for Node پاسداران.منطقه3 - AQI with Weighted Predictions:
# MSE for XGB_1: 361.37976047901685
# MSE for XGB_2: 31.295902013219187
# RMSE for XGB_2: 5.594274038087443
# R2 for XGB_2: 0.953899768933671
# EVS for XGB_2: 0.9539060627713032
# Local Model Results for Node پاسداران.منطقه3 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node پاسداران.منطقه3 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - CO with Weighted Predictions:
# MSE for XGB_1: 93.54023804712597
# MSE for XGB_2: 20.28617494385079
# RMSE for XGB_2: 4.504017644709086
# R2 for XGB_2: 0.8652310520496165
# EVS for XGB_2: 0.8652310540918876
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - O3 with Weighted Predictions:
# MSE for XGB_1: 188.14109886304558
# MSE for XGB_2: 19.98686742881365
# RMSE for XGB_2: 4.470667447799451
# R2 for XGB_2: 0.9603478595651207
# EVS for XGB_2: 0.9603487293202846
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - NO2 with Weighted Predictions:
# MSE for XGB_1: 544.3673967849838
# MSE for XGB_2: 41.03001398413128
# RMSE for XGB_2: 6.405467507070134
# R2 for XGB_2: 0.9374965728139275
# EVS for XGB_2: 0.9375019491352367
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - SO2 with Weighted Predictions:
# MSE for XGB_1: 30.17821550396598
# MSE for XGB_2: 11.439995949384807
# RMSE for XGB_2: 3.382306306262756
# R2 for XGB_2: 0.7998761107957595
# EVS for XGB_2: 0.7998764390992609
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - PM10 with Weighted Predictions:
# MSE for XGB_1: 199.70469876727353
# MSE for XGB_2: 19.730276450890926
# RMSE for XGB_2: 4.4418775817092175
# R2 for XGB_2: 0.9419797341999622
# EVS for XGB_2: 0.9420092380027199
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 654.4065383477948
# MSE for XGB_2: 45.35800998441559
# RMSE for XGB_2: 6.734835557340326
# R2 for XGB_2: 0.9692167394396208
# EVS for XGB_2: 0.9692168817680554
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - AQI with Weighted Predictions:
# MSE for XGB_1: 647.0255888787502
# MSE for XGB_2: 44.77590406477875
# RMSE for XGB_2: 6.691479960724589
# R2 for XGB_2: 0.968973568831343
# EVS for XGB_2: 0.968974053768143
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node پونک - CO with Weighted Predictions:
# MSE for XGB_1: 74.9985194043365
# MSE for XGB_2: 14.515259848840813
# RMSE for XGB_2: 3.8098897423469897
# R2 for XGB_2: 0.88767070828686
# EVS for XGB_2: 0.8876907363526175
# Local Model Results for Node پونک - O3 with Weighted Predictions:
# MSE for XGB_1: 130.81976869374267
# MSE for XGB_2: 14.625837530351424
# RMSE for XGB_2: 3.8243741357706393
# R2 for XGB_2: 0.9618551627487112
# EVS for XGB_2: 0.9618555012143124
# Local Model Results for Node پونک - NO2 with Weighted Predictions:
# MSE for XGB_1: 167.397447489632
# MSE for XGB_2: 27.472585161969146
# RMSE for XGB_2: 5.2414296868286945
# R2 for XGB_2: 0.908544022603596
# EVS for XGB_2: 0.908545119844076
# Local Model Results for Node پونک - SO2 with Weighted Predictions:
# MSE for XGB_1: 144.17013407759924
# MSE for XGB_2: 16.565567236320973
# RMSE for XGB_2: 4.0700819692385775
# R2 for XGB_2: 0.9430128377514901
# EVS for XGB_2: 0.9430134252021035
# Local Model Results for Node پونک - PM10 with Weighted Predictions:
# MSE for XGB_1: 148.81486109973565
# MSE for XGB_2: 18.69163622173002
# RMSE for XGB_2: 4.323382497736005
# R2 for XGB_2: 0.9263682164667344
# EVS for XGB_2: 0.9263722778761512
# Local Model Results for Node پونک - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 281.66612372089475
# MSE for XGB_2: 28.13064400959766
# RMSE for XGB_2: 5.303832954533698
# R2 for XGB_2: 0.9633730338110331
# EVS for XGB_2: 0.9633730479959808
# Local Model Results for Node پونک - AQI with Weighted Predictions:
# MSE for XGB_1: 223.44189418001838
# MSE for XGB_2: 29.32646061026924
# RMSE for XGB_2: 5.415391085625233
# R2 for XGB_2: 0.9373695645718547
# EVS for XGB_2: 0.9373760838725077
# Local Model Results for Node پونک - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node پونک - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node تربیت.مدرس.منطقه6 - CO with Weighted Predictions:
# MSE for XGB_1: 144.94835615661313
# MSE for XGB_2: 20.46069572536834
# RMSE for XGB_2: 4.523350055585831
# R2 for XGB_2: 0.9150463454022288
# EVS for XGB_2: 0.9150665566647029
# Local Model Results for Node تربیت.مدرس.منطقه6 - O3 with Weighted Predictions:
# MSE for XGB_1: 513.3499422469073
# MSE for XGB_2: 28.117650875718002
# RMSE for XGB_2: 5.302607931548212
# R2 for XGB_2: 0.9900668632037372
# EVS for XGB_2: 0.9900669339485452
# Local Model Results for Node تربیت.مدرس.منطقه6 - NO2 with Weighted Predictions:
# MSE for XGB_1: 130.95561793348034
# MSE for XGB_2: 19.92230916351008
# RMSE for XGB_2: 4.463441403615609
# R2 for XGB_2: 0.934340057588288
# EVS for XGB_2: 0.934343964924561
# Local Model Results for Node تربیت.مدرس.منطقه6 - SO2 with Weighted Predictions:
# MSE for XGB_1: 263.08172408480516
# MSE for XGB_2: 18.27825316055171
# RMSE for XGB_2: 4.275307376148727
# R2 for XGB_2: 0.954067277308332
# EVS for XGB_2: 0.9540737951678611
# Local Model Results for Node تربیت.مدرس.منطقه6 - PM10 with Weighted Predictions:
# MSE for XGB_1: 269.68927533624304
# MSE for XGB_2: 24.464770492665142
# RMSE for XGB_2: 4.946187470432671
# R2 for XGB_2: 0.9349756884588799
# EVS for XGB_2: 0.9349759581758231
# Local Model Results for Node تربیت.مدرس.منطقه6 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 473.3207806137566
# MSE for XGB_2: 30.85796887122395
# RMSE for XGB_2: 5.554994947902649
# R2 for XGB_2: 0.9697883964431937
# EVS for XGB_2: 0.9698107516263987
# Local Model Results for Node تربیت.مدرس.منطقه6 - AQI with Weighted Predictions:
# MSE for XGB_1: 808.9866963800669
# MSE for XGB_2: 51.002136452950886
# RMSE for XGB_2: 7.141578008602223
# R2 for XGB_2: 0.9653500051032591
# EVS for XGB_2: 0.9653552427344869
# Local Model Results for Node تربیت.مدرس.منطقه6 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node تربیت.مدرس.منطقه6 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node گلبرگ.منطقه8 - CO with Weighted Predictions:
# MSE for XGB_1: 49.92888015518537
# MSE for XGB_2: 15.512776763985745
# RMSE for XGB_2: 3.93862625340178
# R2 for XGB_2: 0.7956202502792179
# EVS for XGB_2: 0.7956629571971473
# Local Model Results for Node گلبرگ.منطقه8 - O3 with Weighted Predictions:
# MSE for XGB_1: 562.6142774113505
# MSE for XGB_2: 26.078881384729574
# RMSE for XGB_2: 5.106748611859563
# R2 for XGB_2: 0.9864783567962307
# EVS for XGB_2: 0.9864784429988318
# Local Model Results for Node گلبرگ.منطقه8 - NO2 with Weighted Predictions:
# MSE for XGB_1: 188.34749683860818
# MSE for XGB_2: 36.38885583503553
# RMSE for XGB_2: 6.032317617221056
# R2 for XGB_2: 0.8608033872281541
# EVS for XGB_2: 0.8608033873197739
# Local Model Results for Node گلبرگ.منطقه8 - SO2 with Weighted Predictions:
# MSE for XGB_1: 227.1071703695011
# MSE for XGB_2: 12.923321880143577
# RMSE for XGB_2: 3.5949022073129577
# R2 for XGB_2: 0.9427693570211952
# EVS for XGB_2: 0.9427999786589362
# Local Model Results for Node گلبرگ.منطقه8 - PM10 with Weighted Predictions:
# MSE for XGB_1: 177.14089012158792
# MSE for XGB_2: 24.2408240278774
# RMSE for XGB_2: 4.9234971339361415
# R2 for XGB_2: 0.9151777704535877
# EVS for XGB_2: 0.9151788995866414
# Local Model Results for Node گلبرگ.منطقه8 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 353.67352723106455
# MSE for XGB_2: 25.108277904824288
# RMSE for XGB_2: 5.010816091698466
# R2 for XGB_2: 0.968540186191375
# EVS for XGB_2: 0.968541547058544
# Local Model Results for Node گلبرگ.منطقه8 - AQI with Weighted Predictions:
# MSE for XGB_1: 578.9653911696213
# MSE for XGB_2: 45.04817245500988
# RMSE for XGB_2: 6.711793534891392
# R2 for XGB_2: 0.9512764535001564
# EVS for XGB_2: 0.9512767055171698
# Local Model Results for Node گلبرگ.منطقه8 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node گلبرگ.منطقه8 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node میدان.فتح.منطقه9 - CO with Weighted Predictions:
# MSE for XGB_1: 114.2883738001262
# MSE for XGB_2: 17.698255885239174
# RMSE for XGB_2: 4.206929507995015
# R2 for XGB_2: 0.9508928374084432
# EVS for XGB_2: 0.9509223121754364
# Local Model Results for Node میدان.فتح.منطقه9 - O3 with Weighted Predictions:
# MSE for XGB_1: 265.33317279451353
# MSE for XGB_2: 18.53236321136809
# RMSE for XGB_2: 4.3049231365226595
# R2 for XGB_2: 0.9838042495865694
# EVS for XGB_2: 0.983804271569967
# Local Model Results for Node میدان.فتح.منطقه9 - NO2 with Weighted Predictions:
# MSE for XGB_1: 199.9119509059597
# MSE for XGB_2: 24.066502017214834
# RMSE for XGB_2: 4.905762123994073
# R2 for XGB_2: 0.9468926832391565
# EVS for XGB_2: 0.9468941128086926
# Local Model Results for Node میدان.فتح.منطقه9 - SO2 with Weighted Predictions:
# MSE for XGB_1: 110.1270810748667
# MSE for XGB_2: 21.09926991857442
# RMSE for XGB_2: 4.593394161028903
# R2 for XGB_2: 0.9329746572416482
# EVS for XGB_2: 0.9330003415904818
# Local Model Results for Node میدان.فتح.منطقه9 - PM10 with Weighted Predictions:
# MSE for XGB_1: 265.2893166991144
# MSE for XGB_2: 26.67192425834042
# RMSE for XGB_2: 5.164486833978805
# R2 for XGB_2: 0.9415025684961817
# EVS for XGB_2: 0.9415153016340558
# Local Model Results for Node میدان.فتح.منطقه9 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 328.2218413597794
# MSE for XGB_2: 24.246496941168978
# RMSE for XGB_2: 4.924073206317
# R2 for XGB_2: 0.9711322324281301
# EVS for XGB_2: 0.9711360130807118
# Local Model Results for Node میدان.فتح.منطقه9 - AQI with Weighted Predictions:
# MSE for XGB_1: 335.94723797477906
# MSE for XGB_2: 36.4940946489131
# RMSE for XGB_2: 6.041034236694334
# R2 for XGB_2: 0.9356375739972229
# EVS for XGB_2: 0.9356385963795796
# Local Model Results for Node میدان.فتح.منطقه9 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node میدان.فتح.منطقه9 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شهرداری.منطقه10 - CO with Weighted Predictions:
# MSE for XGB_1: 58.3500779396316
# MSE for XGB_2: 16.001615422646545
# RMSE for XGB_2: 4.000201922734219
# R2 for XGB_2: 0.8220466328177523
# EVS for XGB_2: 0.8220466693559453
# Local Model Results for Node شهرداری.منطقه10 - O3 with Weighted Predictions:
# MSE for XGB_1: 279.4538598103967
# MSE for XGB_2: 21.67076008225681
# RMSE for XGB_2: 4.655186363858789
# R2 for XGB_2: 0.9782337310211157
# EVS for XGB_2: 0.9782337311647225
# Local Model Results for Node شهرداری.منطقه10 - NO2 with Weighted Predictions:
# MSE for XGB_1: 115.1702400852322
# MSE for XGB_2: 23.496445884766537
# RMSE for XGB_2: 4.847313264558681
# R2 for XGB_2: 0.8729281730160697
# EVS for XGB_2: 0.8729301911382529
# Local Model Results for Node شهرداری.منطقه10 - SO2 with Weighted Predictions:
# MSE for XGB_1: 109.87432893540534
# MSE for XGB_2: 15.439155090197675
# RMSE for XGB_2: 3.9292690274652453
# R2 for XGB_2: 0.9318249453003182
# EVS for XGB_2: 0.9318404171334224
# Local Model Results for Node شهرداری.منطقه10 - PM10 with Weighted Predictions:
# MSE for XGB_1: 195.10509001087308
# MSE for XGB_2: 18.443539069378364
# RMSE for XGB_2: 4.2945941681814785
# R2 for XGB_2: 0.9454152699992726
# EVS for XGB_2: 0.94542365094638
# Local Model Results for Node شهرداری.منطقه10 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 497.8521119334999
# MSE for XGB_2: 34.20402379489181
# RMSE for XGB_2: 5.8484206239712115
# R2 for XGB_2: 0.9702175379552991
# EVS for XGB_2: 0.9702271091560409
# Local Model Results for Node شهرداری.منطقه10 - AQI with Weighted Predictions:
# MSE for XGB_1: 510.71360312221844
# MSE for XGB_2: 44.39428914205839
# RMSE for XGB_2: 6.6629039571389885
# R2 for XGB_2: 0.9660021766693647
# EVS for XGB_2: 0.9660095793396344
# Local Model Results for Node شهرداری.منطقه10 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شهرداری.منطقه10 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شهرداری.منطقه11 - CO with Weighted Predictions:
# MSE for XGB_1: 198.43166324720133
# MSE for XGB_2: 15.39247314554074
# RMSE for XGB_2: 3.9233242468015233
# R2 for XGB_2: 0.9572507592476495
# EVS for XGB_2: 0.95726715732775
# Local Model Results for Node شهرداری.منطقه11 - O3 with Weighted Predictions:
# MSE for XGB_1: 579.5697792842927
# MSE for XGB_2: 26.63971664801954
# RMSE for XGB_2: 5.161367710987035
# R2 for XGB_2: 0.9848450583788713
# EVS for XGB_2: 0.984845229255527
# Local Model Results for Node شهرداری.منطقه11 - NO2 with Weighted Predictions:
# MSE for XGB_1: 276.79773730114164
# MSE for XGB_2: 40.640476174137284
# RMSE for XGB_2: 6.37498832737263
# R2 for XGB_2: 0.902693798436977
# EVS for XGB_2: 0.9027039947612203
# Local Model Results for Node شهرداری.منطقه11 - SO2 with Weighted Predictions:
# MSE for XGB_1: 21.153308765023954
# MSE for XGB_2: 7.577512908163198
# RMSE for XGB_2: 2.7527282663138397
# R2 for XGB_2: 0.7449169807755163
# EVS for XGB_2: 0.7449884350143948
# Local Model Results for Node شهرداری.منطقه11 - PM10 with Weighted Predictions:
# MSE for XGB_1: 194.5227342023057
# MSE for XGB_2: 18.421648655661322
# RMSE for XGB_2: 4.292044810537434
# R2 for XGB_2: 0.9455635315237401
# EVS for XGB_2: 0.945570063694514
# Local Model Results for Node شهرداری.منطقه11 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 454.5472064114908
# MSE for XGB_2: 28.75072470513664
# RMSE for XGB_2: 5.361970226058388
# R2 for XGB_2: 0.9763692959009449
# EVS for XGB_2: 0.9763704108092801
# Local Model Results for Node شهرداری.منطقه11 - AQI with Weighted Predictions:
# MSE for XGB_1: 693.7403182959903
# MSE for XGB_2: 47.0025832939072
# RMSE for XGB_2: 6.8558430038841465
# R2 for XGB_2: 0.960338852762507
# EVS for XGB_2: 0.9603396586626427
# Local Model Results for Node شهرداری.منطقه11 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شهرداری.منطقه11 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - CO with Weighted Predictions:
# MSE for XGB_1: 80.3712828271123
# MSE for XGB_2: 18.406188100305158
# RMSE for XGB_2: 4.290243361431279
# R2 for XGB_2: 0.7950236393554425
# EVS for XGB_2: 0.7950247147494105
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - O3 with Weighted Predictions:
# MSE for XGB_1: 459.7028959204534
# MSE for XGB_2: 29.86521727544174
# RMSE for XGB_2: 5.464907801184
# R2 for XGB_2: 0.9711533509983898
# EVS for XGB_2: 0.9711558904706276
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - NO2 with Weighted Predictions:
# MSE for XGB_1: 402.21546521014557
# MSE for XGB_2: 33.40631499935106
# RMSE for XGB_2: 5.779819633807881
# R2 for XGB_2: 0.9474792390851394
# EVS for XGB_2: 0.9474794412843793
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - SO2 with Weighted Predictions:
# MSE for XGB_1: 83.82533324398813
# MSE for XGB_2: 12.64160059831184
# RMSE for XGB_2: 3.5555028615249125
# R2 for XGB_2: 0.8857864197817273
# EVS for XGB_2: 0.8858330387208972
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - PM10 with Weighted Predictions:
# MSE for XGB_1: 211.85579595869413
# MSE for XGB_2: 18.05115447505849
# RMSE for XGB_2: 4.248665022693421
# R2 for XGB_2: 0.9493331325460832
# EVS for XGB_2: 0.949340409025658
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 1343.854619978799
# MSE for XGB_2: 29.43720468240167
# RMSE for XGB_2: 5.425606388451126
# R2 for XGB_2: 0.9741175055318075
# EVS for XGB_2: 0.9741183500497684
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - AQI with Weighted Predictions:
# MSE for XGB_1: 1451.5250936927462
# MSE for XGB_2: 50.03995273643537
# RMSE for XGB_2: 7.073892332827477
# R2 for XGB_2: 0.9549271307532344
# EVS for XGB_2: 0.9549279336630566
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node پیروزی.منطقه13 - CO with Weighted Predictions:
# MSE for XGB_1: 64.31834186108473
# MSE for XGB_2: 16.245057020536056
# RMSE for XGB_2: 4.030515726372502
# R2 for XGB_2: 0.83106683282798
# EVS for XGB_2: 0.8310777901832358
# Local Model Results for Node پیروزی.منطقه13 - O3 with Weighted Predictions:
# MSE for XGB_1: 520.6408785062598
# MSE for XGB_2: 14.900599587585496
# RMSE for XGB_2: 3.8601294780856117
# R2 for XGB_2: 0.9898829535610095
# EVS for XGB_2: 0.989884045394762
# Local Model Results for Node پیروزی.منطقه13 - NO2 with Weighted Predictions:
# MSE for XGB_1: 127.56965019939058
# MSE for XGB_2: 25.646844091894927
# RMSE for XGB_2: 5.0642713288186805
# R2 for XGB_2: 0.8870723269310294
# EVS for XGB_2: 0.887072574778349
# Local Model Results for Node پیروزی.منطقه13 - SO2 with Weighted Predictions:
# MSE for XGB_1: 87.67354229318391
# MSE for XGB_2: 13.161041772801056
# RMSE for XGB_2: 3.627815013586147
# R2 for XGB_2: 0.8840467556723246
# EVS for XGB_2: 0.8840557752193904
# Local Model Results for Node پیروزی.منطقه13 - PM10 with Weighted Predictions:
# MSE for XGB_1: 218.3703413690385
# MSE for XGB_2: 20.156855038209756
# RMSE for XGB_2: 4.489638631138341
# R2 for XGB_2: 0.9434092216278175
# EVS for XGB_2: 0.9434182503864211
# Local Model Results for Node پیروزی.منطقه13 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 369.10557259481027
# MSE for XGB_2: 28.501667712456094
# RMSE for XGB_2: 5.338695319313146
# R2 for XGB_2: 0.9690610865330975
# EVS for XGB_2: 0.9690612033396501
# Local Model Results for Node پیروزی.منطقه13 - AQI with Weighted Predictions:
# MSE for XGB_1: 552.1556020697096
# MSE for XGB_2: 56.38031966045381
# RMSE for XGB_2: 7.508682951120909
# R2 for XGB_2: 0.9521952919295975
# EVS for XGB_2: 0.9521959872566548
# Local Model Results for Node پیروزی.منطقه13 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node پیروزی.منطقه13 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - CO with Weighted Predictions:
# MSE for XGB_1: 75.62318642100193
# MSE for XGB_2: 18.235835145741635
# RMSE for XGB_2: 4.270343680049843
# R2 for XGB_2: 0.7720340599464468
# EVS for XGB_2: 0.7720345305576783
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - O3 with Weighted Predictions:
# MSE for XGB_1: 212.0097096447477
# MSE for XGB_2: 21.65880973314369
# RMSE for XGB_2: 4.653902634686688
# R2 for XGB_2: 0.9738530884615675
# EVS for XGB_2: 0.9738530886838703
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - NO2 with Weighted Predictions:
# MSE for XGB_1: 107.68117253924781
# MSE for XGB_2: 18.43706963247599
# RMSE for XGB_2: 4.293840895104986
# R2 for XGB_2: 0.9588742566194371
# EVS for XGB_2: 0.9588788773199507
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - SO2 with Weighted Predictions:
# MSE for XGB_1: 124.0135589690577
# MSE for XGB_2: 18.332666038192066
# RMSE for XGB_2: 4.281666268894864
# R2 for XGB_2: 0.9162752403733333
# EVS for XGB_2: 0.9162857493330047
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - PM10 with Weighted Predictions:
# MSE for XGB_1: 229.5355719142463
# MSE for XGB_2: 24.074641325715003
# RMSE for XGB_2: 4.906591620026575
# R2 for XGB_2: 0.9316008676445626
# EVS for XGB_2: 0.9316033554256269
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 612.0738631915347
# MSE for XGB_2: 44.512878222285714
# RMSE for XGB_2: 6.67179722580698
# R2 for XGB_2: 0.9696926609227252
# EVS for XGB_2: 0.9696965734364669
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - AQI with Weighted Predictions:
# MSE for XGB_1: 335.18559663391187
# MSE for XGB_2: 29.81694209427945
# RMSE for XGB_2: 5.460489180859115
# R2 for XGB_2: 0.9467150175364678
# EVS for XGB_2: 0.9467153356935076
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node مسعودیه.منطقه15 - CO with Weighted Predictions:
# MSE for XGB_1: 61.191612615092524
# MSE for XGB_2: 15.74650475362174
# RMSE for XGB_2: 3.9681865825111777
# R2 for XGB_2: 0.7137582724628493
# EVS for XGB_2: 0.7137698698857626
# Local Model Results for Node مسعودیه.منطقه15 - O3 with Weighted Predictions:
# MSE for XGB_1: 287.59390455688856
# MSE for XGB_2: 19.538512078234465
# RMSE for XGB_2: 4.420238916420069
# R2 for XGB_2: 0.9800818070589563
# EVS for XGB_2: 0.9800828276515184
# Local Model Results for Node مسعودیه.منطقه15 - NO2 with Weighted Predictions:
# MSE for XGB_1: 160.53892408350245
# MSE for XGB_2: 43.61684587501319
# RMSE for XGB_2: 6.6043051015995005
# R2 for XGB_2: 0.8557727841513829
# EVS for XGB_2: 0.8557755984201
# Local Model Results for Node مسعودیه.منطقه15 - SO2 with Weighted Predictions:
# MSE for XGB_1: 143.77417336199238
# MSE for XGB_2: 16.69402281850243
# RMSE for XGB_2: 4.085831961608606
# R2 for XGB_2: 0.9348438644496764
# EVS for XGB_2: 0.9348440726395966
# Local Model Results for Node مسعودیه.منطقه15 - PM10 with Weighted Predictions:
# MSE for XGB_1: 193.5421045037827
# MSE for XGB_2: 14.693069581591415
# RMSE for XGB_2: 3.8331539992011034
# R2 for XGB_2: 0.9598324250548685
# EVS for XGB_2: 0.9598333633008379
# Local Model Results for Node مسعودیه.منطقه15 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 328.2925091387037
# MSE for XGB_2: 24.656964795524285
# RMSE for XGB_2: 4.96557799208957
# R2 for XGB_2: 0.9622955758162877
# EVS for XGB_2: 0.9622962835392277
# Local Model Results for Node مسعودیه.منطقه15 - AQI with Weighted Predictions:
# MSE for XGB_1: 250.8429203913608
# MSE for XGB_2: 25.694538551260404
# RMSE for XGB_2: 5.068978057879162
# R2 for XGB_2: 0.9555659966542004
# EVS for XGB_2: 0.9555688935505702
# Local Model Results for Node مسعودیه.منطقه15 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node مسعودیه.منطقه15 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شهرداری.منطقه16 - CO with Weighted Predictions:
# MSE for XGB_1: 58.48867723228363
# MSE for XGB_2: 15.597174136089722
# RMSE for XGB_2: 3.9493257824709422
# R2 for XGB_2: 0.827424200047972
# EVS for XGB_2: 0.8274242270041577
# Local Model Results for Node شهرداری.منطقه16 - O3 with Weighted Predictions:
# MSE for XGB_1: 269.9322735726697
# MSE for XGB_2: 18.951656476993698
# RMSE for XGB_2: 4.353350029229639
# R2 for XGB_2: 0.9808776483372164
# EVS for XGB_2: 0.9808787483081746
# Local Model Results for Node شهرداری.منطقه16 - NO2 with Weighted Predictions:
# MSE for XGB_1: 128.72430486167858
# MSE for XGB_2: 26.41252016453261
# RMSE for XGB_2: 5.139311253906754
# R2 for XGB_2: 0.8694272154843891
# EVS for XGB_2: 0.8694417976533159
# Local Model Results for Node شهرداری.منطقه16 - SO2 with Weighted Predictions:
# MSE for XGB_1: 64.43317212137813
# MSE for XGB_2: 11.90279101905813
# RMSE for XGB_2: 3.450042176417287
# R2 for XGB_2: 0.9289987762346755
# EVS for XGB_2: 0.9290395134203894
# Local Model Results for Node شهرداری.منطقه16 - PM10 with Weighted Predictions:
# MSE for XGB_1: 182.00285230484093
# MSE for XGB_2: 17.48273689650105
# RMSE for XGB_2: 4.181236288049391
# R2 for XGB_2: 0.9503301374700698
# EVS for XGB_2: 0.9503306115452579
# Local Model Results for Node شهرداری.منطقه16 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 313.70867549921667
# MSE for XGB_2: 24.624699874308043
# RMSE for XGB_2: 4.962328069999811
# R2 for XGB_2: 0.9702163038592835
# EVS for XGB_2: 0.9702166574022397
# Local Model Results for Node شهرداری.منطقه16 - AQI with Weighted Predictions:
# MSE for XGB_1: 186.3095326898655
# MSE for XGB_2: 28.98140345526663
# RMSE for XGB_2: 5.383437884406825
# R2 for XGB_2: 0.961223378164306
# EVS for XGB_2: 0.9612236948212796
# Local Model Results for Node شهرداری.منطقه16 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شهرداری.منطقه16 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node پارک.سلامت.منطقه17 - CO with Weighted Predictions:
# MSE for XGB_1: 93.69681802463806
# MSE for XGB_2: 18.759798415652572
# RMSE for XGB_2: 4.331258294728285
# R2 for XGB_2: 0.8430877279826177
# EVS for XGB_2: 0.8430881258428319
# Local Model Results for Node پارک.سلامت.منطقه17 - O3 with Weighted Predictions:
# MSE for XGB_1: 269.90746535915224
# MSE for XGB_2: 18.961204189750763
# RMSE for XGB_2: 4.35444648488769
# R2 for XGB_2: 0.9808641946369069
# EVS for XGB_2: 0.9808643959771224
# Local Model Results for Node پارک.سلامت.منطقه17 - NO2 with Weighted Predictions:
# MSE for XGB_1: 280.8996382738898
# MSE for XGB_2: 35.11906876483389
# RMSE for XGB_2: 5.926134386329244
# R2 for XGB_2: 0.9346189314477964
# EVS for XGB_2: 0.9346307066807469
# Local Model Results for Node پارک.سلامت.منطقه17 - SO2 with Weighted Predictions:
# MSE for XGB_1: 561.4300206895155
# MSE for XGB_2: 36.36414324310558
# RMSE for XGB_2: 6.030268919634147
# R2 for XGB_2: 0.979625745618872
# EVS for XGB_2: 0.9796317008538287
# Local Model Results for Node پارک.سلامت.منطقه17 - PM10 with Weighted Predictions:
# MSE for XGB_1: 200.71175389521642
# MSE for XGB_2: 19.743725026331628
# RMSE for XGB_2: 4.443391162876798
# R2 for XGB_2: 0.943349490351197
# EVS for XGB_2: 0.9433505094801741
# Local Model Results for Node پارک.سلامت.منطقه17 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 482.95054107060906
# MSE for XGB_2: 40.344292498147844
# RMSE for XGB_2: 6.351715712950938
# R2 for XGB_2: 0.9627406713212696
# EVS for XGB_2: 0.9627469849635211
# Local Model Results for Node پارک.سلامت.منطقه17 - AQI with Weighted Predictions:
# MSE for XGB_1: 549.257264576556
# MSE for XGB_2: 52.665834749754154
# RMSE for XGB_2: 7.257123035318759
# R2 for XGB_2: 0.9428852082222717
# EVS for XGB_2: 0.9428883480867849
# Local Model Results for Node پارک.سلامت.منطقه17 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node پارک.سلامت.منطقه17 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شادآباد.منطقه18 - CO with Weighted Predictions:
# MSE for XGB_1: 251.34080089054927
# MSE for XGB_2: 36.14627450482018
# RMSE for XGB_2: 6.012177185081971
# R2 for XGB_2: 0.9042614429398954
# EVS for XGB_2: 0.9043084637141429
# Local Model Results for Node شادآباد.منطقه18 - O3 with Weighted Predictions:
# MSE for XGB_1: 501.92714338005624
# MSE for XGB_2: 25.35159300651484
# RMSE for XGB_2: 5.035036544704997
# R2 for XGB_2: 0.9860981589667076
# EVS for XGB_2: 0.9860995919668797
# Local Model Results for Node شادآباد.منطقه18 - NO2 with Weighted Predictions:
# MSE for XGB_1: 211.80714245138492
# MSE for XGB_2: 23.083782464398777
# RMSE for XGB_2: 4.804558508791289
# R2 for XGB_2: 0.9563047537452344
# EVS for XGB_2: 0.9563047557563417
# Local Model Results for Node شادآباد.منطقه18 - SO2 with Weighted Predictions:
# MSE for XGB_1: 226.9724154126422
# MSE for XGB_2: 23.949004607323836
# RMSE for XGB_2: 4.8937720224101
# R2 for XGB_2: 0.9586294204334136
# EVS for XGB_2: 0.9586316469168342
# Local Model Results for Node شادآباد.منطقه18 - PM10 with Weighted Predictions:
# MSE for XGB_1: 273.2237718963734
# MSE for XGB_2: 21.6728625538888
# RMSE for XGB_2: 4.655412178732276
# R2 for XGB_2: 0.9510640425066155
# EVS for XGB_2: 0.9510648787804029
# Local Model Results for Node شادآباد.منطقه18 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 499.59687272225403
# MSE for XGB_2: 46.60636335713845
# RMSE for XGB_2: 6.826885333527907
# R2 for XGB_2: 0.9551354467124891
# EVS for XGB_2: 0.9551363094269447
# Local Model Results for Node شادآباد.منطقه18 - AQI with Weighted Predictions:
# MSE for XGB_1: 724.3740383337071
# MSE for XGB_2: 41.61684235311781
# RMSE for XGB_2: 6.451111714512299
# R2 for XGB_2: 0.9602742975294734
# EVS for XGB_2: 0.9602761830804348
# Local Model Results for Node شادآباد.منطقه18 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شادآباد.منطقه18 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شهرداری.منطقه19 - CO with Weighted Predictions:
# MSE for XGB_1: 251.77714857325702
# MSE for XGB_2: 30.793271994992768
# RMSE for XGB_2: 5.549168585922829
# R2 for XGB_2: 0.8744981491049367
# EVS for XGB_2: 0.8745119492408073
# Local Model Results for Node شهرداری.منطقه19 - O3 with Weighted Predictions:
# MSE for XGB_1: 268.8318216132655
# MSE for XGB_2: 16.44449724356021
# RMSE for XGB_2: 4.055181530284459
# R2 for XGB_2: 0.9851647519533066
# EVS for XGB_2: 0.9851650876259016
# Local Model Results for Node شهرداری.منطقه19 - NO2 with Weighted Predictions:
# MSE for XGB_1: 115.17997907430504
# MSE for XGB_2: 16.471222359074662
# RMSE for XGB_2: 4.058475373717902
# R2 for XGB_2: 0.9438177546905494
# EVS for XGB_2: 0.9438195937112603
# Local Model Results for Node شهرداری.منطقه19 - SO2 with Weighted Predictions:
# MSE for XGB_1: 82.02340291300445
# MSE for XGB_2: 26.785841298211494
# RMSE for XGB_2: 5.175503965626101
# R2 for XGB_2: 0.8253834585360386
# EVS for XGB_2: 0.825383545498912
# Local Model Results for Node شهرداری.منطقه19 - PM10 with Weighted Predictions:
# MSE for XGB_1: 535.0236315448535
# MSE for XGB_2: 40.026246953444165
# RMSE for XGB_2: 6.326629983920679
# R2 for XGB_2: 0.960530058037931
# EVS for XGB_2: 0.9605351718080511
# Local Model Results for Node شهرداری.منطقه19 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 523.0603126400159
# MSE for XGB_2: 61.02119504525007
# RMSE for XGB_2: 7.811606431794299
# R2 for XGB_2: 0.9547138867074609
# EVS for XGB_2: 0.9547149488560489
# Local Model Results for Node شهرداری.منطقه19 - AQI with Weighted Predictions:
# MSE for XGB_1: 664.4034612763747
# MSE for XGB_2: 64.25326531000256
# RMSE for XGB_2: 8.01581345279458
# R2 for XGB_2: 0.9529050695239373
# EVS for XGB_2: 0.9529082028852756
# Local Model Results for Node شهرداری.منطقه19 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شهرداری.منطقه19 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شهر.ری.منطقه20 - CO with Weighted Predictions:
# MSE for XGB_1: 325.9386182020374
# MSE for XGB_2: 37.29325901097489
# RMSE for XGB_2: 6.106820695826503
# R2 for XGB_2: 0.8764880742611034
# EVS for XGB_2: 0.8764975905270181
# Local Model Results for Node شهر.ری.منطقه20 - O3 with Weighted Predictions:
# MSE for XGB_1: 198.9698581805755
# MSE for XGB_2: 18.671432325756996
# RMSE for XGB_2: 4.321045281613813
# R2 for XGB_2: 0.9660201530232747
# EVS for XGB_2: 0.9660404207287059
# Local Model Results for Node شهر.ری.منطقه20 - NO2 with Weighted Predictions:
# MSE for XGB_1: 201.61122171790603
# MSE for XGB_2: 35.79041633926472
# RMSE for XGB_2: 5.982509200934397
# R2 for XGB_2: 0.8868894941864829
# EVS for XGB_2: 0.8868904996555981
# Local Model Results for Node شهر.ری.منطقه20 - SO2 with Weighted Predictions:
# MSE for XGB_1: 232.42243512293734
# MSE for XGB_2: 26.070252738393474
# RMSE for XGB_2: 5.105903714171809
# R2 for XGB_2: 0.9474570361455816
# EVS for XGB_2: 0.9474621284366607
# Local Model Results for Node شهر.ری.منطقه20 - PM10 with Weighted Predictions:
# MSE for XGB_1: 233.7786959322425
# MSE for XGB_2: 23.556398036961276
# RMSE for XGB_2: 4.853493384868395
# R2 for XGB_2: 0.947763914608153
# EVS for XGB_2: 0.9477642185731848
# Local Model Results for Node شهر.ری.منطقه20 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 365.5533122449394
# MSE for XGB_2: 27.273892533742096
# RMSE for XGB_2: 5.22244124272759
# R2 for XGB_2: 0.9701084810010968
# EVS for XGB_2: 0.9701113554605203
# Local Model Results for Node شهر.ری.منطقه20 - AQI with Weighted Predictions:
# MSE for XGB_1: 370.37271206170607
# MSE for XGB_2: 35.047896942708874
# RMSE for XGB_2: 5.9201264296219955
# R2 for XGB_2: 0.9540283019831152
# EVS for XGB_2: 0.9540302205170464
# Local Model Results for Node شهر.ری.منطقه20 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شهر.ری.منطقه20 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شهرداری.منطقه21 - CO with Weighted Predictions:
# MSE for XGB_1: 132.00286720818204
# MSE for XGB_2: 20.224333061602614
# RMSE for XGB_2: 4.4971472136903206
# R2 for XGB_2: 0.9012071054261654
# EVS for XGB_2: 0.9012085501741688
# Local Model Results for Node شهرداری.منطقه21 - O3 with Weighted Predictions:
# MSE for XGB_1: 299.80051555015166
# MSE for XGB_2: 29.98993982195736
# RMSE for XGB_2: 5.476307133640092
# R2 for XGB_2: 0.9663512085575652
# EVS for XGB_2: 0.9663651339636267
# Local Model Results for Node شهرداری.منطقه21 - NO2 with Weighted Predictions:
# MSE for XGB_1: 253.10973905168962
# MSE for XGB_2: 33.119349667615225
# RMSE for XGB_2: 5.754941326166169
# R2 for XGB_2: 0.886334496323977
# EVS for XGB_2: 0.886340494565238
# Local Model Results for Node شهرداری.منطقه21 - SO2 with Weighted Predictions:
# MSE for XGB_1: 247.66377091863532
# MSE for XGB_2: 26.47168400076611
# RMSE for XGB_2: 5.145064042435829
# R2 for XGB_2: 0.9481307993446667
# EVS for XGB_2: 0.9481307994092121
# Local Model Results for Node شهرداری.منطقه21 - PM10 with Weighted Predictions:
# MSE for XGB_1: 431.7475899429569
# MSE for XGB_2: 26.46900632030825
# RMSE for XGB_2: 5.1448038174752835
# R2 for XGB_2: 0.9649574241257096
# EVS for XGB_2: 0.9649586001223485
# Local Model Results for Node شهرداری.منطقه21 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 345.44798002706466
# MSE for XGB_2: 32.1643762224037
# RMSE for XGB_2: 5.671364582038763
# R2 for XGB_2: 0.9676997191593167
# EVS for XGB_2: 0.9676999594497364
# Local Model Results for Node شهرداری.منطقه21 - AQI with Weighted Predictions:
# MSE for XGB_1: 531.576434471981
# MSE for XGB_2: 45.851416102799256
# RMSE for XGB_2: 6.771367373197179
# R2 for XGB_2: 0.9620720205056076
# EVS for XGB_2: 0.9620720361355309
# Local Model Results for Node شهرداری.منطقه21 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شهرداری.منطقه21 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# Local Model Results for Node شهرداری.منطقه22 - CO with Weighted Predictions:
# MSE for XGB_1: 83.25606892255695
# MSE for XGB_2: 16.139842449796408
# RMSE for XGB_2: 4.017442277095765
# R2 for XGB_2: 0.8879980569831101
# EVS for XGB_2: 0.8880045881520147
# Local Model Results for Node شهرداری.منطقه22 - O3 with Weighted Predictions:
# MSE for XGB_1: 269.9322735726697
# MSE for XGB_2: 18.951656476993698
# RMSE for XGB_2: 4.353350029229639
# R2 for XGB_2: 0.9808776483372164
# EVS for XGB_2: 0.9808787483081746
# Local Model Results for Node شهرداری.منطقه22 - NO2 with Weighted Predictions:
# MSE for XGB_1: 232.6374349859435
# MSE for XGB_2: 28.19122128083089
# RMSE for XGB_2: 5.30954059037417
# R2 for XGB_2: 0.9101881711250163
# EVS for XGB_2: 0.9101916197159526
# Local Model Results for Node شهرداری.منطقه22 - SO2 with Weighted Predictions:
# MSE for XGB_1: 125.13780898762347
# MSE for XGB_2: 19.369467402675216
# RMSE for XGB_2: 4.401075709718616
# R2 for XGB_2: 0.931088678483502
# EVS for XGB_2: 0.9310887874663384
# Local Model Results for Node شهرداری.منطقه22 - PM10 with Weighted Predictions:
# MSE for XGB_1: 202.59026147348686
# MSE for XGB_2: 22.261735787434752
# RMSE for XGB_2: 4.7182343930155435
# R2 for XGB_2: 0.9284459721183973
# EVS for XGB_2: 0.9284656398158229
# Local Model Results for Node شهرداری.منطقه22 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 305.32590998548255
# MSE for XGB_2: 26.259331392270933
# RMSE for XGB_2: 5.124385952704083
# R2 for XGB_2: 0.9696688489788633
# EVS for XGB_2: 0.9696698048683218
# Local Model Results for Node شهرداری.منطقه22 - AQI with Weighted Predictions:
# MSE for XGB_1: 324.2601767612617
# MSE for XGB_2: 27.71062355124426
# RMSE for XGB_2: 5.264088102534404
# R2 for XGB_2: 0.9600979110990991
# EVS for XGB_2: 0.9600986124593376
# Local Model Results for Node شهرداری.منطقه22 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.743124793295895
# MSE for XGB_2: 2.532715919058239
# RMSE for XGB_2: 1.5914508849029048
# R2 for XGB_2: 0.9788037162661039
# EVS for XGB_2: 0.97880772735957
# Local Model Results for Node شهرداری.منطقه22 - Wind:km/h with Weighted Predictions:
# MSE for XGB_1: 45.87815188618677
# MSE for XGB_2: 16.005053523611682
# RMSE for XGB_2: 4.000631640580233
# R2 for XGB_2: 0.6621500867514049
# EVS for XGB_2: 0.6621534455178044
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Global Model Results:
# Mean Squared Error (MSE) for Global Model: 5.191857072402621
# Duration of the program execution: 17.415807962417603 seconds
