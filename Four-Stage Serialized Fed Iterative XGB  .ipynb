# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
# Import the time module
import time

# Record the start time
start_time = time.time()

# Read data from Excel file
file_path = ''
df = pd.read_excel(file_path)

# Convert 'iranidate' to datetime and drop rows with invalid dates
df['iranidate'] = pd.to_datetime(df['iranidate'], errors='coerce')
df = df.dropna(subset=['iranidate'])

# Function to convert date values to numeric representation
def convert_to_numeric_date(date):
    base_date = datetime(2000, 1, 1)
    return (date - base_date).days

df['iranidate'] = df['iranidate'].apply(convert_to_numeric_date)

# Encode 'node' column
label_encoder = LabelEncoder()
df['node_encoded'] = label_encoder.fit_transform(df['node'])

# Handling NaN values by finding the nearest non-empty cells in the same column 
for col in ['CO', 'O3', 'SO2', 'PM10', 'PM2.5', 'AQI']:
    for idx, value in df[col].items():
        if pd.isnull(value):
            upper_cell = df[col].iloc[:idx].last_valid_index()
            lower_cell = df[col].iloc[idx + 1:].first_valid_index()
            if upper_cell is not None and lower_cell is not None:
                avg = (df.at[upper_cell, col] + df.at[lower_cell, col]) / 2
                df.at[idx, col] = avg

# Check sample threshold
your_threshold_value = 100
if len(df) < your_threshold_value:
    print("Insufficient samples in the dataset.")
else:
    output_columns = ['CO', 'O3', 'NO2', 'SO2', 'PM10', 'PM2.5', 'AQI', 'Highest tempreture: 12pm']
    unique_nodes = df['node'].unique()  

    # Dictionary to store weighted predictions for each node and column
    weighted_predictions = {}
                
    for node_value in unique_nodes:
        node_df = df[df['node'] == node_value]  
        
        # Dictionary to store predictions and true values for each column
        columns_data = {}

        for output_column in output_columns:
            if node_df[output_column].isnull().any():
                print(f"NaN values found in {output_column} for Node {node_value}. Handle missing values before modeling.")
            else:
                # Modify X to include the 'node' column along with 'iranidate'
                X = node_df[['iranidate', 'node_encoded']]
                Y = node_df[[output_column]]  
                X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
                xgb_model_1 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.3, max_depth=10, alpha=10, n_estimators=200)
                xgb_model_1.fit(X_train, Y_train)
                Y1_pred_xgb = xgb_model_1.predict(X_test)
                xgb_model_2 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.3, max_depth=10, alpha=10, n_estimators=200)
                xgb_model_2.fit(np.concatenate((X_test, Y1_pred_xgb.reshape(-1, 1)), axis=1), Y_test)
                Y2_pred_xgb = xgb_model_2.predict(np.concatenate((X_test, Y1_pred_xgb.reshape(-1, 1)), axis=1))
                xgb_model_3 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.3, max_depth=10, alpha=10, n_estimators=200)
                xgb_model_3.fit(np.concatenate((X_test, Y2_pred_xgb.reshape(-1, 1)), axis=1), Y_test)
                Y3_pred_xgb = xgb_model_3.predict(np.concatenate((X_test, Y2_pred_xgb.reshape(-1, 1)), axis=1))
                xgb_model_4 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.3, max_depth=10, alpha=10, n_estimators=200)
                xgb_model_4.fit(np.concatenate((X_test, Y3_pred_xgb.reshape(-1, 1)), axis=1), Y_test)
                Y4_pred_xgb = xgb_model_4.predict(np.concatenate((X_test, Y3_pred_xgb.reshape(-1, 1)), axis=1))

                # Calculate errors for the fourth XGBoost model
                mse_xgb_1 = mean_squared_error(Y_test, Y1_pred_xgb)
                mse_xgb_2 = mean_squared_error(Y_test, Y2_pred_xgb)
                mse_xgb_3 = mean_squared_error(Y_test, Y3_pred_xgb)
                mse_xgb_4 = mean_squared_error(Y_test, Y4_pred_xgb)
                rmse_xgb_4 = np.sqrt(mse_xgb_4)
                r2_xgb_4 = r2_score(Y_test, Y4_pred_xgb)
                evs_xgb_4 = explained_variance_score(Y_test, Y4_pred_xgb)

                # Store predictions and true values for each column in the dictionary
                columns_data[output_column] = (Y4_pred_xgb, Y_test)

                # Output results for the local model with weighted predictions
                print(f"Local Model Results for Node {node_value} - {output_column} with Weighted Predictions:")
                print(f"MSE for XGB_1: {mse_xgb_1}")
                print(f"MSE for XGB_2: {mse_xgb_2}")
                print(f"MSE for XGB_3: {mse_xgb_3}")
                print(f"MSE for XGB_4: {mse_xgb_4}")
                print(f"RMSE for XGB_4: {rmse_xgb_4}")
                print(f"R2 for XGB_4: {r2_xgb_4}")
                print(f"EVS for XGB_4: {evs_xgb_4}")

                # Store weighted predictions for each node and column
                if node_value not in weighted_predictions:
                    weighted_predictions[node_value] = {output_column: (Y4_pred_xgb, Y_test)}
                else:
                    weighted_predictions[node_value][output_column] = (Y4_pred_xgb, Y_test)


# Aggregate predictions for the global model using weighted average
global_X_test = []
global_Y_test = []

for node, columns in weighted_predictions.items():
    for column, (node_prediction, Y_test) in columns.items():
        global_X_test.extend(node_prediction * r2_xgb_4)  # Apply weights using the R2 score from the fourth XGBoost model
        global_Y_test.extend(Y_test.values)

# Create and train the global model (Random Forest)
global_model = RandomForestRegressor(random_state=42)
global_model.fit(np.array(global_X_test).reshape(-1, 1), global_Y_test)  # Reshape for RF

# Predict using the global model
global_Y_pred = global_model.predict(np.array(global_X_test).reshape(-1, 1))
global_mse = mean_squared_error(global_Y_test, global_Y_pred)

# Print results for the global model
print("Global Model Results:")
print(f"Mean Squared Error (MSE) for Global Model: {global_mse}")

# Record the end time
end_time = time.time()

# Calculate the duration of the program execution
duration_seconds = end_time - start_time

# Print the duration of the program execution
print(f"Duration of the program execution: {duration_seconds} seconds")
# Out:
# 2024-02-27 22:55:22.614336: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Local Model Results for Node اقدسیه.منطقه1 - CO with Weighted Predictions:
# MSE for XGB_1: 51.02335610081563
# MSE for XGB_2: 12.96339893055318
# MSE for XGB_3: 5.473984936654395
# MSE for XGB_4: 4.501487987712225
# RMSE for XGB_4: 2.1216710366388623
# R2 for XGB_4: 0.9442709405407346
# EVS for XGB_4: 0.9442713475910993
# Local Model Results for Node اقدسیه.منطقه1 - O3 with Weighted Predictions:
# MSE for XGB_1: 415.29830034606607
# MSE for XGB_2: 16.294605543988634
# MSE for XGB_3: 8.004895184759615
# MSE for XGB_4: 6.041959425388637
# RMSE for XGB_4: 2.458039752605445
# R2 for XGB_4: 0.995051212799771
# EVS for XGB_4: 0.9950512156419704
# Local Model Results for Node اقدسیه.منطقه1 - NO2 with Weighted Predictions:
# MSE for XGB_1: 456.89028626028204
# MSE for XGB_2: 18.92046274248124
# MSE for XGB_3: 8.38755324626844
# MSE for XGB_4: 5.942090836809127
# RMSE for XGB_4: 2.437640424018507
# R2 for XGB_4: 0.9902223592783201
# EVS for XGB_4: 0.9902223659370338
# Local Model Results for Node اقدسیه.منطقه1 - SO2 with Weighted Predictions:
# MSE for XGB_1: 45.20623290023065
# MSE for XGB_2: 9.087105320667364
# MSE for XGB_3: 5.044433643255176
# MSE for XGB_4: 4.016419316620042
# RMSE for XGB_4: 2.004100625372898
# R2 for XGB_4: 0.9456538275395876
# EVS for XGB_4: 0.9456563562909632
# Local Model Results for Node اقدسیه.منطقه1 - PM10 with Weighted Predictions:
# MSE for XGB_1: 145.38581054391727
# MSE for XGB_2: 13.037801214651637
# MSE for XGB_3: 5.66749264184322
# MSE for XGB_4: 4.749235201279845
# RMSE for XGB_4: 2.179274007847532
# R2 for XGB_4: 0.9789069075363038
# EVS for XGB_4: 0.9789070613961286
# Local Model Results for Node اقدسیه.منطقه1 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 487.7744610987405
# MSE for XGB_2: 17.82874904606149
# MSE for XGB_3: 6.838744868499526
# MSE for XGB_4: 6.967947964045705
# RMSE for XGB_4: 2.639687095859224
# R2 for XGB_4: 0.9914325429156007
# EVS for XGB_4: 0.9914325789679937
# Local Model Results for Node اقدسیه.منطقه1 - AQI with Weighted Predictions:
# MSE for XGB_1: 649.2558760187534
# MSE for XGB_2: 14.832121535501305
# MSE for XGB_3: 6.62047367497407
# MSE for XGB_4: 6.255391832353454
# RMSE for XGB_4: 2.501078133996108
# R2 for XGB_4: 0.9915148598416903
# EVS for XGB_4: 0.9915148605385057
# Local Model Results for Node اقدسیه.منطقه1 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شریف.منطقه2 - CO with Weighted Predictions:
# MSE for XGB_1: 227.75689218745546
# MSE for XGB_2: 19.466231369320617
# MSE for XGB_3: 7.275929046024
# MSE for XGB_4: 5.257963876510629
# RMSE for XGB_4: 2.293025049254942
# R2 for XGB_4: 0.9685215199832813
# EVS for XGB_4: 0.9685217255632936
# Local Model Results for Node شریف.منطقه2 - O3 with Weighted Predictions:
# MSE for XGB_1: 190.97139602930048
# MSE for XGB_2: 11.442072887881517
# MSE for XGB_3: 5.626532506947543
# MSE for XGB_4: 4.696801163048161
# RMSE for XGB_4: 2.167210456565804
# R2 for XGB_4: 0.9910700083350015
# EVS for XGB_4: 0.9910701263979731
# Local Model Results for Node شریف.منطقه2 - NO2 with Weighted Predictions:
# MSE for XGB_1: 171.41844331878463
# MSE for XGB_2: 13.978105807333367
# MSE for XGB_3: 7.507898777976201
# MSE for XGB_4: 6.211083076240627
# RMSE for XGB_4: 2.4922044611629732
# R2 for XGB_4: 0.9881632596572326
# EVS for XGB_4: 0.9881638899669926
# Local Model Results for Node شریف.منطقه2 - SO2 with Weighted Predictions:
# MSE for XGB_1: 131.67589362454956
# MSE for XGB_2: 13.244023970971272
# MSE for XGB_3: 5.973527290926197
# MSE for XGB_4: 4.203733961013928
# RMSE for XGB_4: 2.050300944011373
# R2 for XGB_4: 0.978308828620618
# EVS for XGB_4: 0.9783093901508662
# Local Model Results for Node شریف.منطقه2 - PM10 with Weighted Predictions:
# MSE for XGB_1: 418.74617714030063
# MSE for XGB_2: 15.918005630094125
# MSE for XGB_3: 6.6682289992164145
# MSE for XGB_4: 4.538087126367286
# RMSE for XGB_4: 2.1302786499346245
# R2 for XGB_4: 0.9925388757455363
# EVS for XGB_4: 0.9925389297077637
# Local Model Results for Node شریف.منطقه2 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 540.3526429060652
# MSE for XGB_2: 15.693337183577839
# MSE for XGB_3: 6.777407125003535
# MSE for XGB_4: 6.076368698080989
# RMSE for XGB_4: 2.4650291475114425
# R2 for XGB_4: 0.992194726066213
# EVS for XGB_4: 0.9921949391987913
# Local Model Results for Node شریف.منطقه2 - AQI with Weighted Predictions:
# MSE for XGB_1: 504.1961751030801
# MSE for XGB_2: 15.535876751026278
# MSE for XGB_3: 5.686685830312608
# MSE for XGB_4: 4.9279265497902385
# RMSE for XGB_4: 2.219893364508809
# R2 for XGB_4: 0.994404672236841
# EVS for XGB_4: 0.9944047357385216
# Local Model Results for Node شریف.منطقه2 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node پاسداران.منطقه3 - CO with Weighted Predictions:
# MSE for XGB_1: 62.895446129483034
# MSE for XGB_2: 15.269097262342097
# MSE for XGB_3: 7.980291538120479
# MSE for XGB_4: 5.738811730020083
# RMSE for XGB_4: 2.3955817101531065
# R2 for XGB_4: 0.936020384082389
# EVS for XGB_4: 0.9360206619140566
# Local Model Results for Node پاسداران.منطقه3 - O3 with Weighted Predictions:
# MSE for XGB_1: 343.51281641649047
# MSE for XGB_2: 13.798216228735306
# MSE for XGB_3: 7.100737563337928
# MSE for XGB_4: 5.598298723359178
# RMSE for XGB_4: 2.3660724256368777
# R2 for XGB_4: 0.9943933817208173
# EVS for XGB_4: 0.9943933817287887
# Local Model Results for Node پاسداران.منطقه3 - NO2 with Weighted Predictions:
# MSE for XGB_1: 118.77166486769862
# MSE for XGB_2: 15.084929094120117
# MSE for XGB_3: 6.853651245102511
# MSE for XGB_4: 5.157189223236564
# RMSE for XGB_4: 2.2709445663064
# R2 for XGB_4: 0.9732986499517544
# EVS for XGB_4: 0.9732999478083669
# Local Model Results for Node پاسداران.منطقه3 - SO2 with Weighted Predictions:
# MSE for XGB_1: 57.99462557157884
# MSE for XGB_2: 9.327458358852137
# MSE for XGB_3: 5.441899961692878
# MSE for XGB_4: 4.6847562084953065
# RMSE for XGB_4: 2.1644297652026747
# R2 for XGB_4: 0.9716776027650894
# EVS for XGB_4: 0.9716776029002752
# Local Model Results for Node پاسداران.منطقه3 - PM10 with Weighted Predictions:
# MSE for XGB_1: 145.38581054391727
# MSE for XGB_2: 13.037801214651637
# MSE for XGB_3: 5.66749264184322
# MSE for XGB_4: 4.749235201279845
# RMSE for XGB_4: 2.179274007847532
# R2 for XGB_4: 0.9789069075363038
# EVS for XGB_4: 0.9789070613961286
# Local Model Results for Node پاسداران.منطقه3 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 486.062157694875
# MSE for XGB_2: 18.146517135810573
# MSE for XGB_3: 5.302228062284345
# MSE for XGB_4: 4.790818597569587
# RMSE for XGB_4: 2.188793868222768
# R2 for XGB_4: 0.9939904300908018
# EVS for XGB_4: 0.9939904307074696
# Local Model Results for Node پاسداران.منطقه3 - AQI with Weighted Predictions:
# MSE for XGB_1: 436.29226305139906
# MSE for XGB_2: 19.01250989367252
# MSE for XGB_3: 7.742135467810819
# MSE for XGB_4: 6.245611622779834
# RMSE for XGB_4: 2.499122170439019
# R2 for XGB_4: 0.9907999411923298
# EVS for XGB_4: 0.9907999586842838
# Local Model Results for Node پاسداران.منطقه3 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - CO with Weighted Predictions:
# MSE for XGB_1: 95.813080253609
# MSE for XGB_2: 15.848056957461672
# MSE for XGB_3: 6.306020981062394
# MSE for XGB_4: 4.827763666228681
# RMSE for XGB_4: 2.1972172551271942
# R2 for XGB_4: 0.9679272888037502
# EVS for XGB_4: 0.9679275412598088
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - O3 with Weighted Predictions:
# MSE for XGB_1: 261.8655717027308
# MSE for XGB_2: 14.592624230821098
# MSE for XGB_3: 6.752751587205315
# MSE for XGB_4: 6.080523512523781
# RMSE for XGB_4: 2.4658717550845544
# R2 for XGB_4: 0.9879367903402114
# EVS for XGB_4: 0.987936973135203
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - NO2 with Weighted Predictions:
# MSE for XGB_1: 603.22646466449
# MSE for XGB_2: 15.456918806691846
# MSE for XGB_3: 6.57106024206301
# MSE for XGB_4: 6.762626319653582
# RMSE for XGB_4: 2.6005050124261597
# R2 for XGB_4: 0.989698094621158
# EVS for XGB_4: 0.9896981761449715
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - SO2 with Weighted Predictions:
# MSE for XGB_1: 28.764951157360876
# MSE for XGB_2: 10.062497826873235
# MSE for XGB_3: 4.646703884569054
# MSE for XGB_4: 3.041010387483383
# RMSE for XGB_4: 1.7438493018272487
# R2 for XGB_4: 0.9468025313517356
# EVS for XGB_4: 0.9468349232067952
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - PM10 with Weighted Predictions:
# MSE for XGB_1: 213.9356152068524
# MSE for XGB_2: 15.288638398428741
# MSE for XGB_3: 7.619103703382458
# MSE for XGB_4: 5.804273529051883
# RMSE for XGB_4: 2.409205995561999
# R2 for XGB_4: 0.9829315370329488
# EVS for XGB_4: 0.9829316647967451
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 737.7285953017621
# MSE for XGB_2: 20.2983617251237
# MSE for XGB_3: 7.4522377914277085
# MSE for XGB_4: 5.678769399237377
# RMSE for XGB_4: 2.383016869272515
# R2 for XGB_4: 0.9961459720534677
# EVS for XGB_4: 0.9961459722822956
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - AQI with Weighted Predictions:
# MSE for XGB_1: 729.4292070619747
# MSE for XGB_2: 22.37742386662195
# MSE for XGB_3: 7.767038119313611
# MSE for XGB_4: 6.814505908229504
# RMSE for XGB_4: 2.6104608612713394
# R2 for XGB_4: 0.9952780451243551
# EVS for XGB_4: 0.9952780464511677
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node پونک - CO with Weighted Predictions:
# MSE for XGB_1: 78.08390962131752
# MSE for XGB_2: 12.931911035717711
# MSE for XGB_3: 6.478186363239567
# MSE for XGB_4: 4.84934642199776
# RMSE for XGB_4: 2.202123162313534
# R2 for XGB_4: 0.9624723460325679
# EVS for XGB_4: 0.9624723534179542
# Local Model Results for Node پونک - O3 with Weighted Predictions:
# MSE for XGB_1: 159.71814666293767
# MSE for XGB_2: 11.037001719492524
# MSE for XGB_3: 6.93851670295602
# MSE for XGB_4: 5.8638398357621195
# RMSE for XGB_4: 2.4215366682670982
# R2 for XGB_4: 0.9847068439165552
# EVS for XGB_4: 0.9847068783730892
# Local Model Results for Node پونک - NO2 with Weighted Predictions:
# MSE for XGB_1: 201.18254810458726
# MSE for XGB_2: 13.956666999161193
# MSE for XGB_3: 5.635410744472458
# MSE for XGB_4: 4.642310691864137
# RMSE for XGB_4: 2.154602211978846
# R2 for XGB_4: 0.9845457914062653
# EVS for XGB_4: 0.9845458068426526
# Local Model Results for Node پونک - SO2 with Weighted Predictions:
# MSE for XGB_1: 141.4732415904845
# MSE for XGB_2: 9.678585801668651
# MSE for XGB_3: 4.555955938271995
# MSE for XGB_4: 3.478581748419909
# RMSE for XGB_4: 1.8650956405557086
# R2 for XGB_4: 0.9880333405029881
# EVS for XGB_4: 0.9880347845996272
# Local Model Results for Node پونک - PM10 with Weighted Predictions:
# MSE for XGB_1: 168.4990673360924
# MSE for XGB_2: 13.843617401782513
# MSE for XGB_3: 6.329681224876978
# MSE for XGB_4: 5.325293673907399
# RMSE for XGB_4: 2.307659782963554
# R2 for XGB_4: 0.9790221216378923
# EVS for XGB_4: 0.9790224620004013
# Local Model Results for Node پونک - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 319.4242832699378
# MSE for XGB_2: 18.356295365416017
# MSE for XGB_3: 6.558722580463931
# MSE for XGB_4: 5.816355727730173
# RMSE for XGB_4: 2.411712198362436
# R2 for XGB_4: 0.9924269254372601
# EVS for XGB_4: 0.9924269422978417
# Local Model Results for Node پونک - AQI with Weighted Predictions:
# MSE for XGB_1: 257.87004259798414
# MSE for XGB_2: 17.0940977779186
# MSE for XGB_3: 7.999155859474484
# MSE for XGB_4: 6.548684246726961
# RMSE for XGB_4: 2.55903971183078
# R2 for XGB_4: 0.9860144409751812
# EVS for XGB_4: 0.9860145014130338
# Local Model Results for Node پونک - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node تربیت.مدرس.منطقه6 - CO with Weighted Predictions:
# MSE for XGB_1: 164.57896990480785
# MSE for XGB_2: 13.83918882606622
# MSE for XGB_3: 7.529913252457131
# MSE for XGB_4: 6.561438591168443
# RMSE for XGB_4: 2.5615305173213225
# R2 for XGB_4: 0.9727566356872464
# EVS for XGB_4: 0.9727566365146033
# Local Model Results for Node تربیت.مدرس.منطقه6 - O3 with Weighted Predictions:
# MSE for XGB_1: 678.5351151168925
# MSE for XGB_2: 13.457221303164731
# MSE for XGB_3: 4.496746481679073
# MSE for XGB_4: 5.01176265109809
# RMSE for XGB_4: 2.2386966411504017
# R2 for XGB_4: 0.9982294920644758
# EVS for XGB_4: 0.9982294962454502
# Local Model Results for Node تربیت.مدرس.منطقه6 - NO2 with Weighted Predictions:
# MSE for XGB_1: 138.78165032428743
# MSE for XGB_2: 15.681229781893329
# MSE for XGB_3: 6.756951671996016
# MSE for XGB_4: 5.583102967356094
# RMSE for XGB_4: 2.3628590663338542
# R2 for XGB_4: 0.981599210397422
# EVS for XGB_4: 0.9815996865886246
# Local Model Results for Node تربیت.مدرس.منطقه6 - SO2 with Weighted Predictions:
# MSE for XGB_1: 259.0821524549952
# MSE for XGB_2: 16.736290928948428
# MSE for XGB_3: 6.198432127941637
# MSE for XGB_4: 5.926045690299302
# RMSE for XGB_4: 2.4343470767947823
# R2 for XGB_4: 0.985108018202848
# EVS for XGB_4: 0.9851080201262943
# Local Model Results for Node تربیت.مدرس.منطقه6 - PM10 with Weighted Predictions:
# MSE for XGB_1: 277.0542635570321
# MSE for XGB_2: 15.387193881708846
# MSE for XGB_3: 5.952489161648659
# MSE for XGB_4: 4.6472168771808615
# RMSE for XGB_4: 2.155740447544848
# R2 for XGB_4: 0.9876482766060872
# EVS for XGB_4: 0.9876482768020806
# Local Model Results for Node تربیت.مدرس.منطقه6 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 467.4890334201936
# MSE for XGB_2: 15.686490155997678
# MSE for XGB_3: 5.929164214106104
# MSE for XGB_4: 5.174387463739216
# RMSE for XGB_4: 2.27472799774813
# R2 for XGB_4: 0.994933997653696
# EVS for XGB_4: 0.9949341136474861
# Local Model Results for Node تربیت.مدرس.منطقه6 - AQI with Weighted Predictions:
# MSE for XGB_1: 928.255393131535
# MSE for XGB_2: 22.321056963675666
# MSE for XGB_3: 7.031938957017535
# MSE for XGB_4: 7.081150027929661
# RMSE for XGB_4: 2.6610430338364806
# R2 for XGB_4: 0.9951891856028979
# EVS for XGB_4: 0.9951892426462597
# Local Model Results for Node تربیت.مدرس.منطقه6 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node گلبرگ.منطقه8 - CO with Weighted Predictions:
# MSE for XGB_1: 49.67349505792703
# MSE for XGB_2: 11.51407603302149
# MSE for XGB_3: 5.102356410668494
# MSE for XGB_4: 4.087554992079173
# RMSE for XGB_4: 2.021770261943521
# R2 for XGB_4: 0.9461467486471823
# EVS for XGB_4: 0.9461467514782789
# Local Model Results for Node گلبرگ.منطقه8 - O3 with Weighted Predictions:
# MSE for XGB_1: 713.9754400082992
# MSE for XGB_2: 18.38444528781276
# MSE for XGB_3: 7.544260987363821
# MSE for XGB_4: 5.675302283936776
# RMSE for XGB_4: 2.3822892947618213
# R2 for XGB_4: 0.9970574116494941
# EVS for XGB_4: 0.9970575159600381
# Local Model Results for Node گلبرگ.منطقه8 - NO2 with Weighted Predictions:
# MSE for XGB_1: 193.67153865441756
# MSE for XGB_2: 18.87449917910068
# MSE for XGB_3: 7.137036315769312
# MSE for XGB_4: 5.50350513167332
# RMSE for XGB_4: 2.3459550574709054
# R2 for XGB_4: 0.978947695520456
# EVS for XGB_4: 0.9789480732440766
# Local Model Results for Node گلبرگ.منطقه8 - SO2 with Weighted Predictions:
# MSE for XGB_1: 226.19714894991296
# MSE for XGB_2: 9.250469918774987
# MSE for XGB_3: 4.475359302770574
# MSE for XGB_4: 3.961628699478187
# RMSE for XGB_4: 1.990384058285784
# R2 for XGB_4: 0.9824560155804226
# EVS for XGB_4: 0.982456015581576
# Local Model Results for Node گلبرگ.منطقه8 - PM10 with Weighted Predictions:
# MSE for XGB_1: 199.76677137591477
# MSE for XGB_2: 18.547662870188752
# MSE for XGB_3: 8.183365920883825
# MSE for XGB_4: 5.9314004754151215
# RMSE for XGB_4: 2.4354466685631038
# R2 for XGB_4: 0.9792451522242491
# EVS for XGB_4: 0.9792453363623871
# Local Model Results for Node گلبرگ.منطقه8 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 373.88488871384914
# MSE for XGB_2: 17.910856482153502
# MSE for XGB_3: 9.405138300227422
# MSE for XGB_4: 6.272590095193644
# RMSE for XGB_4: 2.504513943900821
# R2 for XGB_4: 0.9921406590591104
# EVS for XGB_4: 0.9921412502792676
# Local Model Results for Node گلبرگ.منطقه8 - AQI with Weighted Predictions:
# MSE for XGB_1: 673.3953196094128
# MSE for XGB_2: 20.111397878825983
# MSE for XGB_3: 8.738119499619492
# MSE for XGB_4: 7.483782027041268
# RMSE for XGB_4: 2.73565020187912
# R2 for XGB_4: 0.991905633864428
# EVS for XGB_4: 0.991905643280157
# Local Model Results for Node گلبرگ.منطقه8 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node میدان.فتح.منطقه9 - CO with Weighted Predictions:
# MSE for XGB_1: 125.29532513909012
# MSE for XGB_2: 12.8337977668724
# MSE for XGB_3: 6.4232897472919825
# MSE for XGB_4: 5.023618239252156
# RMSE for XGB_4: 2.241342954403042
# R2 for XGB_4: 0.9860610198387618
# EVS for XGB_4: 0.9860610840579718
# Local Model Results for Node میدان.فتح.منطقه9 - O3 with Weighted Predictions:
# MSE for XGB_1: 349.7700180536259
# MSE for XGB_2: 14.486860302271769
# MSE for XGB_3: 7.077833714367159
# MSE for XGB_4: 5.875013987599763
# RMSE for XGB_4: 2.423842814127963
# R2 for XGB_4: 0.9948657244015047
# EVS for XGB_4: 0.9948659713547022
# Local Model Results for Node میدان.فتح.منطقه9 - NO2 with Weighted Predictions:
# MSE for XGB_1: 184.6061858622793
# MSE for XGB_2: 17.853774144334878
# MSE for XGB_3: 7.4692276623979055
# MSE for XGB_4: 5.700883991167782
# RMSE for XGB_4: 2.3876524016631446
# R2 for XGB_4: 0.9874199145468168
# EVS for XGB_4: 0.9874199221800246
# Local Model Results for Node میدان.فتح.منطقه9 - SO2 with Weighted Predictions:
# MSE for XGB_1: 112.11892551174572
# MSE for XGB_2: 17.833711558396807
# MSE for XGB_3: 6.912553948623881
# MSE for XGB_4: 4.983775796869903
# RMSE for XGB_4: 2.232437187665065
# R2 for XGB_4: 0.9841682066580931
# EVS for XGB_4: 0.984168216122164
# Local Model Results for Node میدان.فتح.منطقه9 - PM10 with Weighted Predictions:
# MSE for XGB_1: 273.78769334535497
# MSE for XGB_2: 14.770416705355121
# MSE for XGB_3: 6.335729466994215
# MSE for XGB_4: 4.691270174917527
# RMSE for XGB_4: 2.165934019059105
# R2 for XGB_4: 0.9897110064851309
# EVS for XGB_4: 0.98971113918652
# Local Model Results for Node میدان.فتح.منطقه9 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 331.4185908316744
# MSE for XGB_2: 13.348148405544922
# MSE for XGB_3: 6.441749560492028
# MSE for XGB_4: 6.265453385568109
# RMSE for XGB_4: 2.5030887690148163
# R2 for XGB_4: 0.9925403800596093
# EVS for XGB_4: 0.9925403838986504
# Local Model Results for Node میدان.فتح.منطقه9 - AQI with Weighted Predictions:
# MSE for XGB_1: 325.5421641268513
# MSE for XGB_2: 18.616764745214684
# MSE for XGB_3: 7.177492728520578
# MSE for XGB_4: 6.0764378381559325
# RMSE for XGB_4: 2.4650431716616916
# R2 for XGB_4: 0.9892833543486621
# EVS for XGB_4: 0.9892834124182652
# Local Model Results for Node میدان.فتح.منطقه9 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شهرداری.منطقه10 - CO with Weighted Predictions:
# MSE for XGB_1: 60.958445133125345
# MSE for XGB_2: 14.05767214425138
# MSE for XGB_3: 7.746199001884444
# MSE for XGB_4: 5.303184504231655
# RMSE for XGB_4: 2.302864412906599
# R2 for XGB_4: 0.9410234832927475
# EVS for XGB_4: 0.941027172521835
# Local Model Results for Node شهرداری.منطقه10 - O3 with Weighted Predictions:
# MSE for XGB_1: 347.9137733693845
# MSE for XGB_2: 15.737547449748984
# MSE for XGB_3: 7.110430317779046
# MSE for XGB_4: 5.371697987233457
# RMSE for XGB_4: 2.317692384082378
# R2 for XGB_4: 0.9946046274879308
# EVS for XGB_4: 0.9946048158902084
# Local Model Results for Node شهرداری.منطقه10 - NO2 with Weighted Predictions:
# MSE for XGB_1: 112.76678205519862
# MSE for XGB_2: 15.201581435723407
# MSE for XGB_3: 7.3693881831962385
# MSE for XGB_4: 5.649536644413095
# RMSE for XGB_4: 2.376875395222285
# R2 for XGB_4: 0.9694465730460252
# EVS for XGB_4: 0.96944683593045
# Local Model Results for Node شهرداری.منطقه10 - SO2 with Weighted Predictions:
# MSE for XGB_1: 114.95694701144645
# MSE for XGB_2: 11.58440697550797
# MSE for XGB_3: 6.502355210123492
# MSE for XGB_4: 5.038341138467714
# RMSE for XGB_4: 2.244624943830865
# R2 for XGB_4: 0.9777520738211397
# EVS for XGB_4: 0.9777526186844587
# Local Model Results for Node شهرداری.منطقه10 - PM10 with Weighted Predictions:
# MSE for XGB_1: 209.89745771800366
# MSE for XGB_2: 14.346713591119059
# MSE for XGB_3: 7.329220511319283
# MSE for XGB_4: 5.4188838634466725
# RMSE for XGB_4: 2.3278496221720753
# R2 for XGB_4: 0.9839624970305927
# EVS for XGB_4: 0.9839624970538915
# Local Model Results for Node شهرداری.منطقه10 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 472.22308229895117
# MSE for XGB_2: 13.384605273372795
# MSE for XGB_3: 5.2150537385792
# MSE for XGB_4: 5.763185547988295
# RMSE for XGB_4: 2.4006635640981213
# R2 for XGB_4: 0.9949818227273843
# EVS for XGB_4: 0.9949823426722302
# Local Model Results for Node شهرداری.منطقه10 - AQI with Weighted Predictions:
# MSE for XGB_1: 501.85434352272233
# MSE for XGB_2: 15.488774086381039
# MSE for XGB_3: 5.6476426289030055
# MSE for XGB_4: 5.4431519554589585
# RMSE for XGB_4: 2.333056354968512
# R2 for XGB_4: 0.9958315512621154
# EVS for XGB_4: 0.995831613359756
# Local Model Results for Node شهرداری.منطقه10 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شهرداری.منطقه11 - CO with Weighted Predictions:
# MSE for XGB_1: 202.8699472211887
# MSE for XGB_2: 12.120377648338446
# MSE for XGB_3: 6.009773038642303
# MSE for XGB_4: 5.143877584145363
# RMSE for XGB_4: 2.2680118130524285
# R2 for XGB_4: 0.9857140006569409
# EVS for XGB_4: 0.9857140006572065
# Local Model Results for Node شهرداری.منطقه11 - O3 with Weighted Predictions:
# MSE for XGB_1: 809.0017039013652
# MSE for XGB_2: 13.721437984448677
# MSE for XGB_3: 6.557950848290242
# MSE for XGB_4: 5.977102903622855
# RMSE for XGB_4: 2.4448114249616175
# R2 for XGB_4: 0.996599714375167
# EVS for XGB_4: 0.9965997298950039
# Local Model Results for Node شهرداری.منطقه11 - NO2 with Weighted Predictions:
# MSE for XGB_1: 329.18504131605516
# MSE for XGB_2: 23.142222843985177
# MSE for XGB_3: 7.245417372657296
# MSE for XGB_4: 6.20503951720157
# RMSE for XGB_4: 2.490991673450871
# R2 for XGB_4: 0.9851431655628194
# EVS for XGB_4: 0.9851435588022668
# Local Model Results for Node شهرداری.منطقه11 - SO2 with Weighted Predictions:
# MSE for XGB_1: 21.44438709500929
# MSE for XGB_2: 7.060249326797546
# MSE for XGB_3: 3.994382746862618
# MSE for XGB_4: 3.5432322840441164
# RMSE for XGB_4: 1.882347546029722
# R2 for XGB_4: 0.8807236094769354
# EVS for XGB_4: 0.8807236793625106
# Local Model Results for Node شهرداری.منطقه11 - PM10 with Weighted Predictions:
# MSE for XGB_1: 209.57423326369096
# MSE for XGB_2: 15.588485465224565
# MSE for XGB_3: 7.601262093205857
# MSE for XGB_4: 5.6675525297607
# RMSE for XGB_4: 2.3806622040433836
# R2 for XGB_4: 0.9832522294616095
# EVS for XGB_4: 0.9832523885105073
# Local Model Results for Node شهرداری.منطقه11 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 485.51375885508537
# MSE for XGB_2: 18.58444562440197
# MSE for XGB_3: 8.571943569812847
# MSE for XGB_4: 6.75303234819008
# RMSE for XGB_4: 2.598659721508393
# R2 for XGB_4: 0.9944495691559763
# EVS for XGB_4: 0.9944495694802696
# Local Model Results for Node شهرداری.منطقه11 - AQI with Weighted Predictions:
# MSE for XGB_1: 840.2636824155155
# MSE for XGB_2: 18.605275141006782
# MSE for XGB_3: 6.947216098670504
# MSE for XGB_4: 7.580530811597978
# RMSE for XGB_4: 2.7532763776268405
# R2 for XGB_4: 0.9936034888385356
# EVS for XGB_4: 0.9936034930721919
# Local Model Results for Node شهرداری.منطقه11 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - CO with Weighted Predictions:
# MSE for XGB_1: 91.35696917157057
# MSE for XGB_2: 16.97213793661928
# MSE for XGB_3: 6.813781992254533
# MSE for XGB_4: 4.682668542864186
# RMSE for XGB_4: 2.1639474445707285
# R2 for XGB_4: 0.9478525183601084
# EVS for XGB_4: 0.9478525240159539
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - O3 with Weighted Predictions:
# MSE for XGB_1: 597.4401460484443
# MSE for XGB_2: 16.72135954005629
# MSE for XGB_3: 7.509955804121782
# MSE for XGB_4: 6.486817888563985
# RMSE for XGB_4: 2.5469232199978045
# R2 for XGB_4: 0.9937344183019675
# EVS for XGB_4: 0.9937344727242867
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - NO2 with Weighted Predictions:
# MSE for XGB_1: 488.60631166997484
# MSE for XGB_2: 19.748629050529228
# MSE for XGB_3: 7.754648320919376
# MSE for XGB_4: 5.033543175625212
# RMSE for XGB_4: 2.2435559221078516
# R2 for XGB_4: 0.9920863609863352
# EVS for XGB_4: 0.9920873525111554
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - SO2 with Weighted Predictions:
# MSE for XGB_1: 76.17112520722478
# MSE for XGB_2: 10.947009775939058
# MSE for XGB_3: 6.158513675255744
# MSE for XGB_4: 4.755008043166304
# RMSE for XGB_4: 2.180598092993366
# R2 for XGB_4: 0.9570397365149133
# EVS for XGB_4: 0.9570420968503467
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - PM10 with Weighted Predictions:
# MSE for XGB_1: 228.10707155956274
# MSE for XGB_2: 15.809229275884281
# MSE for XGB_3: 8.265705237253806
# MSE for XGB_4: 6.204859996704494
# RMSE for XGB_4: 2.4909556392486185
# R2 for XGB_4: 0.9825838940408205
# EVS for XGB_4: 0.982583894189376
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 1527.9284543520184
# MSE for XGB_2: 20.317051124892156
# MSE for XGB_3: 8.111777723046387
# MSE for XGB_4: 6.881668051007781
# RMSE for XGB_4: 2.6232933596926937
# R2 for XGB_4: 0.9939493325815468
# EVS for XGB_4: 0.9939494048376575
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - AQI with Weighted Predictions:
# MSE for XGB_1: 1832.649141928188
# MSE for XGB_2: 19.4042770676523
# MSE for XGB_3: 8.164853315350644
# MSE for XGB_4: 6.540819393879087
# RMSE for XGB_4: 2.5575025696720397
# R2 for XGB_4: 0.9941084377345473
# EVS for XGB_4: 0.9941084795328022
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node پیروزی.منطقه13 - CO with Weighted Predictions:
# MSE for XGB_1: 68.03141500723534
# MSE for XGB_2: 15.72526339105131
# MSE for XGB_3: 6.249100787880164
# MSE for XGB_4: 3.945241300674928
# RMSE for XGB_4: 1.9862631499061065
# R2 for XGB_4: 0.9589732367612901
# EVS for XGB_4: 0.9589741191586082
# Local Model Results for Node پیروزی.منطقه13 - O3 with Weighted Predictions:
# MSE for XGB_1: 593.3640576331894
# MSE for XGB_2: 10.830534407210342
# MSE for XGB_3: 4.941149341173151
# MSE for XGB_4: 4.706624797651715
# RMSE for XGB_4: 2.169475696487913
# R2 for XGB_4: 0.9968043472768425
# EVS for XGB_4: 0.9968043556043068
# Local Model Results for Node پیروزی.منطقه13 - NO2 with Weighted Predictions:
# MSE for XGB_1: 121.37058204553425
# MSE for XGB_2: 19.09298254496437
# MSE for XGB_3: 7.779536780077091
# MSE for XGB_4: 5.341634513026223
# RMSE for XGB_4: 2.311197636080961
# R2 for XGB_4: 0.9764798213074649
# EVS for XGB_4: 0.9764798222892198
# Local Model Results for Node پیروزی.منطقه13 - SO2 with Weighted Predictions:
# MSE for XGB_1: 82.38663379546256
# MSE for XGB_2: 9.702654659742349
# MSE for XGB_3: 5.523372021561446
# MSE for XGB_4: 4.14914930894727
# RMSE for XGB_4: 2.03694607413826
# R2 for XGB_4: 0.9634445865397496
# EVS for XGB_4: 0.9634445873794896
# Local Model Results for Node پیروزی.منطقه13 - PM10 with Weighted Predictions:
# MSE for XGB_1: 246.62034066102137
# MSE for XGB_2: 16.995257913946592
# MSE for XGB_3: 6.569127415171522
# MSE for XGB_4: 5.470370918405435
# RMSE for XGB_4: 2.3388824079900714
# R2 for XGB_4: 0.9846418229594706
# EVS for XGB_4: 0.9846418606697195
# Local Model Results for Node پیروزی.منطقه13 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 381.38563989944333
# MSE for XGB_2: 16.218123941037984
# MSE for XGB_3: 5.150938403079524
# MSE for XGB_4: 4.286465876833818
# RMSE for XGB_4: 2.0703781965703314
# R2 for XGB_4: 0.9953469881769679
# EVS for XGB_4: 0.995346994738086
# Local Model Results for Node پیروزی.منطقه13 - AQI with Weighted Predictions:
# MSE for XGB_1: 583.8649327003211
# MSE for XGB_2: 21.2363588053776
# MSE for XGB_3: 7.154997450119942
# MSE for XGB_4: 6.472403229080947
# RMSE for XGB_4: 2.5440918279576596
# R2 for XGB_4: 0.9945120682404153
# EVS for XGB_4: 0.9945121543481964
# Local Model Results for Node پیروزی.منطقه13 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - CO with Weighted Predictions:
# MSE for XGB_1: 107.20869093533248
# MSE for XGB_2: 14.915236080622957
# MSE for XGB_3: 7.44453209191216
# MSE for XGB_4: 4.917203280536272
# RMSE for XGB_4: 2.217476782411999
# R2 for XGB_4: 0.9385301051844819
# EVS for XGB_4: 0.93853562561405
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - O3 with Weighted Predictions:
# MSE for XGB_1: 258.84794240992386
# MSE for XGB_2: 11.591047706497232
# MSE for XGB_3: 5.7666668907639265
# MSE for XGB_4: 4.979245804988761
# RMSE for XGB_4: 2.2314223726109677
# R2 for XGB_4: 0.9939889633273834
# EVS for XGB_4: 0.9939889721608889
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - NO2 with Weighted Predictions:
# MSE for XGB_1: 106.09430723319596
# MSE for XGB_2: 18.22964393424522
# MSE for XGB_3: 7.966731169666619
# MSE for XGB_4: 5.456258706680316
# RMSE for XGB_4: 2.335863589056586
# R2 for XGB_4: 0.9878292646357619
# EVS for XGB_4: 0.9878293775860318
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - SO2 with Weighted Predictions:
# MSE for XGB_1: 118.12709203620648
# MSE for XGB_2: 14.624749044908416
# MSE for XGB_3: 5.432751058148378
# MSE for XGB_4: 4.371913139585146
# RMSE for XGB_4: 2.090912035353268
# R2 for XGB_4: 0.9800335981707258
# EVS for XGB_4: 0.9800341700251282
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - PM10 with Weighted Predictions:
# MSE for XGB_1: 250.20180350763326
# MSE for XGB_2: 18.883586890190003
# MSE for XGB_3: 8.530794859050962
# MSE for XGB_4: 5.476785597175203
# RMSE for XGB_4: 2.3402533190180934
# R2 for XGB_4: 0.9844397522739661
# EVS for XGB_4: 0.9844398049315132
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 599.2555570798366
# MSE for XGB_2: 19.86661319745614
# MSE for XGB_3: 7.7046169116421845
# MSE for XGB_4: 7.387087089409237
# RMSE for XGB_4: 2.717919625266582
# R2 for XGB_4: 0.9949703779635621
# EVS for XGB_4: 0.9949707139382074
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - AQI with Weighted Predictions:
# MSE for XGB_1: 368.5823779846767
# MSE for XGB_2: 20.545813868949896
# MSE for XGB_3: 8.328007655427243
# MSE for XGB_4: 6.505192252235182
# RMSE for XGB_4: 2.55052783796515
# R2 for XGB_4: 0.9883747617718063
# EVS for XGB_4: 0.9883748032920658
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node مسعودیه.منطقه15 - CO with Weighted Predictions:
# MSE for XGB_1: 68.08355854980405
# MSE for XGB_2: 13.668466621528296
# MSE for XGB_3: 7.054824822187565
# MSE for XGB_4: 4.990125830606416
# RMSE for XGB_4: 2.2338589549491292
# R2 for XGB_4: 0.9092889335932148
# EVS for XGB_4: 0.9092889848129161
# Local Model Results for Node مسعودیه.منطقه15 - O3 with Weighted Predictions:
# MSE for XGB_1: 346.7907849115225
# MSE for XGB_2: 15.252948684351752
# MSE for XGB_3: 7.699349593653576
# MSE for XGB_4: 5.4013748937699
# RMSE for XGB_4: 2.3240858189339524
# R2 for XGB_4: 0.9944936632405664
# EVS for XGB_4: 0.9944938841623817
# Local Model Results for Node مسعودیه.منطقه15 - NO2 with Weighted Predictions:
# MSE for XGB_1: 170.96067781608946
# MSE for XGB_2: 20.963361965144863
# MSE for XGB_3: 8.678662712286695
# MSE for XGB_4: 6.2953272860977405
# RMSE for XGB_4: 2.5090490800495995
# R2 for XGB_4: 0.9791833290758457
# EVS for XGB_4: 0.979183490851042
# Local Model Results for Node مسعودیه.منطقه15 - SO2 with Weighted Predictions:
# MSE for XGB_1: 148.42877442705293
# MSE for XGB_2: 12.983657280542072
# MSE for XGB_3: 5.167855696183219
# MSE for XGB_4: 4.30070099881585
# RMSE for XGB_4: 2.073813154268207
# R2 for XGB_4: 0.983214527721282
# EVS for XGB_4: 0.9832147877697235
# Local Model Results for Node مسعودیه.منطقه15 - PM10 with Weighted Predictions:
# MSE for XGB_1: 211.37972847135663
# MSE for XGB_2: 13.220480142554678
# MSE for XGB_3: 6.827651015671551
# MSE for XGB_4: 4.478952071140975
# RMSE for XGB_4: 2.1163534844493666
# R2 for XGB_4: 0.9877555440682994
# EVS for XGB_4: 0.9877556062453463
# Local Model Results for Node مسعودیه.منطقه15 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 346.74408267360013
# MSE for XGB_2: 14.863400834559098
# MSE for XGB_3: 6.851152085514328
# MSE for XGB_4: 5.738116184763143
# RMSE for XGB_4: 2.3954365332363
# R2 for XGB_4: 0.9912255069332375
# EVS for XGB_4: 0.9912255355278324
# Local Model Results for Node مسعودیه.منطقه15 - AQI with Weighted Predictions:
# MSE for XGB_1: 286.1526889048941
# MSE for XGB_2: 15.587669854052168
# MSE for XGB_3: 6.192225385072045
# MSE for XGB_4: 5.048805667106118
# RMSE for XGB_4: 2.2469547541297126
# R2 for XGB_4: 0.9912690143293708
# EVS for XGB_4: 0.9912690346071605
# Local Model Results for Node مسعودیه.منطقه15 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شهرداری.منطقه16 - CO with Weighted Predictions:
# MSE for XGB_1: 61.11416313750668
# MSE for XGB_2: 15.812150223810624
# MSE for XGB_3: 7.851164034616025
# MSE for XGB_4: 5.00473812208202
# RMSE for XGB_4: 2.2371272029283493
# R2 for XGB_4: 0.9446247969386814
# EVS for XGB_4: 0.9446250466689745
# Local Model Results for Node شهرداری.منطقه16 - O3 with Weighted Predictions:
# MSE for XGB_1: 338.742967721818
# MSE for XGB_2: 12.753651191936074
# MSE for XGB_3: 6.515359246136203
# MSE for XGB_4: 5.4223755831061125
# RMSE for XGB_4: 2.3285994896302182
# R2 for XGB_4: 0.994528785762146
# EVS for XGB_4: 0.9945288586520546
# Local Model Results for Node شهرداری.منطقه16 - NO2 with Weighted Predictions:
# MSE for XGB_1: 126.11718323763105
# MSE for XGB_2: 14.698471699960987
# MSE for XGB_3: 6.733234466219872
# MSE for XGB_4: 4.5831931989334205
# RMSE for XGB_4: 2.140839367849307
# R2 for XGB_4: 0.9773425521597388
# EVS for XGB_4: 0.9773428028247857
# Local Model Results for Node شهرداری.منطقه16 - SO2 with Weighted Predictions:
# MSE for XGB_1: 61.20944313419761
# MSE for XGB_2: 11.182580879575852
# MSE for XGB_3: 6.13137505341848
# MSE for XGB_4: 4.65804087806694
# RMSE for XGB_4: 2.158249493934133
# R2 for XGB_4: 0.9722143653398504
# EVS for XGB_4: 0.9722181959333311
# Local Model Results for Node شهرداری.منطقه16 - PM10 with Weighted Predictions:
# MSE for XGB_1: 181.30575857460897
# MSE for XGB_2: 11.66778179293959
# MSE for XGB_3: 4.609188816762908
# MSE for XGB_4: 4.062821820823331
# RMSE for XGB_4: 2.0156442694144547
# R2 for XGB_4: 0.9884571962319993
# EVS for XGB_4: 0.9884572060484276
# Local Model Results for Node شهرداری.منطقه16 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 315.7543324418148
# MSE for XGB_2: 13.64428500850859
# MSE for XGB_3: 5.8665937769741365
# MSE for XGB_4: 5.2834905598688495
# RMSE for XGB_4: 2.2985844687261006
# R2 for XGB_4: 0.9936095920680983
# EVS for XGB_4: 0.9936096015798181
# Local Model Results for Node شهرداری.منطقه16 - AQI with Weighted Predictions:
# MSE for XGB_1: 194.28012604198935
# MSE for XGB_2: 15.720390859851674
# MSE for XGB_3: 4.08465888021131
# MSE for XGB_4: 3.542723005972068
# RMSE for XGB_4: 1.8822122637928136
# R2 for XGB_4: 0.9952598972481359
# EVS for XGB_4: 0.9952600058467058
# Local Model Results for Node شهرداری.منطقه16 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node پارک.سلامت.منطقه17 - CO with Weighted Predictions:
# MSE for XGB_1: 104.95407966002121
# MSE for XGB_2: 15.728151670911517
# MSE for XGB_3: 6.496811147048354
# MSE for XGB_4: 4.091778510445411
# RMSE for XGB_4: 2.0228145022333144
# R2 for XGB_4: 0.9657752045922741
# EVS for XGB_4: 0.9657753456748664
# Local Model Results for Node پارک.سلامت.منطقه17 - O3 with Weighted Predictions:
# MSE for XGB_1: 338.7056316300805
# MSE for XGB_2: 12.737106068596383
# MSE for XGB_3: 6.622752363457785
# MSE for XGB_4: 5.889766211530722
# RMSE for XGB_4: 2.426884053994076
# R2 for XGB_4: 0.9940559988316092
# EVS for XGB_4: 0.9940560663176651
# Local Model Results for Node پارک.سلامت.منطقه17 - NO2 with Weighted Predictions:
# MSE for XGB_1: 335.629017563368
# MSE for XGB_2: 16.549738232832045
# MSE for XGB_3: 5.036261410916272
# MSE for XGB_4: 4.155430603458112
# RMSE for XGB_4: 2.0384873321799457
# R2 for XGB_4: 0.9922638468870602
# EVS for XGB_4: 0.9922638952983857
# Local Model Results for Node پارک.سلامت.منطقه17 - SO2 with Weighted Predictions:
# MSE for XGB_1: 523.8976731747
# MSE for XGB_2: 18.55763474753813
# MSE for XGB_3: 6.253270548541909
# MSE for XGB_4: 5.419619610735852
# RMSE for XGB_4: 2.328007648341356
# R2 for XGB_4: 0.9969634728402678
# EVS for XGB_4: 0.9969635446779259
# Local Model Results for Node پارک.سلامت.منطقه17 - PM10 with Weighted Predictions:
# MSE for XGB_1: 216.71340125553533
# MSE for XGB_2: 15.619444853955628
# MSE for XGB_3: 7.845882519440638
# MSE for XGB_4: 5.8235598366142955
# RMSE for XGB_4: 2.4132053034531262
# R2 for XGB_4: 0.9832905071219078
# EVS for XGB_4: 0.9832905326695675
# Local Model Results for Node پارک.سلامت.منطقه17 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 494.9846457987411
# MSE for XGB_2: 21.66154854084034
# MSE for XGB_3: 6.5247934416704085
# MSE for XGB_4: 5.081194560243653
# RMSE for XGB_4: 2.2541505185421076
# R2 for XGB_4: 0.9953073437039605
# EVS for XGB_4: 0.9953073496938383
# Local Model Results for Node پارک.سلامت.منطقه17 - AQI with Weighted Predictions:
# MSE for XGB_1: 555.8382153671664
# MSE for XGB_2: 21.188489209611806
# MSE for XGB_3: 5.9079225429815745
# MSE for XGB_4: 4.627809545946091
# RMSE for XGB_4: 2.1512344237544383
# R2 for XGB_4: 0.9949812553079314
# EVS for XGB_4: 0.9949812744013068
# Local Model Results for Node پارک.سلامت.منطقه17 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شادآباد.منطقه18 - CO with Weighted Predictions:
# MSE for XGB_1: 277.88278722411764
# MSE for XGB_2: 19.890126824721982
# MSE for XGB_3: 6.146311172104787
# MSE for XGB_4: 3.989410321804725
# RMSE for XGB_4: 1.9973508259203552
# R2 for XGB_4: 0.9894334784714994
# EVS for XGB_4: 0.9894334790855166
# Local Model Results for Node شادآباد.منطقه18 - O3 with Weighted Predictions:
# MSE for XGB_1: 723.6805881282987
# MSE for XGB_2: 15.701941407804696
# MSE for XGB_3: 6.762461387016641
# MSE for XGB_4: 5.931580223854318
# RMSE for XGB_4: 2.4354835708446725
# R2 for XGB_4: 0.9967473489603965
# EVS for XGB_4: 0.9967476203663553
# Local Model Results for Node شادآباد.منطقه18 - NO2 with Weighted Predictions:
# MSE for XGB_1: 268.6376787709947
# MSE for XGB_2: 17.160775941222717
# MSE for XGB_3: 7.956133358229181
# MSE for XGB_4: 5.815907684390107
# RMSE for XGB_4: 2.4116193075172765
# R2 for XGB_4: 0.988991079826006
# EVS for XGB_4: 0.9889914278655035
# Local Model Results for Node شادآباد.منطقه18 - SO2 with Weighted Predictions:
# MSE for XGB_1: 262.7484188768898
# MSE for XGB_2: 17.68015718965883
# MSE for XGB_3: 6.88793879159195
# MSE for XGB_4: 4.4901794527954
# RMSE for XGB_4: 2.1190043541237475
# R2 for XGB_4: 0.9922434635858178
# EVS for XGB_4: 0.9922435025264634
# Local Model Results for Node شادآباد.منطقه18 - PM10 with Weighted Predictions:
# MSE for XGB_1: 270.50215832583507
# MSE for XGB_2: 15.311495132269224
# MSE for XGB_3: 8.725749139135596
# MSE for XGB_4: 7.1856847021557435
# RMSE for XGB_4: 2.680612747517952
# R2 for XGB_4: 0.9837751768936281
# EVS for XGB_4: 0.9837751938977793
# Local Model Results for Node شادآباد.منطقه18 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 502.90657040103895
# MSE for XGB_2: 14.771512838448775
# MSE for XGB_3: 5.963822194454144
# MSE for XGB_4: 5.830035421750192
# RMSE for XGB_4: 2.414546628613784
# R2 for XGB_4: 0.9943878492976834
# EVS for XGB_4: 0.9943878552305035
# Local Model Results for Node شادآباد.منطقه18 - AQI with Weighted Predictions:
# MSE for XGB_1: 815.3030798808616
# MSE for XGB_2: 27.604292857956924
# MSE for XGB_3: 8.186133598060218
# MSE for XGB_4: 7.762865463943915
# RMSE for XGB_4: 2.7861919287701475
# R2 for XGB_4: 0.9925898923055545
# EVS for XGB_4: 0.9925898962855583
# Local Model Results for Node شادآباد.منطقه18 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شهرداری.منطقه19 - CO with Weighted Predictions:
# MSE for XGB_1: 283.4159177139947
# MSE for XGB_2: 17.158233422604553
# MSE for XGB_3: 5.825112397661569
# MSE for XGB_4: 4.5580076175351785
# RMSE for XGB_4: 2.134949090150671
# R2 for XGB_4: 0.981423266988728
# EVS for XGB_4: 0.9814248215987211
# Local Model Results for Node شهرداری.منطقه19 - O3 with Weighted Predictions:
# MSE for XGB_1: 361.76983869187967
# MSE for XGB_2: 14.38042250779869
# MSE for XGB_3: 4.91553189396789
# MSE for XGB_4: 4.1519496311274935
# RMSE for XGB_4: 2.037633340698835
# R2 for XGB_4: 0.9962543578108309
# EVS for XGB_4: 0.9962543664289478
# Local Model Results for Node شهرداری.منطقه19 - NO2 with Weighted Predictions:
# MSE for XGB_1: 146.27083521688652
# MSE for XGB_2: 13.096425873930894
# MSE for XGB_3: 7.064162785087961
# MSE for XGB_4: 5.941255566926333
# RMSE for XGB_4: 2.437469090455576
# R2 for XGB_4: 0.9797347719294619
# EVS for XGB_4: 0.9797347910439673
# Local Model Results for Node شهرداری.منطقه19 - SO2 with Weighted Predictions:
# MSE for XGB_1: 82.39166943867212
# MSE for XGB_2: 21.913552308820556
# MSE for XGB_3: 7.399867764197684
# MSE for XGB_4: 4.342402677230151
# RMSE for XGB_4: 2.0838432467990846
# R2 for XGB_4: 0.9716919349778868
# EVS for XGB_4: 0.9716919476337001
# Local Model Results for Node شهرداری.منطقه19 - PM10 with Weighted Predictions:
# MSE for XGB_1: 614.1173547396775
# MSE for XGB_2: 18.965245594499383
# MSE for XGB_3: 8.5337467788374
# MSE for XGB_4: 7.486632646636533
# RMSE for XGB_4: 2.7361711654493646
# R2 for XGB_4: 0.9926174203542546
# EVS for XGB_4: 0.9926174203836305
# Local Model Results for Node شهرداری.منطقه19 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 591.4402058531299
# MSE for XGB_2: 18.797814598596435
# MSE for XGB_3: 6.576704717370192
# MSE for XGB_4: 6.9070478276505725
# RMSE for XGB_4: 2.6281262959855205
# R2 for XGB_4: 0.9948740212280665
# EVS for XGB_4: 0.9948740222975379
# Local Model Results for Node شهرداری.منطقه19 - AQI with Weighted Predictions:
# MSE for XGB_1: 672.6038790402123
# MSE for XGB_2: 26.660726069440805
# MSE for XGB_3: 8.642092250458093
# MSE for XGB_4: 6.93772444898014
# RMSE for XGB_4: 2.633956045377398
# R2 for XGB_4: 0.9949149409137353
# EVS for XGB_4: 0.9949149831008786
# Local Model Results for Node شهرداری.منطقه19 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شهر.ری.منطقه20 - CO with Weighted Predictions:
# MSE for XGB_1: 392.24188721374884
# MSE for XGB_2: 18.982308659229354
# MSE for XGB_3: 6.655681424430677
# MSE for XGB_4: 5.529809828007223
# RMSE for XGB_4: 2.351554768234672
# R2 for XGB_4: 0.9816857663036086
# EVS for XGB_4: 0.9816862314657803
# Local Model Results for Node شهر.ری.منطقه20 - O3 with Weighted Predictions:
# MSE for XGB_1: 247.09856082670592
# MSE for XGB_2: 12.440226335026031
# MSE for XGB_3: 5.810357980694824
# MSE for XGB_4: 5.223688222506988
# RMSE for XGB_4: 2.285538934804434
# R2 for XGB_4: 0.9904934916958646
# EVS for XGB_4: 0.9904935259302209
# Local Model Results for Node شهر.ری.منطقه20 - NO2 with Weighted Predictions:
# MSE for XGB_1: 187.72475739699337
# MSE for XGB_2: 24.777250474187547
# MSE for XGB_3: 10.672288907512009
# MSE for XGB_4: 6.86710333252145
# RMSE for XGB_4: 2.6205158523698056
# R2 for XGB_4: 0.9782974994184952
# EVS for XGB_4: 0.9782974998107744
# Local Model Results for Node شهر.ری.منطقه20 - SO2 with Weighted Predictions:
# MSE for XGB_1: 247.47382789099694
# MSE for XGB_2: 16.989272967904895
# MSE for XGB_3: 6.436218732478296
# MSE for XGB_4: 5.089991556497156
# RMSE for XGB_4: 2.2561009632765012
# R2 for XGB_4: 0.989741440366688
# EVS for XGB_4: 0.98974150829025
# Local Model Results for Node شهر.ری.منطقه20 - PM10 with Weighted Predictions:
# MSE for XGB_1: 245.16441123708216
# MSE for XGB_2: 15.862230921131191
# MSE for XGB_3: 7.799897703936315
# MSE for XGB_4: 5.756108329996377
# RMSE for XGB_4: 2.3991890984239608
# R2 for XGB_4: 0.9872358853090089
# EVS for XGB_4: 0.9872365250230726
# Local Model Results for Node شهر.ری.منطقه20 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 381.45994663142795
# MSE for XGB_2: 23.204862938427866
# MSE for XGB_3: 8.428958627693989
# MSE for XGB_4: 5.899379715900968
# RMSE for XGB_4: 2.4288638734809673
# R2 for XGB_4: 0.9935344241515421
# EVS for XGB_4: 0.993534440985562
# Local Model Results for Node شهر.ری.منطقه20 - AQI with Weighted Predictions:
# MSE for XGB_1: 397.62774004449534
# MSE for XGB_2: 20.210553745739507
# MSE for XGB_3: 6.080126512246482
# MSE for XGB_4: 5.488489480356432
# RMSE for XGB_4: 2.342752543559911
# R2 for XGB_4: 0.9928008467563049
# EVS for XGB_4: 0.9928009209685642
# Local Model Results for Node شهر.ری.منطقه20 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شهرداری.منطقه21 - CO with Weighted Predictions:
# MSE for XGB_1: 144.2378990880317
# MSE for XGB_2: 11.920133745255667
# MSE for XGB_3: 4.972601415525449
# MSE for XGB_4: 4.18319863095252
# RMSE for XGB_4: 2.045286931203669
# R2 for XGB_4: 0.9795656895052957
# EVS for XGB_4: 0.9795678959462086
# Local Model Results for Node شهرداری.منطقه21 - O3 with Weighted Predictions:
# MSE for XGB_1: 399.11128694364106
# MSE for XGB_2: 21.949149444402234
# MSE for XGB_3: 8.061949977920818
# MSE for XGB_4: 5.919875350881003
# RMSE for XGB_4: 2.433079396748286
# R2 for XGB_4: 0.9933578842695389
# EVS for XGB_4: 0.9933579004443772
# Local Model Results for Node شهرداری.منطقه21 - NO2 with Weighted Predictions:
# MSE for XGB_1: 263.6271557270634
# MSE for XGB_2: 18.51767060276576
# MSE for XGB_3: 6.398639153402514
# MSE for XGB_4: 5.120052816822617
# RMSE for XGB_4: 2.262753370746051
# R2 for XGB_4: 0.9824279948696865
# EVS for XGB_4: 0.982428033633957
# Local Model Results for Node شهرداری.منطقه21 - SO2 with Weighted Predictions:
# MSE for XGB_1: 258.2489384701646
# MSE for XGB_2: 21.079377701719885
# MSE for XGB_3: 7.56905214985814
# MSE for XGB_4: 5.080909694860467
# RMSE for XGB_4: 2.254087330797205
# R2 for XGB_4: 0.9900443536396581
# EVS for XGB_4: 0.9900448479235341
# Local Model Results for Node شهرداری.منطقه21 - PM10 with Weighted Predictions:
# MSE for XGB_1: 426.04603697285074
# MSE for XGB_2: 16.512652170597114
# MSE for XGB_3: 6.595201900135592
# MSE for XGB_4: 5.004456533245876
# RMSE for XGB_4: 2.2370642666776197
# R2 for XGB_4: 0.9933745511390314
# EVS for XGB_4: 0.9933746818795575
# Local Model Results for Node شهرداری.منطقه21 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 359.4677801224423
# MSE for XGB_2: 16.722204878365996
# MSE for XGB_3: 7.132929117686385
# MSE for XGB_4: 5.782327160642602
# RMSE for XGB_4: 2.404646992937342
# R2 for XGB_4: 0.9941932406862168
# EVS for XGB_4: 0.9941932412954306
# Local Model Results for Node شهرداری.منطقه21 - AQI with Weighted Predictions:
# MSE for XGB_1: 603.3743586407987
# MSE for XGB_2: 22.705230269138262
# MSE for XGB_3: 7.663843323715772
# MSE for XGB_4: 6.588825946114598
# RMSE for XGB_4: 2.5668708471823427
# R2 for XGB_4: 0.9945497679980903
# EVS for XGB_4: 0.994549778334776
# Local Model Results for Node شهرداری.منطقه21 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# Local Model Results for Node شهرداری.منطقه22 - CO with Weighted Predictions:
# MSE for XGB_1: 90.18013554174071
# MSE for XGB_2: 16.054773724902546
# MSE for XGB_3: 7.243864082555639
# MSE for XGB_4: 5.600795837831893
# RMSE for XGB_4: 2.366600058698532
# R2 for XGB_4: 0.9611334485928644
# EVS for XGB_4: 0.9611335804740108
# Local Model Results for Node شهرداری.منطقه22 - O3 with Weighted Predictions:
# MSE for XGB_1: 338.742967721818
# MSE for XGB_2: 12.753651191936074
# MSE for XGB_3: 6.515359246136203
# MSE for XGB_4: 5.4223755831061125
# RMSE for XGB_4: 2.3285994896302182
# R2 for XGB_4: 0.994528785762146
# EVS for XGB_4: 0.9945288586520546
# Local Model Results for Node شهرداری.منطقه22 - NO2 with Weighted Predictions:
# MSE for XGB_1: 255.26155430326205
# MSE for XGB_2: 18.74073558603551
# MSE for XGB_3: 7.776263381376928
# MSE for XGB_4: 6.654162457973635
# RMSE for XGB_4: 2.5795663313769692
# R2 for XGB_4: 0.9788011135087562
# EVS for XGB_4: 0.9788011532134564
# Local Model Results for Node شهرداری.منطقه22 - SO2 with Weighted Predictions:
# MSE for XGB_1: 146.6407691691523
# MSE for XGB_2: 11.685785116247287
# MSE for XGB_3: 5.882846477599272
# MSE for XGB_4: 4.56005250881724
# RMSE for XGB_4: 2.135427945124171
# R2 for XGB_4: 0.9837765676239597
# EVS for XGB_4: 0.9837766678390076
# Local Model Results for Node شهرداری.منطقه22 - PM10 with Weighted Predictions:
# MSE for XGB_1: 218.59470240536197
# MSE for XGB_2: 14.832623803559196
# MSE for XGB_3: 5.89949136923321
# MSE for XGB_4: 4.51216464991933
# RMSE for XGB_4: 2.1241856439396556
# R2 for XGB_4: 0.9854969280810104
# EVS for XGB_4: 0.9854973115542629
# Local Model Results for Node شهرداری.منطقه22 - PM2.5 with Weighted Predictions:
# MSE for XGB_1: 338.081513032436
# MSE for XGB_2: 16.01586432507373
# MSE for XGB_3: 6.295474844633491
# MSE for XGB_4: 5.665570071359254
# RMSE for XGB_4: 2.3802458006179226
# R2 for XGB_4: 0.9934559163411979
# EVS for XGB_4: 0.9934559248121383
# Local Model Results for Node شهرداری.منطقه22 - AQI with Weighted Predictions:
# MSE for XGB_1: 352.12774440969855
# MSE for XGB_2: 13.714631234575103
# MSE for XGB_3: 6.079761187497186
# MSE for XGB_4: 5.508537596574004
# RMSE for XGB_4: 2.34702739578685
# R2 for XGB_4: 0.9920679461981078
# EVS for XGB_4: 0.9920680379042577
# Local Model Results for Node شهرداری.منطقه22 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for XGB_1: 3.481322377869096
# MSE for XGB_2: 2.4411617983121325
# MSE for XGB_3: 1.8829497745849169
# MSE for XGB_4: 1.7546617498031734
# RMSE for XGB_4: 1.3246364594873468
# R2 for XGB_4: 0.9853152467570574
# EVS for XGB_4: 0.9853162849130706
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Global Model Results:
# Mean Squared Error (MSE) for Global Model: 1.3866003143517984
# Duration of the program execution: 42.953099966049194 seconds
