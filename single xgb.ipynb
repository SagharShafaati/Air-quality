# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb  # Import XGBoost
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import xgboost as xgb
import time

# Record the start time
start_time = time.time()

# Read data from Excel file
file_path = ''

df = pd.read_excel(file_path)

# Convert 'iranidate' to datetime and drop rows with invalid dates
df['iranidate'] = pd.to_datetime(df['iranidate'], errors='coerce')
df = df.dropna(subset=['iranidate'])

# Function to convert date values to numeric representation
def convert_to_numeric_date(date):
    base_date = datetime(2000, 1, 1)
    return (date - base_date).days

df['iranidate'] = df['iranidate'].apply(convert_to_numeric_date)

# Encode 'node' column
label_encoder = LabelEncoder()
df['node_encoded'] = label_encoder.fit_transform(df['node'])

# Handling NaN values by finding the nearest non-empty cells in the same column
for col in ['CO', 'O3', 'SO2', 'PM10', 'PM2.5', 'AQI']:
    for idx, value in df[col].items():
        if pd.isnull(value):  # Check for NaN values
            upper_cell = df[col].iloc[:idx].last_valid_index()  # Find the first non-empty cell above
            lower_cell = df[col].iloc[idx + 1:].first_valid_index()  # Find the first non-empty cell below
            if upper_cell is not None and lower_cell is not None:  # If both upper and lower cells are found
                avg = (df.at[upper_cell, col] + df.at[lower_cell, col]) / 2  # Calculate the average
                df.at[idx, col] = avg  # Fill the empty cell with the average


# Check sample threshold
your_threshold_value = 100
if len(df) < your_threshold_value:
    print("Insufficient samples in the dataset.")
else:
    output_columns = ['CO', 'O3', 'NO2', 'SO2', 'PM10', 'PM2.5', 'AQI', 'Highest tempreture: 12pm', 'Wind:km/h']
    unique_nodes = df['node'].unique()

    
    for node_value in unique_nodes:
        node_df = df[df['node'] == node_value]
        for output_column in output_columns:
            if node_df[output_column].isnull().any():
                print(f"NaN values found in {output_column} for Node {node_value}. Handle missing values before modeling.")
            else:
                X = node_df[['iranidate', 'node_encoded']]
                Y = node_df[[output_column]]
                X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

                scaler = StandardScaler()
                X_train_scaled = scaler.fit_transform(X_train)
                X_test_scaled = scaler.transform(X_test)

                # Use XGBoost model instead of LSTM
                model = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                                         max_depth = 5, alpha = 10, n_estimators = 100)

                model.fit(X_train_scaled, Y_train.values.ravel())  # Fit XGBoost model

                Y_pred = model.predict(X_test_scaled)
                Y_pred = np.clip(Y_pred, a_min=0, a_max=None)

                mse = mean_squared_error(Y_test, Y_pred)
                rmse = np.sqrt(mse)
                r2 = r2_score(Y_test, Y_pred)
                evs = explained_variance_score(Y_test, Y_pred)

                print(f"For Node {node_value} and output column {output_column}:")
                print(f"Mean Squared Error (MSE): {mse}") 
                print(f"Root Mean Squared Error (RMSE): {rmse}")
                print(f"R-squared Score: {r2}")
                print(f"Explained Variance Score: {evs}")

                # Record the end time
end_time = time.time()

# Calculate the duration of the program execution
duration_seconds = end_time - start_time

# Print the duration of the program execution
print(f"Duration of the program execution: {duration_seconds} seconds")
# Out:
# 2024-02-20 21:15:06.116839: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# For Node اقدسیه.منطقه1 and output column CO:
# Mean Squared Error (MSE): 52.2541058549973
# Root Mean Squared Error (RMSE): 7.228700149750113
# R-squared Score: 0.353086761503526
# Explained Variance Score: 0.35316849303861186
# For Node اقدسیه.منطقه1 and output column O3:
# Mean Squared Error (MSE): 337.4835357256914
# Root Mean Squared Error (RMSE): 18.370724964619427
# R-squared Score: 0.7235773886747228
# Explained Variance Score: 0.7257126126431405
# For Node اقدسیه.منطقه1 and output column NO2:
# Mean Squared Error (MSE): 444.4083255603937
# Root Mean Squared Error (RMSE): 21.080994415833274
# R-squared Score: 0.26873131690692065
# Explained Variance Score: 0.275142838929904
# For Node اقدسیه.منطقه1 and output column SO2:
# Mean Squared Error (MSE): 46.29400070561974
# Root Mean Squared Error (RMSE): 6.803969481532066
# R-squared Score: 0.373595845478783
# Explained Variance Score: 0.38638797509246403
# For Node اقدسیه.منطقه1 and output column PM10:
# Mean Squared Error (MSE): 133.61824715387297
# Root Mean Squared Error (RMSE): 11.559335930488091
# R-squared Score: 0.4065524400025221
# Explained Variance Score: 0.40709135104975935
# For Node اقدسیه.منطقه1 and output column PM2.5:
# Mean Squared Error (MSE): 382.2537478921528
# Root Mean Squared Error (RMSE): 19.551310643845664
# R-squared Score: 0.5299989900447897
# Explained Variance Score: 0.5302649470154444
# For Node اقدسیه.منطقه1 and output column AQI:
# Mean Squared Error (MSE): 537.7630985502299
# Root Mean Squared Error (RMSE): 23.189719673817315
# R-squared Score: 0.27055004938853455
# Explained Variance Score: 0.29288823353340665
# For Node اقدسیه.منطقه1 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node اقدسیه.منطقه1 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شریف.منطقه2 and output column CO:
# Mean Squared Error (MSE): 206.2997846735461
# Root Mean Squared Error (RMSE): 14.363139791617503
# R-squared Score: -0.23507954824696253
# Explained Variance Score: -0.20906437449813486
# For Node شریف.منطقه2 and output column O3:
# Mean Squared Error (MSE): 148.88872795904345
# Root Mean Squared Error (RMSE): 12.201996884077763
# R-squared Score: 0.7169190149783526
# Explained Variance Score: 0.7182188320996111
# For Node شریف.منطقه2 and output column NO2:
# Mean Squared Error (MSE): 180.21848269129515
# Root Mean Squared Error (RMSE): 13.42454776487071
# R-squared Score: 0.6565495327627239
# Explained Variance Score: 0.6566067935679698
# For Node شریف.منطقه2 and output column SO2:
# Mean Squared Error (MSE): 132.70518033954795
# Root Mean Squared Error (RMSE): 11.519773450009682
# R-squared Score: 0.3152442955779631
# Explained Variance Score: 0.329793422423452
# For Node شریف.منطقه2 and output column PM10:
# Mean Squared Error (MSE): 378.65733543891207
# Root Mean Squared Error (RMSE): 19.459119595678324
# R-squared Score: 0.37744486809017797
# Explained Variance Score: 0.37956232052489924
# For Node شریف.منطقه2 and output column PM2.5:
# Mean Squared Error (MSE): 474.739434692012
# Root Mean Squared Error (RMSE): 21.788516119552796
# R-squared Score: 0.3901832625606473
# Explained Variance Score: 0.39059359374543556
# For Node شریف.منطقه2 and output column AQI:
# Mean Squared Error (MSE): 462.41748416680934
# Root Mean Squared Error (RMSE): 21.50389462787635
# R-squared Score: 0.47495617859020434
# Explained Variance Score: 0.47497278150864497
# For Node شریف.منطقه2 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شریف.منطقه2 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node پاسداران.منطقه3 and output column CO:
# Mean Squared Error (MSE): 60.40690991809444
# Root Mean Squared Error (RMSE): 7.7721882322866085
# R-squared Score: 0.3265485823289267
# Explained Variance Score: 0.32655683160893
# For Node پاسداران.منطقه3 and output column O3:
# Mean Squared Error (MSE): 274.48914833760193
# Root Mean Squared Error (RMSE): 16.567714034760556
# R-squared Score: 0.7251029370609428
# Explained Variance Score: 0.7265870714263727
# For Node پاسداران.منطقه3 and output column NO2:
# Mean Squared Error (MSE): 121.28713787443986
# Root Mean Squared Error (RMSE): 11.013043987673884
# R-squared Score: 0.3720357767476302
# Explained Variance Score: 0.37204833751990984
# For Node پاسداران.منطقه3 and output column SO2:
# Mean Squared Error (MSE): 61.20464757823452
# Root Mean Squared Error (RMSE): 7.823339924753015
# R-squared Score: 0.6299781110935893
# Explained Variance Score: 0.6425211731225572
# For Node پاسداران.منطقه3 and output column PM10:
# Mean Squared Error (MSE): 133.61824715387297
# Root Mean Squared Error (RMSE): 11.559335930488091
# R-squared Score: 0.4065524400025221
# Explained Variance Score: 0.40709135104975935
# For Node پاسداران.منطقه3 and output column PM2.5:
# Mean Squared Error (MSE): 420.0396553755279
# Root Mean Squared Error (RMSE): 20.494869001179975
# R-squared Score: 0.4731051443076284
# Explained Variance Score: 0.4741088678767471
# For Node پاسداران.منطقه3 and output column AQI:
# Mean Squared Error (MSE): 361.37976047901685
# Root Mean Squared Error (RMSE): 19.00999106993522
# R-squared Score: 0.46767182317543143
# Explained Variance Score: 0.4678914437150593
# For Node پاسداران.منطقه3 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node پاسداران.منطقه3 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column CO:
# Mean Squared Error (MSE): 93.54023804712597
# Root Mean Squared Error (RMSE): 9.671620238984055
# R-squared Score: 0.3785758277481055
# Explained Variance Score: 0.39367001580255034
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column O3:
# Mean Squared Error (MSE): 188.14109886304558
# Root Mean Squared Error (RMSE): 13.716453581849995
# R-squared Score: 0.6267450464530948
# Explained Variance Score: 0.6271554723255899
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column NO2:
# Mean Squared Error (MSE): 544.3673967849838
# Root Mean Squared Error (RMSE): 23.331682253643518
# R-squared Score: 0.17073321104444517
# Explained Variance Score: 0.19423580506893767
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column SO2:
# Mean Squared Error (MSE): 30.17821550396598
# Root Mean Squared Error (RMSE): 5.493470260588109
# R-squared Score: 0.4720818186808752
# Explained Variance Score: 0.48704819499509133
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column PM10:
# Mean Squared Error (MSE): 199.70469876727353
# Root Mean Squared Error (RMSE): 14.13169129181902
# R-squared Score: 0.412734041875501
# Explained Variance Score: 0.41415162826887975
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column PM2.5:
# Mean Squared Error (MSE): 654.4065383477948
# Root Mean Squared Error (RMSE): 25.581370923932024
# R-squared Score: 0.5558718958504258
# Explained Variance Score: 0.5561079446204794
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column AQI:
# Mean Squared Error (MSE): 647.0255888787502
# Root Mean Squared Error (RMSE): 25.436697680295495
# R-squared Score: 0.5516585244451282
# Explained Variance Score: 0.5528066162883851
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node دانشگاه.علم.وصنعت.منطقه4 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node پونک and output column CO:
# Mean Squared Error (MSE): 74.9985194043365
# Root Mean Squared Error (RMSE): 8.660168555192012
# R-squared Score: 0.41960869788382826
# Explained Variance Score: 0.42322485547366884
# For Node پونک and output column O3:
# Mean Squared Error (MSE): 130.81976869374267
# Root Mean Squared Error (RMSE): 11.43764699113164
# R-squared Score: 0.658816202783694
# Explained Variance Score: 0.6693416894826827
# For Node پونک and output column NO2:
# Mean Squared Error (MSE): 167.397447489632
# Root Mean Squared Error (RMSE): 12.93821654980438
# R-squared Score: 0.4427354730700499
# Explained Variance Score: 0.44486485023736877
# For Node پونک and output column SO2:
# Mean Squared Error (MSE): 144.17013407759924
# Root Mean Squared Error (RMSE): 12.007086827269937
# R-squared Score: 0.5040407186265352
# Explained Variance Score: 0.5258051211200991
# For Node پونک and output column PM10:
# Mean Squared Error (MSE): 148.81486109973565
# Root Mean Squared Error (RMSE): 12.198969673695219
# R-squared Score: 0.41377504307033075
# Explained Variance Score: 0.4209995544331271
# For Node پونک and output column PM2.5:
# Mean Squared Error (MSE): 281.66612372089475
# Root Mean Squared Error (RMSE): 16.782911658019735
# R-squared Score: 0.6332620189362623
# Explained Variance Score: 0.6379945876246209
# For Node پونک and output column AQI:
# Mean Squared Error (MSE): 223.44189418001838
# Root Mean Squared Error (RMSE): 14.947972912071334
# R-squared Score: 0.5228110438774274
# Explained Variance Score: 0.5321473902663627
# For Node پونک and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node پونک and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node تربیت.مدرس.منطقه6 and output column CO:
# Mean Squared Error (MSE): 144.94835615661313
# Root Mean Squared Error (RMSE): 12.039449993941298
# R-squared Score: 0.39816843235803756
# Explained Variance Score: 0.40567375198069633
# For Node تربیت.مدرس.منطقه6 and output column O3:
# Mean Squared Error (MSE): 513.3499422469073
# Root Mean Squared Error (RMSE): 22.6572271526528
# R-squared Score: 0.8186486053464817
# Explained Variance Score: 0.8188113028744344
# For Node تربیت.مدرس.منطقه6 and output column NO2:
# Mean Squared Error (MSE): 130.95561793348034
# Root Mean Squared Error (RMSE): 11.443584138436714
# R-squared Score: 0.5683965015585817
# Explained Variance Score: 0.5783914206182785
# For Node تربیت.مدرس.منطقه6 and output column SO2:
# Mean Squared Error (MSE): 263.08172408480516
# Root Mean Squared Error (RMSE): 16.219794205994265
# R-squared Score: 0.33888321977544245
# Explained Variance Score: 0.3526047651248152
# For Node تربیت.مدرس.منطقه6 and output column PM10:
# Mean Squared Error (MSE): 269.68927533624304
# Root Mean Squared Error (RMSE): 16.42221895287732
# R-squared Score: 0.28319951074053984
# Explained Variance Score: 0.28414530812073957
# For Node تربیت.مدرس.منطقه6 and output column PM2.5:
# Mean Squared Error (MSE): 473.3207806137566
# Root Mean Squared Error (RMSE): 21.755936675164243
# R-squared Score: 0.5365936157763154
# Explained Variance Score: 0.5399412243077055
# For Node تربیت.مدرس.منطقه6 and output column AQI:
# Mean Squared Error (MSE): 808.9866963800669
# Root Mean Squared Error (RMSE): 28.442691440510107
# R-squared Score: 0.4503880258632037
# Explained Variance Score: 0.45041243453358426
# For Node تربیت.مدرس.منطقه6 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node تربیت.مدرس.منطقه6 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node گلبرگ.منطقه8 and output column CO:
# Mean Squared Error (MSE): 49.92888015518537
# Root Mean Squared Error (RMSE): 7.066037089853504
# R-squared Score: 0.34219049334570273
# Explained Variance Score: 0.3505824471158926
# For Node گلبرگ.منطقه8 and output column O3:
# Mean Squared Error (MSE): 562.6142774113505
# Root Mean Squared Error (RMSE): 23.719491508279653
# R-squared Score: 0.7082900371272329
# Explained Variance Score: 0.710510913661233
# For Node گلبرگ.منطقه8 and output column NO2:
# Mean Squared Error (MSE): 188.34749683860818
# Root Mean Squared Error (RMSE): 13.723975256411977
# R-squared Score: 0.2795230027884549
# Explained Variance Score: 0.2839635036962549
# For Node گلبرگ.منطقه8 and output column SO2:
# Mean Squared Error (MSE): 227.1071703695011
# Root Mean Squared Error (RMSE): 15.070075327266984
# R-squared Score: -0.005739043404457744
# Explained Variance Score: 0.030096225777209717
# For Node گلبرگ.منطقه8 and output column PM10:
# Mean Squared Error (MSE): 177.14089012158792
# Root Mean Squared Error (RMSE): 13.309428617397064
# R-squared Score: 0.3801578186174883
# Explained Variance Score: 0.38620657339439035
# For Node گلبرگ.منطقه8 and output column PM2.5:
# Mean Squared Error (MSE): 353.67352723106455
# Root Mean Squared Error (RMSE): 18.80620980503686
# R-squared Score: 0.5568591618308034
# Explained Variance Score: 0.5610443956068683
# For Node گلبرگ.منطقه8 and output column AQI:
# Mean Squared Error (MSE): 578.9653911696213
# Root Mean Squared Error (RMSE): 24.061699673331916
# R-squared Score: 0.3737981893355147
# Explained Variance Score: 0.37383184743268427
# For Node گلبرگ.منطقه8 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node گلبرگ.منطقه8 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node میدان.فتح.منطقه9 and output column CO:
# Mean Squared Error (MSE): 114.2883738001262
# Root Mean Squared Error (RMSE): 10.690574063170144
# R-squared Score: 0.6828852633321747
# Explained Variance Score: 0.6853467119154752
# For Node میدان.فتح.منطقه9 and output column O3:
# Mean Squared Error (MSE): 265.33317279451353
# Root Mean Squared Error (RMSE): 16.289050702681035
# R-squared Score: 0.7681207844907998
# Explained Variance Score: 0.7715912482505204
# For Node میدان.فتح.منطقه9 and output column NO2:
# Mean Squared Error (MSE): 199.9119509059597
# Root Mean Squared Error (RMSE): 14.1390222754602
# R-squared Score: 0.5588562353828248
# Explained Variance Score: 0.5697463503513557
# For Node میدان.فتح.منطقه9 and output column SO2:
# Mean Squared Error (MSE): 110.1270810748667
# Root Mean Squared Error (RMSE): 10.494145085468691
# R-squared Score: 0.6501629968948965
# Explained Variance Score: 0.650247105945388
# For Node میدان.فتح.منطقه9 and output column PM10:
# Mean Squared Error (MSE): 265.2893166991144
# Root Mean Squared Error (RMSE): 16.287704463770037
# R-squared Score: 0.41816182882086517
# Explained Variance Score: 0.4203539982249862
# For Node میدان.فتح.منطقه9 and output column PM2.5:
# Mean Squared Error (MSE): 328.2218413597794
# Root Mean Squared Error (RMSE): 18.116893811020127
# R-squared Score: 0.6092205875605357
# Explained Variance Score: 0.6092553983185117
# For Node میدان.فتح.منطقه9 and output column AQI:
# Mean Squared Error (MSE): 335.94723797477906
# Root Mean Squared Error (RMSE): 18.328863521090963
# R-squared Score: 0.40751018889482027
# Explained Variance Score: 0.40787098724191173
# For Node میدان.فتح.منطقه9 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node میدان.فتح.منطقه9 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شهرداری.منطقه10 and output column CO:
# Mean Squared Error (MSE): 58.3500779396316
# Root Mean Squared Error (RMSE): 7.638722271403222
# R-squared Score: 0.35109096360305647
# Explained Variance Score: 0.3513827765840394
# For Node شهرداری.منطقه10 and output column O3:
# Mean Squared Error (MSE): 279.4538598103967
# Root Mean Squared Error (RMSE): 16.716873505844227
# R-squared Score: 0.71931451150157
# Explained Variance Score: 0.7196873185639678
# For Node شهرداری.منطقه10 and output column NO2:
# Mean Squared Error (MSE): 115.1702400852322
# Root Mean Squared Error (RMSE): 10.731739844276518
# R-squared Score: 0.377144403303285
# Explained Variance Score: 0.37719783101516846
# For Node شهرداری.منطقه10 and output column SO2:
# Mean Squared Error (MSE): 109.87432893540534
# Root Mean Squared Error (RMSE): 10.482095636627504
# R-squared Score: 0.5148252387193175
# Explained Variance Score: 0.5282521645508318
# For Node شهرداری.منطقه10 and output column PM10:
# Mean Squared Error (MSE): 195.10509001087308
# Root Mean Squared Error (RMSE): 13.96800236293197
# R-squared Score: 0.42257510231901174
# Explained Variance Score: 0.42337115950374316
# For Node شهرداری.منطقه10 and output column PM2.5:
# Mean Squared Error (MSE): 497.8521119334999
# Root Mean Squared Error (RMSE): 22.312599847025893
# R-squared Score: 0.5665053411128768
# Explained Variance Score: 0.566509519948365
# For Node شهرداری.منطقه10 and output column AQI:
# Mean Squared Error (MSE): 510.71360312221844
# Root Mean Squared Error (RMSE): 22.598973497090935
# R-squared Score: 0.6088877378813166
# Explained Variance Score: 0.6089022176658736
# For Node شهرداری.منطقه10 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شهرداری.منطقه10 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شهرداری.منطقه11 and output column CO:
# Mean Squared Error (MSE): 198.43166324720133
# Root Mean Squared Error (RMSE): 14.086577414233783
# R-squared Score: 0.44889928571995186
# Explained Variance Score: 0.4637663616036438
# For Node شهرداری.منطقه11 and output column O3:
# Mean Squared Error (MSE): 579.5697792842927
# Root Mean Squared Error (RMSE): 24.07425552918081
# R-squared Score: 0.6702913065302111
# Explained Variance Score: 0.6703657289373242
# For Node شهرداری.منطقه11 and output column NO2:
# Mean Squared Error (MSE): 276.79773730114164
# Root Mean Squared Error (RMSE): 16.637239473576788
# R-squared Score: 0.3372583455320365
# Explained Variance Score: 0.33726103227642046
# For Node شهرداری.منطقه11 and output column SO2:
# Mean Squared Error (MSE): 21.153308765023954
# Root Mean Squared Error (RMSE): 4.599272634343821
# R-squared Score: 0.28791281100199295
# Explained Variance Score: 0.30959991899685846
# For Node شهرداری.منطقه11 and output column PM10:
# Mean Squared Error (MSE): 194.5227342023057
# Root Mean Squared Error (RMSE): 13.947140717806848
# R-squared Score: 0.4251800755593359
# Explained Variance Score: 0.42574581591080274
# For Node شهرداری.منطقه11 and output column PM2.5:
# Mean Squared Error (MSE): 454.5472064114908
# Root Mean Squared Error (RMSE): 21.320112720421783
# R-squared Score: 0.6264000075155323
# Explained Variance Score: 0.6266274255881872
# For Node شهرداری.منطقه11 and output column AQI:
# Mean Squared Error (MSE): 693.7403182959903
# Root Mean Squared Error (RMSE): 26.338950592155154
# R-squared Score: 0.41461649593865624
# Explained Variance Score: 0.41519599722991307
# For Node شهرداری.منطقه11 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شهرداری.منطقه11 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node میدان.امام.خمینی.منطقه12 and output column CO:
# Mean Squared Error (MSE): 80.3712828271123
# Root Mean Squared Error (RMSE): 8.965003225159057
# R-squared Score: 0.10496334360710091
# Explained Variance Score: 0.10879307475598365
# For Node میدان.امام.خمینی.منطقه12 and output column O3:
# Mean Squared Error (MSE): 459.7028959204534
# Root Mean Squared Error (RMSE): 21.440683196214934
# R-squared Score: 0.5559755028286526
# Explained Variance Score: 0.562033589998801
# For Node میدان.امام.خمینی.منطقه12 and output column NO2:
# Mean Squared Error (MSE): 402.21546521014557
# Root Mean Squared Error (RMSE): 20.05531014993649
# R-squared Score: 0.3676446418896596
# Explained Variance Score: 0.37161894621615554
# For Node میدان.امام.خمینی.منطقه12 and output column SO2:
# Mean Squared Error (MSE): 83.82533324398813
# Root Mean Squared Error (RMSE): 9.155617578513649
# R-squared Score: 0.2426598714039273
# Explained Variance Score: 0.24492402356914722
# For Node میدان.امام.خمینی.منطقه12 and output column PM10:
# Mean Squared Error (MSE): 211.85579595869413
# Root Mean Squared Error (RMSE): 14.555266949070159
# R-squared Score: 0.40535274084465955
# Explained Variance Score: 0.4068903606810219
# For Node میدان.امام.خمینی.منطقه12 and output column PM2.5:
# Mean Squared Error (MSE): 1343.854619978799
# Root Mean Squared Error (RMSE): 36.658622723430284
# R-squared Score: -0.1815765166197958
# Explained Variance Score: -0.17124145618866216
# For Node میدان.امام.خمینی.منطقه12 and output column AQI:
# Mean Squared Error (MSE): 1451.5250936927462
# Root Mean Squared Error (RMSE): 38.098885727705294
# R-squared Score: -0.3074432963797573
# Explained Variance Score: -0.30707693910255474
# For Node میدان.امام.خمینی.منطقه12 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node میدان.امام.خمینی.منطقه12 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node پیروزی.منطقه13 and output column CO:
# Mean Squared Error (MSE): 64.31834186108473
# Root Mean Squared Error (RMSE): 8.019871686073582
# R-squared Score: 0.3311503195027121
# Explained Variance Score: 0.3373238716706983
# For Node پیروزی.منطقه13 and output column O3:
# Mean Squared Error (MSE): 520.6408785062598
# Root Mean Squared Error (RMSE): 22.81755636579561
# R-squared Score: 0.6465009401183326
# Explained Variance Score: 0.6465664302248426
# For Node پیروزی.منطقه13 and output column NO2:
# Mean Squared Error (MSE): 127.56965019939058
# Root Mean Squared Error (RMSE): 11.29467353221821
# R-squared Score: 0.4382878571873706
# Explained Variance Score: 0.4396219182132646
# For Node پیروزی.منطقه13 and output column SO2:
# Mean Squared Error (MSE): 87.67354229318391
# Root Mean Squared Error (RMSE): 9.363415097771961
# R-squared Score: 0.22756633964921236
# Explained Variance Score: 0.24427102920028165
# For Node پیروزی.منطقه13 and output column PM10:
# Mean Squared Error (MSE): 218.3703413690385
# Root Mean Squared Error (RMSE): 14.777359079654202
# R-squared Score: 0.3869208481160634
# Explained Variance Score: 0.39425597218683583
# For Node پیروزی.منطقه13 and output column PM2.5:
# Mean Squared Error (MSE): 369.10557259481027
# Root Mean Squared Error (RMSE): 19.21212046065739
# R-squared Score: 0.5993313273499584
# Explained Variance Score: 0.6003752535615912
# For Node پیروزی.منطقه13 and output column AQI:
# Mean Squared Error (MSE): 552.1556020697096
# Root Mean Squared Error (RMSE): 23.49799144756227
# R-squared Score: 0.5318288806210123
# Explained Variance Score: 0.5325676911513407
# For Node پیروزی.منطقه13 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node پیروزی.منطقه13 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node اتوبان.محلاتی.منطقه14 and output column CO:
# Mean Squared Error (MSE): 75.62318642100193
# Root Mean Squared Error (RMSE): 8.696159291376965
# R-squared Score: 0.054635521514104446
# Explained Variance Score: 0.10194908319147256
# For Node اتوبان.محلاتی.منطقه14 and output column O3:
# Mean Squared Error (MSE): 212.0097096447477
# Root Mean Squared Error (RMSE): 14.560553205312898
# R-squared Score: 0.7440579980308379
# Explained Variance Score: 0.7482748588638204
# For Node اتوبان.محلاتی.منطقه14 and output column NO2:
# Mean Squared Error (MSE): 107.68117253924781
# Root Mean Squared Error (RMSE): 10.376953914287554
# R-squared Score: 0.7598062839136495
# Explained Variance Score: 0.7653989686254472
# For Node اتوبان.محلاتی.منطقه14 and output column SO2:
# Mean Squared Error (MSE): 124.0135589690577
# Root Mean Squared Error (RMSE): 11.136137524701178
# R-squared Score: 0.433633635527909
# Explained Variance Score: 0.44655372613021893
# For Node اتوبان.محلاتی.منطقه14 and output column PM10:
# Mean Squared Error (MSE): 229.5355719142463
# Root Mean Squared Error (RMSE): 15.15043141016936
# R-squared Score: 0.34786010926469
# Explained Variance Score: 0.35255603131707924
# For Node اتوبان.محلاتی.منطقه14 and output column PM2.5:
# Mean Squared Error (MSE): 612.0738631915347
# Root Mean Squared Error (RMSE): 24.740126579941638
# R-squared Score: 0.583259253210996
# Explained Variance Score: 0.5851719000381983
# For Node اتوبان.محلاتی.منطقه14 and output column AQI:
# Mean Squared Error (MSE): 335.18559663391187
# Root Mean Squared Error (RMSE): 18.30807462935171
# R-squared Score: 0.40099965374741864
# Explained Variance Score: 0.405250690405099
# For Node اتوبان.محلاتی.منطقه14 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node اتوبان.محلاتی.منطقه14 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node مسعودیه.منطقه15 and output column CO:
# Mean Squared Error (MSE): 61.191612615092524
# Root Mean Squared Error (RMSE): 7.822506798660678
# R-squared Score: -0.11234798958794645
# Explained Variance Score: -0.11229052354954461
# For Node مسعودیه.منطقه15 and output column O3:
# Mean Squared Error (MSE): 287.59390455688856
# Root Mean Squared Error (RMSE): 16.95859382604845
# R-squared Score: 0.7068174456327464
# Explained Variance Score: 0.7075908360325421
# For Node مسعودیه.منطقه15 and output column NO2:
# Mean Squared Error (MSE): 160.53892408350245
# Root Mean Squared Error (RMSE): 12.67039557723051
# R-squared Score: 0.46914817907178497
# Explained Variance Score: 0.47089708185517387
# For Node مسعودیه.منطقه15 and output column SO2:
# Mean Squared Error (MSE): 143.77417336199238
# Root Mean Squared Error (RMSE): 11.990586864786577
# R-squared Score: 0.4388548745825873
# Explained Variance Score: 0.44311179929518507
# For Node مسعودیه.منطقه15 and output column PM10:
# Mean Squared Error (MSE): 193.5421045037827
# Root Mean Squared Error (RMSE): 13.91194107606062
# R-squared Score: 0.47089905587637393
# Explained Variance Score: 0.4724688585631529
# For Node مسعودیه.منطقه15 and output column PM2.5:
# Mean Squared Error (MSE): 328.2925091387037
# Root Mean Squared Error (RMSE): 18.118844034283857
# R-squared Score: 0.49798849438484805
# Explained Variance Score: 0.5123858622320419
# For Node مسعودیه.منطقه15 and output column AQI:
# Mean Squared Error (MSE): 250.8429203913608
# Root Mean Squared Error (RMSE): 15.838021353419144
# R-squared Score: 0.5662130634607905
# Explained Variance Score: 0.5664232918710776
# For Node مسعودیه.منطقه15 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node مسعودیه.منطقه15 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شهرداری.منطقه16 and output column CO:
# Mean Squared Error (MSE): 58.48867723228363
# Root Mean Squared Error (RMSE): 7.647789042088153
# R-squared Score: 0.3528487805914914
# Explained Variance Score: 0.35324407773262956
# For Node شهرداری.منطقه16 and output column O3:
# Mean Squared Error (MSE): 269.9322735726697
# Root Mean Squared Error (RMSE): 16.429615746348716
# R-squared Score: 0.7276364803964552
# Explained Variance Score: 0.7286206521287821
# For Node شهرداری.منطقه16 and output column NO2:
# Mean Squared Error (MSE): 128.72430486167858
# Root Mean Squared Error (RMSE): 11.345673398334652
# R-squared Score: 0.36363925835461075
# Explained Variance Score: 0.3637836050470967
# For Node شهرداری.منطقه16 and output column SO2:
# Mean Squared Error (MSE): 64.43317212137813
# Root Mean Squared Error (RMSE): 8.027027601882164
# R-squared Score: 0.6156503071947876
# Explained Variance Score: 0.6322887450751103
# For Node شهرداری.منطقه16 and output column PM10:
# Mean Squared Error (MSE): 182.00285230484093
# Root Mean Squared Error (RMSE): 13.490843276268572
# R-squared Score: 0.4829152490508565
# Explained Variance Score: 0.4835611012423241
# For Node شهرداری.منطقه16 and output column PM2.5:
# Mean Squared Error (MSE): 313.70867549921667
# Root Mean Squared Error (RMSE): 17.7118230427931
# R-squared Score: 0.6205678073045802
# Explained Variance Score: 0.6209151070855846
# For Node شهرداری.منطقه16 and output column AQI:
# Mean Squared Error (MSE): 186.3095326898655
# Root Mean Squared Error (RMSE): 13.649524998690083
# R-squared Score: 0.7507210337604638
# Explained Variance Score: 0.7508086289837731
# For Node شهرداری.منطقه16 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شهرداری.منطقه16 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node پارک.سلامت.منطقه17 and output column CO:
# Mean Squared Error (MSE): 93.69681802463806
# Root Mean Squared Error (RMSE): 9.67971167053224
# R-squared Score: 0.21629325266213117
# Explained Variance Score: 0.22045507203196424
# For Node پارک.سلامت.منطقه17 and output column O3:
# Mean Squared Error (MSE): 269.90746535915224
# Root Mean Squared Error (RMSE): 16.428860744408063
# R-squared Score: 0.7276071355241052
# Explained Variance Score: 0.7285647499253223
# For Node پارک.سلامت.منطقه17 and output column NO2:
# Mean Squared Error (MSE): 280.8996382738898
# Root Mean Squared Error (RMSE): 16.7600608075833
# R-squared Score: 0.47704995741047407
# Explained Variance Score: 0.47705862701625346
# For Node پارک.سلامت.منطقه17 and output column SO2:
# Mean Squared Error (MSE): 561.4300206895155
# Root Mean Squared Error (RMSE): 23.694514569611158
# R-squared Score: 0.6854396381001261
# Explained Variance Score: 0.6936276023661594
# For Node پارک.سلامت.منطقه17 and output column PM10:
# Mean Squared Error (MSE): 200.71175389521642
# Root Mean Squared Error (RMSE): 14.167277575286525
# R-squared Score: 0.4240993968714246
# Explained Variance Score: 0.4241558383315137
# For Node پارک.سلامت.منطقه17 and output column PM2.5:
# Mean Squared Error (MSE): 482.95054107060906
# Root Mean Squared Error (RMSE): 21.976135717423322
# R-squared Score: 0.5539787208773926
# Explained Variance Score: 0.554516367490574
# For Node پارک.سلامت.منطقه17 and output column AQI:
# Mean Squared Error (MSE): 549.257264576556
# Root Mean Squared Error (RMSE): 23.43623827700504
# R-squared Score: 0.40434411705890516
# Explained Variance Score: 0.4043460550450918
# For Node پارک.سلامت.منطقه17 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node پارک.سلامت.منطقه17 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شادآباد.منطقه18 and output column CO:
# Mean Squared Error (MSE): 251.34080089054927
# Root Mean Squared Error (RMSE): 15.85373145005772
# R-squared Score: 0.3342880853631709
# Explained Variance Score: 0.33518191459436886
# For Node شادآباد.منطقه18 and output column O3:
# Mean Squared Error (MSE): 501.92714338005624
# Root Mean Squared Error (RMSE): 22.40373056836866
# R-squared Score: 0.7247624101660608
# Explained Variance Score: 0.7247676183815075
# For Node شادآباد.منطقه18 and output column NO2:
# Mean Squared Error (MSE): 211.80714245138492
# Root Mean Squared Error (RMSE): 14.55359551627655
# R-squared Score: 0.5990706782042738
# Explained Variance Score: 0.6021473842328391
# For Node شادآباد.منطقه18 and output column SO2:
# Mean Squared Error (MSE): 226.9724154126422
# Root Mean Squared Error (RMSE): 15.065603718823954
# R-squared Score: 0.6079177182847306
# Explained Variance Score: 0.620583625564753
# For Node شادآباد.منطقه18 and output column PM10:
# Mean Squared Error (MSE): 273.2237718963734
# Root Mean Squared Error (RMSE): 16.529481900421846
# R-squared Score: 0.38307794577398646
# Explained Variance Score: 0.38574296469253677
# For Node شادآباد.منطقه18 and output column PM2.5:
# Mean Squared Error (MSE): 499.59687272225403
# Root Mean Squared Error (RMSE): 22.35166375736388
# R-squared Score: 0.5190744588509429
# Explained Variance Score: 0.5192664194158497
# For Node شادآباد.منطقه18 and output column AQI:
# Mean Squared Error (MSE): 724.3740383337071
# Root Mean Squared Error (RMSE): 26.914197709270606
# R-squared Score: 0.30854274622632727
# Explained Variance Score: 0.3089037100765938
# For Node شادآباد.منطقه18 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شادآباد.منطقه18 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شهرداری.منطقه19 and output column CO:
# Mean Squared Error (MSE): 251.77714857325702
# Root Mean Squared Error (RMSE): 15.867487153713313
# R-squared Score: -0.026149418748461217
# Explained Variance Score: 0.023529678008798016
# For Node شهرداری.منطقه19 and output column O3:
# Mean Squared Error (MSE): 268.8318216132655
# Root Mean Squared Error (RMSE): 16.396091656649933
# R-squared Score: 0.7574759083596159
# Explained Variance Score: 0.7575098162920725
# For Node شهرداری.منطقه19 and output column NO2:
# Mean Squared Error (MSE): 115.17997907430504
# Root Mean Squared Error (RMSE): 10.73219358166377
# R-squared Score: 0.6071287426021047
# Explained Variance Score: 0.6072180885803938
# For Node شهرداری.منطقه19 and output column SO2:
# Mean Squared Error (MSE): 82.02340291300445
# Root Mean Squared Error (RMSE): 9.056677255649802
# R-squared Score: 0.4652905325497396
# Explained Variance Score: 0.475684015485362
# For Node شهرداری.منطقه19 and output column PM10:
# Mean Squared Error (MSE): 535.0236315448535
# Root Mean Squared Error (RMSE): 23.130577847188633
# R-squared Score: 0.4724123970460431
# Explained Variance Score: 0.4770980068389108
# For Node شهرداری.منطقه19 and output column PM2.5:
# Mean Squared Error (MSE): 523.0603126400159
# Root Mean Squared Error (RMSE): 22.870511857849092
# R-squared Score: 0.6118173601896623
# Explained Variance Score: 0.6118393661514305
# For Node شهرداری.منطقه19 and output column AQI:
# Mean Squared Error (MSE): 664.4034612763747
# Root Mean Squared Error (RMSE): 25.77602493163705
# R-squared Score: 0.5130203163076409
# Explained Variance Score: 0.5145019087842291
# For Node شهرداری.منطقه19 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شهرداری.منطقه19 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شهر.ری.منطقه20 and output column CO:
# Mean Squared Error (MSE): 325.9386182020374
# Root Mean Squared Error (RMSE): 18.053770193564485
# R-squared Score: -0.07947944144440267
# Explained Variance Score: -0.07713371632891342
# For Node شهر.ری.منطقه20 and output column O3:
# Mean Squared Error (MSE): 198.9698581805755
# Root Mean Squared Error (RMSE): 14.10566759074435
# R-squared Score: 0.6378978743569649
# Explained Variance Score: 0.6404337642014488
# For Node شهر.ری.منطقه20 and output column NO2:
# Mean Squared Error (MSE): 201.61122171790603
# Root Mean Squared Error (RMSE): 14.19898664404985
# R-squared Score: 0.3628364909190662
# Explained Variance Score: 0.36517413172706736
# For Node شهر.ری.منطقه20 and output column SO2:
# Mean Squared Error (MSE): 232.42243512293734
# Root Mean Squared Error (RMSE): 15.245407017293351
# R-squared Score: 0.5315671186556763
# Explained Variance Score: 0.5443839223269998
# For Node شهر.ری.منطقه20 and output column PM10:
# Mean Squared Error (MSE): 233.7786959322425
# Root Mean Squared Error (RMSE): 15.289823279954629
# R-squared Score: 0.48159799709826345
# Explained Variance Score: 0.4819102981192128
# For Node شهر.ری.منطقه20 and output column PM2.5:
# Mean Squared Error (MSE): 365.5533122449394
# Root Mean Squared Error (RMSE): 19.11944853401738
# R-squared Score: 0.5993625125359998
# Explained Variance Score: 0.599953967458768
# For Node شهر.ری.منطقه20 and output column AQI:
# Mean Squared Error (MSE): 370.37271206170607
# Root Mean Squared Error (RMSE): 19.245069811816897
# R-squared Score: 0.5141887543087656
# Explained Variance Score: 0.5142540767725878
# For Node شهر.ری.منطقه20 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شهر.ری.منطقه20 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شهرداری.منطقه21 and output column CO:
# Mean Squared Error (MSE): 132.00286720818204
# Root Mean Squared Error (RMSE): 11.48925007161834
# R-squared Score: 0.3551853945532073
# Explained Variance Score: 0.3693113986074531
# For Node شهرداری.منطقه21 and output column O3:
# Mean Squared Error (MSE): 299.80051555015166
# Root Mean Squared Error (RMSE): 17.314748498033453
# R-squared Score: 0.6636230321910963
# Explained Variance Score: 0.663756619550149
# For Node شهرداری.منطقه21 and output column NO2:
# Mean Squared Error (MSE): 253.10973905168962
# Root Mean Squared Error (RMSE): 15.909422964133226
# R-squared Score: 0.1313281733080408
# Explained Variance Score: 0.13225443532899772
# For Node شهرداری.منطقه21 and output column SO2:
# Mean Squared Error (MSE): 247.66377091863532
# Root Mean Squared Error (RMSE): 15.73733684327292
# R-squared Score: 0.5147221526041402
# Explained Variance Score: 0.5594992709203799
# For Node شهرداری.منطقه21 and output column PM10:
# Mean Squared Error (MSE): 431.7475899429569
# Root Mean Squared Error (RMSE): 20.778536761354417
# R-squared Score: 0.42840515068712715
# Explained Variance Score: 0.4287237321747147
# For Node شهرداری.منطقه21 and output column PM2.5:
# Mean Squared Error (MSE): 345.44798002706466
# Root Mean Squared Error (RMSE): 18.58623092579732
# R-squared Score: 0.6530923934738418
# Explained Variance Score: 0.6531775132508992
# For Node شهرداری.منطقه21 and output column AQI:
# Mean Squared Error (MSE): 531.576434471981
# Root Mean Squared Error (RMSE): 23.055941413700307
# R-squared Score: 0.5602835894718496
# Explained Variance Score: 0.563937595067435
# For Node شهرداری.منطقه21 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شهرداری.منطقه21 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# For Node شهرداری.منطقه22 and output column CO:
# Mean Squared Error (MSE): 83.25606892255695
# Root Mean Squared Error (RMSE): 9.124476364293841
# R-squared Score: 0.42224705623491954
# Explained Variance Score: 0.4223926858069649
# For Node شهرداری.منطقه22 and output column O3:
# Mean Squared Error (MSE): 269.9322735726697
# Root Mean Squared Error (RMSE): 16.429615746348716
# R-squared Score: 0.7276364803964552
# Explained Variance Score: 0.7286206521287821
# For Node شهرداری.منطقه22 and output column NO2:
# Mean Squared Error (MSE): 232.6374349859435
# Root Mean Squared Error (RMSE): 15.252456686905997
# R-squared Score: 0.25886171114269263
# Explained Variance Score: 0.2602991584322383
# For Node شهرداری.منطقه22 and output column SO2:
# Mean Squared Error (MSE): 125.13780898762347
# Root Mean Squared Error (RMSE): 11.186501195084345
# R-squared Score: 0.5547935516376039
# Explained Variance Score: 0.5585323720792943
# For Node شهرداری.منطقه22 and output column PM10:
# Mean Squared Error (MSE): 202.59026147348686
# Root Mean Squared Error (RMSE): 14.233420582329705
# R-squared Score: 0.3488311353422331
# Explained Variance Score: 0.34961935893678875
# For Node شهرداری.منطقه22 and output column PM2.5:
# Mean Squared Error (MSE): 305.32590998548255
# Root Mean Squared Error (RMSE): 17.47357748102782
# R-squared Score: 0.6473296997515523
# Explained Variance Score: 0.649433521480091
# For Node شهرداری.منطقه22 and output column AQI:
# Mean Squared Error (MSE): 324.2601767612617
# Root Mean Squared Error (RMSE): 18.007225681966162
# R-squared Score: 0.533079492916401
# Explained Variance Score: 0.5332752215579921
# For Node شهرداری.منطقه22 and output column Highest tempreture: 12pm:
# Mean Squared Error (MSE): 3.743124793295895
# Root Mean Squared Error (RMSE): 1.9347156879748235
# R-squared Score: 0.9686738119450906
# Explained Variance Score: 0.9686748187081564
# For Node شهرداری.منطقه22 and output column Wind:km/h:
# Mean Squared Error (MSE): 45.87815188618677
# Root Mean Squared Error (RMSE): 6.773341264559669
# R-squared Score: 0.03156027489145319
# Explained Variance Score: 0.038965745195163826
# Duration of the program execution: 11.546444177627563 seconds
