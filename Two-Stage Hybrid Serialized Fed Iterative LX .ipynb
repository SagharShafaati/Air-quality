# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import xgboost as xgb
from tensorflow.keras.layers import LSTM, Dense
from sklearn.ensemble import RandomForestRegressor
# Import the time module
import time

# Record the start time
start_time = time.time()

# Read data from Excel file
file_path = ''
df = pd.read_excel(file_path)

# Convert 'iranidate' to datetime and drop rows with invalid dates
df['iranidate'] = pd.to_datetime(df['iranidate'], errors='coerce')
df = df.dropna(subset=['iranidate'])

# Function to convert date values to numeric representation
def convert_to_numeric_date(date):
    base_date = datetime(2000, 1, 1)
    return (date - base_date).days

df['iranidate'] = df['iranidate'].apply(convert_to_numeric_date)

# Encode 'node' column
label_encoder = LabelEncoder()
df['node_encoded'] = label_encoder.fit_transform(df['node'])

# Handling NaN values by finding the nearest non-empty cells in the same column 
for col in ['CO', 'O3', 'SO2', 'PM10', 'PM2.5', 'AQI']:
    for idx, value in df[col].items():
        if pd.isnull(value):
            upper_cell = df[col].iloc[:idx].last_valid_index()
            lower_cell = df[col].iloc[idx + 1:].first_valid_index()
            if upper_cell is not None and lower_cell is not None:
                avg = (df.at[upper_cell, col] + df.at[lower_cell, col]) / 2
                df.at[idx, col] = avg

# Check sample threshold
your_threshold_value = 100
if len(df) < your_threshold_value:
    print("Insufficient samples in the dataset.")
else:
    output_columns = ['CO', 'O3', 'NO2', 'SO2', 'PM10', 'PM2.5', 'AQI', 'Highest tempreture: 12pm', 'Wind:km/h']
    unique_nodes = df['node'].unique()  

    # Dictionary to store weighted predictions for each node and column
    weighted_predictions = {}

    for node_value in unique_nodes:
        node_df = df[df['node'] == node_value]  
        
        # Dictionary to store predictions and true values for each column
        columns_data = {}

        for output_column in output_columns:
            if node_df[output_column].isnull().any():
                print(f"NaN values found in {output_column} for Node {node_value}. Handle missing values before modeling.")
            else:
                X = node_df[['iranidate', 'node_encoded']]
                Y = node_df[[output_column]]  
                X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
                
                # LSTM model
                lstm_model = Sequential()
                lstm_model.add(LSTM(50, activation='relu', input_shape=(X_test.shape[1], 1)))
                lstm_model.add(Dense(1))
                lstm_model.compile(optimizer='adam', loss='mean_squared_error')

                # Train LSTM model
                lstm_model.fit(X_train, Y_train, epochs=10, batch_size=1, verbose=0)

                # Make predictions with LSTM
                Y1_pred_lstm = lstm_model.predict(X_test)

                # XGBoost model as the secondary model, taking Y1_pred_xgb as input
                xgb_model_2 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.1, max_depth=5, alpha=10, n_estimators=100)
                xgb_model_2.fit(np.concatenate((X_test, Y1_pred_lstm.reshape(-1, 1)), axis=1), Y_test)
                Y2_pred_xgb = xgb_model_2.predict(np.concatenate((X_test, Y1_pred_lstm.reshape(-1, 1)), axis=1))

                # Calculate errors for the third XGBoost model
                mse_LSTM_1 = mean_squared_error(Y_test, Y1_pred_lstm)
                mse_xgb_2 = mean_squared_error(Y_test, Y2_pred_xgb)
                rmse_xgb_2 = np.sqrt(mse_xgb_2)
                r2_xgb_2 = r2_score(Y_test, Y2_pred_xgb)
                evs_xgb_2 = explained_variance_score(Y_test, Y2_pred_xgb)

                # Store predictions and true values for each column in the dictionary
                columns_data[output_column] = (Y2_pred_xgb, Y_test)

                # Output results for the local model with weighted predictions
                print(f"Local Model Results for Node {node_value} - {output_column} with Weighted Predictions:")
                print(f"MSE for LSTM_1: {mse_LSTM_1}")
                print(f"MSE for XGB_2: {mse_xgb_2}")
                print(f"RMSE for XGB_2: {rmse_xgb_2}")
                print(f"R2 for XGB_2: {r2_xgb_2}")
                print(f"EVS for XGB_2: {evs_xgb_2}")

                # Store weighted predictions for each node and column
                if node_value not in weighted_predictions:
                    weighted_predictions[node_value] = {output_column: (Y2_pred_xgb, Y_test)}
                else:
                    weighted_predictions[node_value][output_column] = (Y2_pred_xgb, Y_test)

# Aggregate predictions for the global model using weighted average
global_X_test = []
global_Y_test = []

for node, columns in weighted_predictions.items():
    for column, (node_prediction, Y_test) in columns.items():
        global_X_test.extend(node_prediction * r2_xgb_2)  # Apply weights using the R2 score from the third XGBoost model
        global_Y_test.extend(Y_test.values)

# Create and train the global model (Random Forest)
global_model = RandomForestRegressor(random_state=42)
global_model.fit(np.array(global_X_test).reshape(-1, 1), global_Y_test)  # Reshape for RF

# Predict using the global model
global_Y_pred = global_model.predict(np.array(global_X_test).reshape(-1, 1))
global_mse = mean_squared_error(global_Y_test, global_Y_pred)

# Print results for the global model
print("Global Model Results:")
print(f"Mean Squared Error (MSE) for Global Model: {global_mse}")

# Record the end time
end_time = time.time()

# Calculate the duration of the program execution
duration_seconds = end_time - start_time

# Print the duration of the program execution
print(f"Duration of the program execution: {duration_seconds} seconds")
# Out:
# 2024-02-27 00:32:50.060939: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - CO with Weighted Predictions:
# MSE for LSTM_1: 85.18333208097013
# MSE for XGB_2: 28.528526132447052
# RMSE for XGB_2: 5.341210174899229
# R2 for XGB_2: 0.6468128020200803
# EVS for XGB_2: 0.6468256494930813
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1304.1293475634172
# MSE for XGB_2: 28.388198371249977
# RMSE for XGB_2: 5.3280576546477025
# R2 for XGB_2: 0.9767480807390287
# EVS for XGB_2: 0.9767507709854069
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 731.2598056036552
# MSE for XGB_2: 46.51768525885971
# RMSE for XGB_2: 6.8203874713142
# R2 for XGB_2: 0.9234556949470069
# EVS for XGB_2: 0.9234568341244237
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 76.77237547462204
# MSE for XGB_2: 14.86445910951756
# RMSE for XGB_2: 3.8554453840662246
# R2 for XGB_2: 0.798868993843899
# EVS for XGB_2: 0.7989044938968228
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff362014af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اقدسیه.منطقه1 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 231.68588818775635
# MSE for XGB_2: 30.69402796301289
# RMSE for XGB_2: 5.540219125902232
# R2 for XGB_2: 0.8636765831827754
# EVS for XGB_2: 0.8636854966676043
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff362f22f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اقدسیه.منطقه1 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 864.0856292067987
# MSE for XGB_2: 40.77702479058983
# RMSE for XGB_2: 6.385689061533597
# R2 for XGB_2: 0.9498625116425201
# EVS for XGB_2: 0.9498636833060699
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - AQI with Weighted Predictions:
# MSE for LSTM_1: 765.5456169051289
# MSE for XGB_2: 47.898400582645145
# RMSE for XGB_2: 6.920867039803983
# R2 for XGB_2: 0.9350281080394452
# EVS for XGB_2: 0.93502934024253
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 132.13604490946537
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 66.84188230467791
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شریف.منطقه2 - CO with Weighted Predictions:
# MSE for LSTM_1: 169.32563494347414
# MSE for XGB_2: 31.252595833560573
# RMSE for XGB_2: 5.590402117340091
# R2 for XGB_2: 0.8128963536983831
# EVS for XGB_2: 0.8130386576682389
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شریف.منطقه2 - O3 with Weighted Predictions:
# MSE for LSTM_1: 558.7149573264851
# MSE for XGB_2: 24.79132518489529
# RMSE for XGB_2: 4.979088790621763
# R2 for XGB_2: 0.9528644454853383
# EVS for XGB_2: 0.9528645855897833
# 3/3 [==============================] - 0s 4ms/step
# Local Model Results for Node شریف.منطقه2 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 554.8156775333628
# MSE for XGB_2: 33.19293471421504
# RMSE for XGB_2: 5.761330984608942
# R2 for XGB_2: 0.9367427315648784
# EVS for XGB_2: 0.93674351970694
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شریف.منطقه2 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 252.70962661958853
# MSE for XGB_2: 20.744520147177195
# RMSE for XGB_2: 4.554615257865058
# R2 for XGB_2: 0.8929587490862692
# EVS for XGB_2: 0.8931135703765984
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شریف.منطقه2 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 607.0266213941017
# MSE for XGB_2: 38.02759690721192
# RMSE for XGB_2: 6.166652001468213
# R2 for XGB_2: 0.9374783652841655
# EVS for XGB_2: 0.937478688325195
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شریف.منطقه2 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1673.039488228421
# MSE for XGB_2: 50.47330428426928
# RMSE for XGB_2: 7.104456649474981
# R2 for XGB_2: 0.9351655592580275
# EVS for XGB_2: 0.9351655715286346
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شریف.منطقه2 - AQI with Weighted Predictions:
# MSE for LSTM_1: 894.0750268297521
# MSE for XGB_2: 57.37947269787224
# RMSE for XGB_2: 7.574923940071757
# R2 for XGB_2: 0.9348494841840752
# EVS for XGB_2: 0.93485709878485
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شریف.منطقه2 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 681.1892147780435
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شریف.منطقه2 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 138.30483588313163
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - CO with Weighted Predictions:
# MSE for LSTM_1: 157.8789195126187
# MSE for XGB_2: 21.0002222892054
# RMSE for XGB_2: 4.58259994863237
# R2 for XGB_2: 0.765877289680121
# EVS for XGB_2: 0.7659081742110467
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پاسداران.منطقه3 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1088.6001928089242
# MSE for XGB_2: 32.16887058238292
# RMSE for XGB_2: 5.671760800878588
# R2 for XGB_2: 0.9677833236952329
# EVS for XGB_2: 0.9677843308234779
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پاسداران.منطقه3 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 211.01713924947376
# MSE for XGB_2: 34.95276153691862
# RMSE for XGB_2: 5.912086056284924
# R2 for XGB_2: 0.8190320578610836
# EVS for XGB_2: 0.8190345947340414
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پاسداران.منطقه3 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 275.1437600291354
# MSE for XGB_2: 16.780649000702834
# RMSE for XGB_2: 4.0964190460331125
# R2 for XGB_2: 0.898550066277587
# EVS for XGB_2: 0.8985881639521113
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 252.25879229919332
# MSE for XGB_2: 30.69402796301289
# RMSE for XGB_2: 5.540219125902232
# R2 for XGB_2: 0.8636765831827754
# EVS for XGB_2: 0.8636854966676043
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 896.2159954942553
# MSE for XGB_2: 51.17365691773468
# RMSE for XGB_2: 7.153576512328269
# R2 for XGB_2: 0.9358081166102878
# EVS for XGB_2: 0.935808859260199
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - AQI with Weighted Predictions:
# MSE for LSTM_1: 718.09965876817
# MSE for XGB_2: 49.509260241716156
# RMSE for XGB_2: 7.036281705682068
# R2 for XGB_2: 0.9270706964732295
# EVS for XGB_2: 0.9270732231762614
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 332.22699987595706
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.00171470708813
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - CO with Weighted Predictions:
# MSE for LSTM_1: 234.27339829684576
# MSE for XGB_2: 27.336997882129328
# RMSE for XGB_2: 5.228479500019994
# R2 for XGB_2: 0.818389693725224
# EVS for XGB_2: 0.8185467073776664
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - O3 with Weighted Predictions:
# MSE for LSTM_1: 607.5009195088412
# MSE for XGB_2: 33.16627158478766
# RMSE for XGB_2: 5.759016546667292
# R2 for XGB_2: 0.9342011116416652
# EVS for XGB_2: 0.9342057091119474
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 692.6548080847338
# MSE for XGB_2: 56.409515756980404
# RMSE for XGB_2: 7.510626855128699
# R2 for XGB_2: 0.9140680755779985
# EVS for XGB_2: 0.9140720389041515
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 78.91021151041808
# MSE for XGB_2: 16.177226775810478
# RMSE for XGB_2: 4.022092338051238
# R2 for XGB_2: 0.7170060589848141
# EVS for XGB_2: 0.7170196691783666
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 340.0975019001709
# MSE for XGB_2: 31.216144016035024
# RMSE for XGB_2: 5.5871409518675135
# R2 for XGB_2: 0.9082035683802683
# EVS for XGB_2: 0.908234601133239
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1691.461836277608
# MSE for XGB_2: 54.02750668495194
# RMSE for XGB_2: 7.350340582922123
# R2 for XGB_2: 0.9633329853694653
# EVS for XGB_2: 0.9633330096003769
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1573.0496788171688
# MSE for XGB_2: 53.62356561874311
# RMSE for XGB_2: 7.322811319346082
# R2 for XGB_2: 0.9628427855910872
# EVS for XGB_2: 0.962842787791429
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 195.23932336796616
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 98.73513846989849
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - CO with Weighted Predictions:
# MSE for LSTM_1: 249.0756656381003
# MSE for XGB_2: 22.334110162049345
# RMSE for XGB_2: 4.725897815447277
# R2 for XGB_2: 0.8271629442619592
# EVS for XGB_2: 0.8271691298155109
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پونک - O3 with Weighted Predictions:
# MSE for LSTM_1: 396.86126854797476
# MSE for XGB_2: 22.797838587153844
# RMSE for XGB_2: 4.774708220106632
# R2 for XGB_2: 0.9405422191526805
# EVS for XGB_2: 0.9405713446229975
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - NO2 with Weighted Predictions:
# MSE for LSTM_1: 308.6722740164362
# MSE for XGB_2: 45.648420222489875
# RMSE for XGB_2: 6.7563614632796165
# R2 for XGB_2: 0.8480368387817805
# EVS for XGB_2: 0.8480371141992825
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - SO2 with Weighted Predictions:
# MSE for LSTM_1: 640.0935989961359
# MSE for XGB_2: 23.176450941108545
# RMSE for XGB_2: 4.814192657248829
# R2 for XGB_2: 0.9202707549168774
# EVS for XGB_2: 0.9202877733422357
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - PM10 with Weighted Predictions:
# MSE for LSTM_1: 853.1579365370333
# MSE for XGB_2: 36.529859041767736
# RMSE for XGB_2: 6.04399363349828
# R2 for XGB_2: 0.8560982761724647
# EVS for XGB_2: 0.8561013012604257
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پونک - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 789.8765880474076
# MSE for XGB_2: 49.702376178209974
# RMSE for XGB_2: 7.049991218307294
# R2 for XGB_2: 0.9352859731483749
# EVS for XGB_2: 0.9352860130712516
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - AQI with Weighted Predictions:
# MSE for LSTM_1: 491.06043306287904
# MSE for XGB_2: 46.836661043355775
# RMSE for XGB_2: 6.8437315145581055
# R2 for XGB_2: 0.8999742753096283
# EVS for XGB_2: 0.8999797509775046
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پونک - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 123.35198710123768
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 74.32400783318293
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - CO with Weighted Predictions:
# MSE for LSTM_1: 281.2830196731944
# MSE for XGB_2: 26.5011763820857
# RMSE for XGB_2: 5.147929329554331
# R2 for XGB_2: 0.8899660199722857
# EVS for XGB_2: 0.8900516082493539
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - O3 with Weighted Predictions:
# MSE for LSTM_1: 3822.0987887076926
# MSE for XGB_2: 34.400091171218
# RMSE for XGB_2: 5.865159091722747
# R2 for XGB_2: 0.9878474623318297
# EVS for XGB_2: 0.9878474853841922
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 420.2811627920765
# MSE for XGB_2: 35.05368173670152
# RMSE for XGB_2: 5.920614979603176
# R2 for XGB_2: 0.8844700829979097
# EVS for XGB_2: 0.8844884011171876
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 410.4205247809494
# MSE for XGB_2: 36.457023712566915
# RMSE for XGB_2: 6.037965196369297
# R2 for XGB_2: 0.9083845515409001
# EVS for XGB_2: 0.9083882768552615
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 374.5338897098294
# MSE for XGB_2: 36.34344557376159
# RMSE for XGB_2: 6.02855252724579
# R2 for XGB_2: 0.9034036502335252
# EVS for XGB_2: 0.9034040663114917
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1524.9871432125951
# MSE for XGB_2: 56.39822960662148
# RMSE for XGB_2: 7.50987547211147
# R2 for XGB_2: 0.9447831138435716
# EVS for XGB_2: 0.9447868831284354
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1653.508304417448
# MSE for XGB_2: 86.38664864101287
# RMSE for XGB_2: 9.29444181438632
# R2 for XGB_2: 0.9413103618253533
# EVS for XGB_2: 0.9413204149720106
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 120.12390145726661
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 54.25361690806371
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - CO with Weighted Predictions:
# MSE for LSTM_1: 92.60428530780842
# MSE for XGB_2: 21.067729760539045
# RMSE for XGB_2: 4.589959668726845
# R2 for XGB_2: 0.7224341327698101
# EVS for XGB_2: 0.722648143962482
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1944.2714156241045
# MSE for XGB_2: 32.548215973632594
# RMSE for XGB_2: 5.705104378855184
# R2 for XGB_2: 0.983124070514298
# EVS for XGB_2: 0.9831243692218226
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 343.8195408007205
# MSE for XGB_2: 51.57840622673291
# RMSE for XGB_2: 7.181810790234794
# R2 for XGB_2: 0.8026995003228714
# EVS for XGB_2: 0.8027027168558968
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 227.57221949148797
# MSE for XGB_2: 15.431388114029835
# RMSE for XGB_2: 3.9282805543939747
# R2 for XGB_2: 0.9316624415910935
# EVS for XGB_2: 0.931666635695212
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 357.99805659723654
# MSE for XGB_2: 32.197818740151746
# RMSE for XGB_2: 5.6743121821196745
# R2 for XGB_2: 0.887335068769522
# EVS for XGB_2: 0.8873508758702783
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node گلبرگ.منطقه8 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 846.8810826299831
# MSE for XGB_2: 38.07102745711855
# RMSE for XGB_2: 6.170172400923539
# R2 for XGB_2: 0.9522983041750597
# EVS for XGB_2: 0.9522983122428752
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - AQI with Weighted Predictions:
# MSE for LSTM_1: 923.6147193540261
# MSE for XGB_2: 63.51765558449757
# RMSE for XGB_2: 7.969796458159867
# R2 for XGB_2: 0.9313000888432681
# EVS for XGB_2: 0.9313015091814687
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 118.01199680182185
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 46.93450789808304
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - CO with Weighted Predictions:
# MSE for LSTM_1: 701.9746690241212
# MSE for XGB_2: 25.640160621343572
# RMSE for XGB_2: 5.063611420848125
# R2 for XGB_2: 0.9288565187061124
# EVS for XGB_2: 0.9288768958756036
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1333.01924665146
# MSE for XGB_2: 27.119901505981147
# RMSE for XGB_2: 5.207677169908014
# R2 for XGB_2: 0.9762994524217904
# EVS for XGB_2: 0.9763012753927323
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 559.4565822928311
# MSE for XGB_2: 47.64656841575531
# RMSE for XGB_2: 6.902649376562256
# R2 for XGB_2: 0.8948587792437501
# EVS for XGB_2: 0.8948704667622323
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 364.1297223630947
# MSE for XGB_2: 25.652170212172074
# RMSE for XGB_2: 5.064797154099271
# R2 for XGB_2: 0.9185116116528367
# EVS for XGB_2: 0.9185122695843903
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 608.7449361387987
# MSE for XGB_2: 40.9511011938308
# RMSE for XGB_2: 6.39930474300379
# R2 for XGB_2: 0.9101851739721046
# EVS for XGB_2: 0.9101881389447317
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 873.5663001864049
# MSE for XGB_2: 37.386423389862024
# RMSE for XGB_2: 6.114443833241256
# R2 for XGB_2: 0.955487896524568
# EVS for XGB_2: 0.9555037730143413
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - AQI with Weighted Predictions:
# MSE for LSTM_1: 564.522899511917
# MSE for XGB_2: 50.51860864884717
# RMSE for XGB_2: 7.1076443811467644
# R2 for XGB_2: 0.9109033874602087
# EVS for XGB_2: 0.910904125298577
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 117.34648045381687
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.738248648498335
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - CO with Weighted Predictions:
# MSE for LSTM_1: 114.29439003806021
# MSE for XGB_2: 20.18884475791522
# RMSE for XGB_2: 4.49319983507469
# R2 for XGB_2: 0.7754806118445956
# EVS for XGB_2: 0.7756634397590789
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1020.9459376008896
# MSE for XGB_2: 31.033106370646102
# RMSE for XGB_2: 5.570736609340465
# R2 for XGB_2: 0.968830122342277
# EVS for XGB_2: 0.9688376896863903
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 192.69683660606356
# MSE for XGB_2: 33.92010671477554
# RMSE for XGB_2: 5.824097072918303
# R2 for XGB_2: 0.8165556632319911
# EVS for XGB_2: 0.8165608937117111
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 242.81937520241843
# MSE for XGB_2: 25.21825575102884
# RMSE for XGB_2: 5.021778146337096
# R2 for XGB_2: 0.8886431313622523
# EVS for XGB_2: 0.8886617824393478
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 569.8038868976428
# MSE for XGB_2: 32.18102126462034
# RMSE for XGB_2: 5.672831855838876
# R2 for XGB_2: 0.904758389901783
# EVS for XGB_2: 0.9047643310757101
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1238.168917072271
# MSE for XGB_2: 50.38481248387078
# RMSE for XGB_2: 7.098226009635843
# R2 for XGB_2: 0.9561284434127203
# EVS for XGB_2: 0.956129951999586
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1448.6929823182443
# MSE for XGB_2: 62.00103182954224
# RMSE for XGB_2: 7.874073394980659
# R2 for XGB_2: 0.9525186647383237
# EVS for XGB_2: 0.9525201620970608
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 165.19897220382748
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 49.283396339148226
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - CO with Weighted Predictions:
# MSE for LSTM_1: 379.0101352520114
# MSE for XGB_2: 22.89235578302627
# RMSE for XGB_2: 4.784595676023866
# R2 for XGB_2: 0.9364214691489933
# EVS for XGB_2: 0.9364913736659881
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1828.9117203914054
# MSE for XGB_2: 44.7222260653196
# RMSE for XGB_2: 6.687467836582065
# R2 for XGB_2: 0.9745581856540796
# EVS for XGB_2: 0.9745597454463467
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 475.993947977447
# MSE for XGB_2: 54.082245826030444
# RMSE for XGB_2: 7.354063218794794
# R2 for XGB_2: 0.8705099347069746
# EVS for XGB_2: 0.8705142598985496
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه11 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 63.7126933539527
# MSE for XGB_2: 8.162888857524564
# RMSE for XGB_2: 2.8570769778787137
# R2 for XGB_2: 0.7252113773203728
# EVS for XGB_2: 0.7259075721934843
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه11 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 397.1355005941854
# MSE for XGB_2: 32.36097051994179
# RMSE for XGB_2: 5.688670364851683
# R2 for XGB_2: 0.9043724595719824
# EVS for XGB_2: 0.9043725023015586
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1372.1155999729267
# MSE for XGB_2: 42.53138359387862
# RMSE for XGB_2: 6.521608972782608
# R2 for XGB_2: 0.9650427406286983
# EVS for XGB_2: 0.9650428945408221
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1236.2541392021449
# MSE for XGB_2: 89.01348850087315
# RMSE for XGB_2: 9.434695994088688
# R2 for XGB_2: 0.9248897225184289
# EVS for XGB_2: 0.924900718447668
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه11 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 165.18187205294808
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 82.90863008558364
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - CO with Weighted Predictions:
# MSE for LSTM_1: 108.69034587142845
# MSE for XGB_2: 24.393630209961447
# RMSE for XGB_2: 4.938990808855737
# R2 for XGB_2: 0.7283458412953994
# EVS for XGB_2: 0.72848644760773
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1051.0632043529367
# MSE for XGB_2: 36.82972511214363
# RMSE for XGB_2: 6.068749880506168
# R2 for XGB_2: 0.9644263712084418
# EVS for XGB_2: 0.9644283444328312
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 665.1279439090009
# MSE for XGB_2: 46.69053191219015
# RMSE for XGB_2: 6.83304704448829
# R2 for XGB_2: 0.926594050747727
# EVS for XGB_2: 0.9265979662736246
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 134.19186517636948
# MSE for XGB_2: 17.95232422011939
# RMSE for XGB_2: 4.237018317180065
# R2 for XGB_2: 0.8378054102822347
# EVS for XGB_2: 0.8378198196029547
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 391.50328983584967
# MSE for XGB_2: 32.898085956700996
# RMSE for XGB_2: 5.735685308374318
# R2 for XGB_2: 0.9076600356526322
# EVS for XGB_2: 0.9076600883268822
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1503.9527547065966
# MSE for XGB_2: 48.14171259004745
# RMSE for XGB_2: 6.93842291807349
# R2 for XGB_2: 0.9576716735422192
# EVS for XGB_2: 0.9576722556537596
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1333.878891194566
# MSE for XGB_2: 63.958254551088196
# RMSE for XGB_2: 7.997390483844602
# R2 for XGB_2: 0.9423903923367714
# EVS for XGB_2: 0.9423924233276068
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 161.1343984524688
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 50.027986918897135
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پیروزی.منطقه13 - CO with Weighted Predictions:
# MSE for LSTM_1: 186.97300210915503
# MSE for XGB_2: 24.393757564894674
# RMSE for XGB_2: 4.939003701648205
# R2 for XGB_2: 0.7463280849396428
# EVS for XGB_2: 0.7465282732021303
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1718.9737922904076
# MSE for XGB_2: 26.03787674447266
# RMSE for XGB_2: 5.102732282265322
# R2 for XGB_2: 0.9823210867020401
# EVS for XGB_2: 0.9823222754295522
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 230.41910515334482
# MSE for XGB_2: 46.87711285516579
# RMSE for XGB_2: 6.8466862682005365
# R2 for XGB_2: 0.7935916303792576
# EVS for XGB_2: 0.793600419112811
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پیروزی.منطقه13 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 116.97023141843395
# MSE for XGB_2: 19.058756718731523
# RMSE for XGB_2: 4.365633598772522
# R2 for XGB_2: 0.8320858855599191
# EVS for XGB_2: 0.832086532001507
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 852.3219144242838
# MSE for XGB_2: 32.65659808310481
# RMSE for XGB_2: 5.7145951810346824
# R2 for XGB_2: 0.9083159401103397
# EVS for XGB_2: 0.9083161951792279
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 943.0552925762529
# MSE for XGB_2: 51.62464720194177
# RMSE for XGB_2: 7.185029380729196
# R2 for XGB_2: 0.9439608057797187
# EVS for XGB_2: 0.9439609042950041
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پیروزی.منطقه13 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1190.1791585468616
# MSE for XGB_2: 63.22412315617091
# RMSE for XGB_2: 7.951359830630916
# R2 for XGB_2: 0.9463924509706549
# EVS for XGB_2: 0.9463951306883691
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پیروزی.منطقه13 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.05045419576483
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 69.59741672988784
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - CO with Weighted Predictions:
# MSE for LSTM_1: 111.37672531782509
# MSE for XGB_2: 25.833968066311247
# RMSE for XGB_2: 5.082712668084952
# R2 for XGB_2: 0.6770498982644424
# EVS for XGB_2: 0.6772461576159053
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - O3 with Weighted Predictions:
# MSE for LSTM_1: 856.3555123497496
# MSE for XGB_2: 25.18577537247466
# RMSE for XGB_2: 5.018543152397383
# R2 for XGB_2: 0.9695952709865122
# EVS for XGB_2: 0.9695990522696292
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 497.4848852420371
# MSE for XGB_2: 24.379895018270084
# RMSE for XGB_2: 4.9376001274171735
# R2 for XGB_2: 0.945618185202255
# EVS for XGB_2: 0.9456679212898935
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 227.13004085861766
# MSE for XGB_2: 21.69009937282552
# RMSE for XGB_2: 4.657263077476461
# R2 for XGB_2: 0.9009419386964722
# EVS for XGB_2: 0.9009477120250504
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 1504.9212496006307
# MSE for XGB_2: 30.242882979535327
# RMSE for XGB_2: 5.4993529600795155
# R2 for XGB_2: 0.9140761049047194
# EVS for XGB_2: 0.9140761431178045
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1506.664341480405
# MSE for XGB_2: 73.38717105333377
# RMSE for XGB_2: 8.566631254660946
# R2 for XGB_2: 0.9500331147779655
# EVS for XGB_2: 0.9500396348869926
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - AQI with Weighted Predictions:
# MSE for LSTM_1: 613.5650407507538
# MSE for XGB_2: 44.555304390157005
# RMSE for XGB_2: 6.674975984238221
# R2 for XGB_2: 0.9203765226635248
# EVS for XGB_2: 0.9203771720718463
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 152.0433910173704
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.64747449099
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - CO with Weighted Predictions:
# MSE for LSTM_1: 55.17823330159485
# MSE for XGB_2: 17.063475934083474
# RMSE for XGB_2: 4.130796041210879
# R2 for XGB_2: 0.6898182228003804
# EVS for XGB_2: 0.6899136422366904
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - O3 with Weighted Predictions:
# MSE for LSTM_1: 981.5961901744333
# MSE for XGB_2: 31.38526237821451
# RMSE for XGB_2: 5.602255115416872
# R2 for XGB_2: 0.9680048455557192
# EVS for XGB_2: 0.968010677568631
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 348.547948940266
# MSE for XGB_2: 52.85099156426506
# RMSE for XGB_2: 7.269868744638039
# R2 for XGB_2: 0.8252383634067535
# EVS for XGB_2: 0.8252617690011421
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 262.7518279733098
# MSE for XGB_2: 25.4916475186888
# RMSE for XGB_2: 5.048925382562986
# R2 for XGB_2: 0.9005070701540017
# EVS for XGB_2: 0.9005352511850773
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 402.03374231702384
# MSE for XGB_2: 22.274801096644893
# RMSE for XGB_2: 4.719618744839979
# R2 for XGB_2: 0.9391056621988398
# EVS for XGB_2: 0.9391155325172081
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 762.5703129698425
# MSE for XGB_2: 38.32737360418443
# RMSE for XGB_2: 6.190910563413465
# R2 for XGB_2: 0.9413913446280255
# EVS for XGB_2: 0.9413941499009676
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node مسعودیه.منطقه15 - AQI with Weighted Predictions:
# MSE for LSTM_1: 585.8202295303817
# MSE for XGB_2: 43.017296344686045
# RMSE for XGB_2: 6.55875722562484
# R2 for XGB_2: 0.9256094564261684
# EVS for XGB_2: 0.9256442047253964
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 118.56513062092819
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.8653108620862
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - CO with Weighted Predictions:
# MSE for LSTM_1: 114.12149406073452
# MSE for XGB_2: 20.19254726638035
# RMSE for XGB_2: 4.493611828627429
# R2 for XGB_2: 0.7765784386864346
# EVS for XGB_2: 0.7767555724532504
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - O3 with Weighted Predictions:
# MSE for LSTM_1: 982.7394868784312
# MSE for XGB_2: 29.61515038446704
# RMSE for XGB_2: 5.441980373399654
# R2 for XGB_2: 0.9701181096815746
# EVS for XGB_2: 0.9701181620833641
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 239.0474125899521
# MSE for XGB_2: 34.444082005155224
# RMSE for XGB_2: 5.868908076052582
# R2 for XGB_2: 0.8297224320329544
# EVS for XGB_2: 0.8297241957511305
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 170.50650754636595
# MSE for XGB_2: 18.37111909730462
# RMSE for XGB_2: 4.286154348282925
# R2 for XGB_2: 0.8904146148782536
# EVS for XGB_2: 0.8904247041826022
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 570.2944337389596
# MSE for XGB_2: 29.641436675397436
# RMSE for XGB_2: 5.444394977901349
# R2 for XGB_2: 0.9157862928686364
# EVS for XGB_2: 0.9157863311074776
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 949.9718747984817
# MSE for XGB_2: 39.565382393315964
# RMSE for XGB_2: 6.290101938229298
# R2 for XGB_2: 0.9521454745475596
# EVS for XGB_2: 0.9521484583270474
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - AQI with Weighted Predictions:
# MSE for LSTM_1: 748.370144555868
# MSE for XGB_2: 35.93683916943415
# RMSE for XGB_2: 5.994734286808228
# R2 for XGB_2: 0.951917124214008
# EVS for XGB_2: 0.9519209708300537
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 115.05652331661464
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 144.82268625494572
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - CO with Weighted Predictions:
# MSE for LSTM_1: 134.15503968894558
# MSE for XGB_2: 25.35353783641786
# RMSE for XGB_2: 5.035229670672218
# R2 for XGB_2: 0.7879358222596015
# EVS for XGB_2: 0.7881176007126135
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1687.9531024230566
# MSE for XGB_2: 29.92458238100931
# RMSE for XGB_2: 5.470336587542791
# R2 for XGB_2: 0.9697998619557945
# EVS for XGB_2: 0.9698001495980458
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 569.5370326440061
# MSE for XGB_2: 58.06226176314873
# RMSE for XGB_2: 7.619859694452958
# R2 for XGB_2: 0.8919056555271285
# EVS for XGB_2: 0.8919063465476063
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 2065.5790531122234
# MSE for XGB_2: 48.89224299119461
# RMSE for XGB_2: 6.992298834517487
# R2 for XGB_2: 0.9726064494547005
# EVS for XGB_2: 0.9726115461806144
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 358.5045580919176
# MSE for XGB_2: 34.26846172055124
# RMSE for XGB_2: 5.853927034098668
# R2 for XGB_2: 0.9016737814793999
# EVS for XGB_2: 0.9016754369621692
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1168.8089712109727
# MSE for XGB_2: 57.856987128743924
# RMSE for XGB_2: 7.606378055864955
# R2 for XGB_2: 0.9465671011608418
# EVS for XGB_2: 0.9465871706792043
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - AQI with Weighted Predictions:
# MSE for LSTM_1: 957.257713175586
# MSE for XGB_2: 59.566551656411185
# RMSE for XGB_2: 7.717937007802745
# R2 for XGB_2: 0.9354015518611124
# EVS for XGB_2: 0.9354135792512854
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 131.5455882365213
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 103.89256001028032
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شادآباد.منطقه18 - CO with Weighted Predictions:
# MSE for LSTM_1: 428.5649252145378
# MSE for XGB_2: 40.293733698480644
# RMSE for XGB_2: 6.3477345327668395
# R2 for XGB_2: 0.893276306460235
# EVS for XGB_2: 0.8933702772053678
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شادآباد.منطقه18 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1906.4385149067014
# MSE for XGB_2: 49.4983720603589
# RMSE for XGB_2: 7.035507946151358
# R2 for XGB_2: 0.9728569916843869
# EVS for XGB_2: 0.9728579203762128
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 636.895736215205
# MSE for XGB_2: 43.9577065255891
# RMSE for XGB_2: 6.630060823671914
# R2 for XGB_2: 0.9167925440991909
# EVS for XGB_2: 0.9167962812994872
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 874.7018567547299
# MSE for XGB_2: 32.39002117771229
# RMSE for XGB_2: 5.691223170612122
# R2 for XGB_2: 0.9440480316294154
# EVS for XGB_2: 0.9440499348302952
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شادآباد.منطقه18 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 445.28727963902793
# MSE for XGB_2: 36.28836726358773
# RMSE for XGB_2: 6.02398267457566
# R2 for XGB_2: 0.9180631541634254
# EVS for XGB_2: 0.9180696232769905
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1125.9965510750603
# MSE for XGB_2: 67.93135982152091
# RMSE for XGB_2: 8.242048278281372
# R2 for XGB_2: 0.934607424972176
# EVS for XGB_2: 0.9346089268154794
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1470.3129310173504
# MSE for XGB_2: 110.27115094862599
# RMSE for XGB_2: 10.50100713972836
# R2 for XGB_2: 0.894739757127694
# EVS for XGB_2: 0.8947437503990187
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 177.02315123244134
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 46.98819183296608
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه19 - CO with Weighted Predictions:
# MSE for LSTM_1: 343.35971834823795
# MSE for XGB_2: 41.90760508949154
# RMSE for XGB_2: 6.4736083515680445
# R2 for XGB_2: 0.8292002874470177
# EVS for XGB_2: 0.82929174063429
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1379.0197123468758
# MSE for XGB_2: 25.918419357963113
# RMSE for XGB_2: 5.091013588467734
# R2 for XGB_2: 0.9766179424971974
# EVS for XGB_2: 0.976619560301989
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 297.0731940915311
# MSE for XGB_2: 25.459418126212917
# RMSE for XGB_2: 5.045732664956886
# R2 for XGB_2: 0.913159616000526
# EVS for XGB_2: 0.913252867917976
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 253.32432791768932
# MSE for XGB_2: 26.778073612888683
# RMSE for XGB_2: 5.174753483296445
# R2 for XGB_2: 0.8254340959728526
# EVS for XGB_2: 0.8254350400776921
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه19 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 1092.5748417160007
# MSE for XGB_2: 52.97364067664074
# RMSE for XGB_2: 7.2782992983691415
# R2 for XGB_2: 0.9477626137304739
# EVS for XGB_2: 0.9477904330881802
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1698.5273235416792
# MSE for XGB_2: 71.22527707212453
# RMSE for XGB_2: 8.439506921149157
# R2 for XGB_2: 0.947141055425269
# EVS for XGB_2: 0.94714186697307
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1566.0118574209112
# MSE for XGB_2: 83.56768979887603
# RMSE for XGB_2: 9.141536511925992
# R2 for XGB_2: 0.9387484118957209
# EVS for XGB_2: 0.9387494845258961
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.21992649730385
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 50.9890618079843
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - CO with Weighted Predictions:
# MSE for LSTM_1: 832.0751432175443
# MSE for XGB_2: 41.77701302101584
# RMSE for XGB_2: 6.463513983973102
# R2 for XGB_2: 0.8616382835212627
# EVS for XGB_2: 0.8617493964660585
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - O3 with Weighted Predictions:
# MSE for LSTM_1: 620.3021588804779
# MSE for XGB_2: 20.588802271937556
# RMSE for XGB_2: 4.537488542347799
# R2 for XGB_2: 0.9625307615169192
# EVS for XGB_2: 0.9625414978459019
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهر.ری.منطقه20 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 329.0059613424885
# MSE for XGB_2: 58.35006473829096
# RMSE for XGB_2: 7.638721407296575
# R2 for XGB_2: 0.8155929432550673
# EVS for XGB_2: 0.8156063122001445
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 577.2851192773076
# MSE for XGB_2: 31.89620974444533
# RMSE for XGB_2: 5.647672949493918
# R2 for XGB_2: 0.9357151841789696
# EVS for XGB_2: 0.9357212342147299
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 454.4137254451126
# MSE for XGB_2: 34.011851155730476
# RMSE for XGB_2: 5.8319680345257785
# R2 for XGB_2: 0.9245790481839424
# EVS for XGB_2: 0.9246249479607939
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهر.ری.منطقه20 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 960.7913797393323
# MSE for XGB_2: 48.53490999185336
# RMSE for XGB_2: 6.966700079080006
# R2 for XGB_2: 0.9468069259884083
# EVS for XGB_2: 0.9468318104438092
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - AQI with Weighted Predictions:
# MSE for LSTM_1: 839.4906384430466
# MSE for XGB_2: 52.47412428673709
# RMSE for XGB_2: 7.243902559169131
# R2 for XGB_2: 0.9311706320252632
# EVS for XGB_2: 0.9312031745837566
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 120.80120417261763
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 61.23328495226456
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - CO with Weighted Predictions:
# MSE for LSTM_1: 261.86743178697805
# MSE for XGB_2: 28.911873280528223
# RMSE for XGB_2: 5.376976220937584
# R2 for XGB_2: 0.8587697482910741
# EVS for XGB_2: 0.8588328741532176
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - O3 with Weighted Predictions:
# MSE for LSTM_1: 883.3833734141245
# MSE for XGB_2: 44.414192960971256
# RMSE for XGB_2: 6.664397419194871
# R2 for XGB_2: 0.9501671585571645
# EVS for XGB_2: 0.9501672673984574
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه21 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 508.40017178430224
# MSE for XGB_2: 47.6492450974735
# RMSE for XGB_2: 6.9028432618359155
# R2 for XGB_2: 0.8364679410030039
# EVS for XGB_2: 0.8364766719684036
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 992.5620969324115
# MSE for XGB_2: 28.16899711969074
# RMSE for XGB_2: 5.3074473261343575
# R2 for XGB_2: 0.944805046637061
# EVS for XGB_2: 0.9448088042188446
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 1138.5071013424686
# MSE for XGB_2: 42.74966750541754
# RMSE for XGB_2: 6.538322988765357
# R2 for XGB_2: 0.9434032978408449
# EVS for XGB_2: 0.9434073316192426
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1100.9292650265322
# MSE for XGB_2: 41.34905530209809
# RMSE for XGB_2: 6.430323110240891
# R2 for XGB_2: 0.9584762319182044
# EVS for XGB_2: 0.9584823992112317
# 3/3 [==============================] - 0s 4ms/step
# Local Model Results for Node شهرداری.منطقه21 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1346.5822662388885
# MSE for XGB_2: 63.63568902238639
# RMSE for XGB_2: 7.977198068393839
# R2 for XGB_2: 0.9473609909246564
# EVS for XGB_2: 0.9473617379315991
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 133.13457472200759
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه21 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 62.213565853353956
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - CO with Weighted Predictions:
# MSE for LSTM_1: 153.80551422359528
# MSE for XGB_2: 20.824737994739557
# RMSE for XGB_2: 4.563412976571325
# R2 for XGB_2: 0.8554873676441679
# EVS for XGB_2: 0.8554891844086496
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - O3 with Weighted Predictions:
# MSE for LSTM_1: 975.3010244573312
# MSE for XGB_2: 29.61515038446704
# RMSE for XGB_2: 5.441980373399654
# R2 for XGB_2: 0.9701181096815746
# EVS for XGB_2: 0.9701181620833641
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 345.21834487681326
# MSE for XGB_2: 39.586949457833896
# RMSE for XGB_2: 6.291816069930358
# R2 for XGB_2: 0.8738835648526108
# EVS for XGB_2: 0.8738839296147227
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 298.61877134907826
# MSE for XGB_2: 24.883012731062436
# RMSE for XGB_2: 4.988287554969384
# R2 for XGB_2: 0.9114729767751627
# EVS for XGB_2: 0.9114753643622421
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه22 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 532.2967960725008
# MSE for XGB_2: 33.89302223388065
# RMSE for XGB_2: 5.821771400001949
# R2 for XGB_2: 0.8910605048468984
# EVS for XGB_2: 0.8910617470815873
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه22 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 916.2160589798468
# MSE for XGB_2: 49.07045885885528
# RMSE for XGB_2: 7.005030967729927
# R2 for XGB_2: 0.9433205866482002
# EVS for XGB_2: 0.9433300113647664
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - AQI with Weighted Predictions:
# MSE for LSTM_1: 943.6085874171113
# MSE for XGB_2: 40.81071296361031
# RMSE for XGB_2: 6.388326303783355
# R2 for XGB_2: 0.9412343539014297
# EVS for XGB_2: 0.9412526615549031
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 160.43567393958054
# MSE for XGB_2: 2.805644593656875
# RMSE for XGB_2: 1.6750058488425867
# R2 for XGB_2: 0.9765195778902295
# EVS for XGB_2: 0.9766686643560967
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه22 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 108.77647644308045
# MSE for XGB_2: 18.92772349635978
# RMSE for XGB_2: 4.350600360451391
# R2 for XGB_2: 0.6004555853684193
# EVS for XGB_2: 0.6004560825823506
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Global Model Results:
# Mean Squared Error (MSE) for Global Model: 10.059414891887815
# Duration of the program execution: 976.6258301734924 seconds
