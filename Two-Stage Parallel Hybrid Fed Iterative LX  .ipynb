# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
# Import the time module
import time

# Record the start time
start_time = time.time()

# Specify the folder path where the 22 files are located
folder_path = ''

# Initialize an empty list to store all the dataframes
all_dfs = []

# Loop through each file in the specified folder
for filename in os.listdir(folder_path):
    if filename.endswith(".xlsx"):
        file_path = os.path.join(folder_path, filename)
        
        # Read the Excel file into a dataframe
        df = pd.read_excel(file_path)
        
        # Convert 'iranidate' to datetime and handle missing values
        df['iranidate'] = pd.to_datetime(df['iranidate'], errors='coerce')
        
        def convert_to_numeric_date(date):
            base_date = datetime(2000, 1, 1)
            return (date - base_date).days
        df['iranidate'] = df['iranidate'].apply(convert_to_numeric_date)
        
        # Encode 'node' column
        label_encoder = LabelEncoder()
        df['node_encoded'] = label_encoder.fit_transform(df['node'])
        
        # Handling NaN values by finding the nearest non-empty cells in the same column
        for col in ['CO', 'O3', 'SO2', 'PM10', 'PM2.5', 'AQI']:
            for idx, value in df[col].items():
                if pd.isnull(value):  
                    upper_cell = df[col].iloc[:idx].last_valid_index()  
                    lower_cell = df[col].iloc[idx + 1:].first_valid_index()  
                    if upper_cell is not None and lower_cell is not None:  
                        avg = (df.at[upper_cell, col] + df.at[lower_cell, col]) / 2  
                        df.at[idx, col] = avg  
        
        # Append the modified dataframe to the list
        all_dfs.append(df)

# Concatenate all dataframes into a single dataframe
df = pd.concat(all_dfs, ignore_index=True)

your_threshold_value = 100
if len(df) < your_threshold_value:
    print("Insufficient samples in the dataset.")
else:
    output_columns = ['CO', 'O3', 'NO2', 'SO2', 'PM10', 'PM2.5', 'AQI', 'Highest tempreture: 12pm', 'Wind:km/h']
    unique_nodes = df['node'].unique()  

    # Dictionary to store weighted predictions for each node and column
    weighted_predictions = {}
    
    lstm_model = Sequential([
        LSTM(50, activation='relu', input_shape=(2, 1)),
        Dense(1)
    ])
    lstm_model.compile(optimizer='adam', loss='mse')
    xgb_model_2 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.3, max_depth=10, alpha=10, n_estimators=200)
    

    for node_value in unique_nodes:
        node_df = df[df['node'] == node_value]  
        
        # Dictionary to store predictions and true values for each column
        columns_data = {}

        for output_column in output_columns:
            if node_df[output_column].isnull().any():
                print(f"NaN values found in {output_column} for Node {node_value}. Handle missing values before modeling.")
            else:
                # Modify X to include the 'node' column along with 'iranidate'
                X = node_df[['iranidate', 'node_encoded']]
                Y = node_df[[output_column]]  
                X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

                # Reshape the input data for LSTM
                X_train_lstm = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
                X_test_lstm = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))

                lstm_model.fit(X_train_lstm, Y_train, epochs=50, batch_size=32, verbose=0)

                # Predict using the LSTM model
                Y1_pred_lstm = lstm_model.predict(X_test_lstm)

                # Flatten the LSTM predictions for input to XGBoost model
                Y1_pred_lstm_flat = Y1_pred_lstm.flatten()

                xgb_model_2.fit(np.concatenate((X_test, Y1_pred_lstm_flat.reshape(-1, 1)), axis=1), Y_test)
                Y2_pred_xgb = xgb_model_2.predict(np.concatenate((X_test, Y1_pred_lstm_flat.reshape(-1, 1)), axis=1))

                # Calculate errors for the third XGBoost model
                mse_lstm_1 = mean_squared_error(Y_test, Y1_pred_lstm)
                mse_xgb_2 = mean_squared_error(Y_test, Y2_pred_xgb)
                rmse_lstm_1 = np.sqrt(mse_lstm_1)
                rmse_xgb_2 = np.sqrt(mse_xgb_2)
                r2_xgb_2 = r2_score(Y_test, Y2_pred_xgb)
                evs_xgb_2 = explained_variance_score(Y_test, Y2_pred_xgb)

                # Store predictions and true values for each column in the dictionary
                columns_data[output_column] = (Y2_pred_xgb, Y_test)

                # Output results for the local model with weighted predictions
                print(f"Local Model Results for Node {node_value} - {output_column} with Weighted Predictions:")
                print(f"MSE for LSTM_1: {mse_lstm_1}")
                print(f"MSE for XGB_2: {mse_xgb_2}")
                print(f"RMSE for LSTM_1: {rmse_lstm_1}")
                print(f"RMSE for XGB_2: {rmse_xgb_2}")
                print(f"R2 for XGB_3: {r2_xgb_2}")
                print(f"EVS for XGB_3: {evs_xgb_2}")
                    
                # Store predictions and true values for each column in the dictionary
                columns_data[output_column] = (Y2_pred_xgb, Y_test)

                
                # Store weighted predictions for each node and column
                if node_value not in weighted_predictions:
                    weighted_predictions[node_value] = {output_column: (Y2_pred_xgb, Y_test)}
                else:
                    weighted_predictions[node_value][output_column] = (Y2_pred_xgb, Y_test)

# Aggregate predictions for the global model using weighted average
global_X_test = []
global_Y_test = []

for node, columns in weighted_predictions.items():
    for column, (node_prediction, Y_test) in columns.items():
        global_X_test.extend(node_prediction * r2_xgb_2)  # Apply weights using the R2 score from the third XGBoost model
        global_Y_test.extend(Y_test.values)

# Create and train the global model (Random Forest)
global_model = RandomForestRegressor(random_state=42)
global_model.fit(np.array(global_X_test).reshape(-1, 1), global_Y_test)  # Reshape for RF

# Predict using the global model
global_Y_pred = global_model.predict(np.array(global_X_test).reshape(-1, 1))
global_mse = mean_squared_error(global_Y_test, global_Y_pred)

# Print results for the global model
print("Global Model Results:")
print(f"Mean Squared Error (MSE) for Global Model: {global_mse}")

# Record the end time
end_time = time.time()

# Calculate the duration of the program execution
duration_seconds = end_time - start_time

# Print the duration of the program execution
print(f"Duration of the program execution: {duration_seconds} seconds")
# Out:
# 2024-03-04 19:17:27.930269: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 19 - CO with Weighted Predictions:
# MSE for LSTM_1: 272.890977905475
# MSE for XGB_2: 31.704891663599568
# RMSE for LSTM_1: 16.519412153750356
# RMSE for XGB_2: 5.63070969448786
# R2 for XGB_3: 0.8707827285500472
# EVS for XGB_3: 0.8708571587800322
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 19 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1119.5775013820482
# MSE for XGB_2: 18.741009798795158
# RMSE for LSTM_1: 33.460088185509136
# RMSE for XGB_2: 4.329088795438961
# R2 for XGB_3: 0.9830929748174869
# EVS for XGB_3: 0.9831085625145167
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 19 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 308.4835415203428
# MSE for XGB_2: 22.656403919641807
# RMSE for LSTM_1: 17.563699539685334
# RMSE for XGB_2: 4.759874359648772
# R2 for XGB_3: 0.9227205112593221
# EVS for XGB_3: 0.9227828028927234
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 19 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 183.9395959798761
# MSE for XGB_2: 24.46372762477046
# RMSE for LSTM_1: 13.562433261766714
# RMSE for XGB_2: 4.946082047921411
# R2 for XGB_3: 0.840521286541072
# EVS for XGB_3: 0.8405319760839582
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 19 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 1073.1459898345206
# MSE for XGB_2: 31.172252358038122
# RMSE for LSTM_1: 32.75890703052409
# RMSE for XGB_2: 5.5832116526277344
# R2 for XGB_3: 0.9692609953456338
# EVS for XGB_3: 0.9692790047167237
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 19 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1455.6137592866214
# MSE for XGB_2: 38.78219164546814
# RMSE for LSTM_1: 38.15250659244582
# RMSE for XGB_2: 6.22753495738628
# R2 for XGB_3: 0.9712182836916377
# EVS for XGB_3: 0.971218283692173
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 19 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1534.9575510314846
# MSE for XGB_2: 39.64890723542332
# RMSE for LSTM_1: 39.17853431448763
# RMSE for XGB_2: 6.296737824891816
# R2 for XGB_3: 0.9709390251110952
# EVS for XGB_3: 0.970939417818388
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 19 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 115.1746174534068
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.731943787283216
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 19 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 46.93261728757942
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.850738448341129
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 9 - CO with Weighted Predictions:
# MSE for LSTM_1: 369.7875680915616
# MSE for XGB_2: 22.069914629058996
# RMSE for LSTM_1: 19.22986136433546
# RMSE for XGB_2: 4.697862772480588
# R2 for XGB_3: 0.9387628423332444
# EVS for XGB_3: 0.9387840973361153
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 9 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1136.1537313946744
# MSE for XGB_2: 19.938924799148555
# RMSE for LSTM_1: 33.70687958554862
# RMSE for XGB_2: 4.465302318897183
# R2 for XGB_3: 0.982575031264168
# EVS for XGB_3: 0.9825908471712226
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 9 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 470.83392949277186
# MSE for XGB_2: 33.446616370873755
# RMSE for LSTM_1: 21.698708014367394
# RMSE for XGB_2: 5.783304969554498
# R2 for XGB_3: 0.9261936758023313
# EVS for XGB_3: 0.9262339770695447
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 9 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 320.9836651026977
# MSE for XGB_2: 24.08582366917911
# RMSE for LSTM_1: 17.91601699883927
# RMSE for XGB_2: 4.907731010271356
# R2 for XGB_3: 0.92348737215676
# EVS for XGB_3: 0.923493186908557
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 9 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 480.66838073933485
# MSE for XGB_2: 30.70816565464953
# RMSE for LSTM_1: 21.924150627546208
# RMSE for XGB_2: 5.541494893496657
# R2 for XGB_3: 0.932650198028774
# EVS for XGB_3: 0.9326501980515154
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 9 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 876.9243860538734
# MSE for XGB_2: 26.388368287200596
# RMSE for LSTM_1: 29.61290911163362
# RMSE for XGB_2: 5.136960997243467
# R2 for XGB_3: 0.9685821302696156
# EVS for XGB_3: 0.9685821302783635
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 9 - AQI with Weighted Predictions:
# MSE for LSTM_1: 566.8184554125805
# MSE for XGB_2: 39.637849447119834
# RMSE for LSTM_1: 23.807949416373106
# RMSE for XGB_2: 6.295859706753307
# R2 for XGB_3: 0.9300931239288751
# EVS for XGB_3: 0.930094703359615
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 9 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 121.59436807429105
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 11.026983634443784
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 9 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.377220737965736
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.9553735153452205
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 15 - CO with Weighted Predictions:
# MSE for LSTM_1: 73.92836174837637
# MSE for XGB_2: 15.944261195352198
# RMSE for LSTM_1: 8.598160370008015
# RMSE for XGB_2: 3.9930265708297257
# R2 for XGB_3: 0.7101634337098552
# EVS for XGB_3: 0.7102965090535429
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 15 - O3 with Weighted Predictions:
# MSE for LSTM_1: 962.6350777328657
# MSE for XGB_2: 21.724928487884576
# RMSE for LSTM_1: 31.026361013384502
# RMSE for XGB_2: 4.661000803248651
# R2 for XGB_3: 0.9778529032548949
# EVS for XGB_3: 0.9778529032635694
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 15 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 307.433392455346
# MSE for XGB_2: 42.148850230364125
# RMSE for LSTM_1: 17.53377861316111
# RMSE for XGB_2: 6.492214585976354
# R2 for XGB_3: 0.8606269848726442
# EVS for XGB_3: 0.860687374947179
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 15 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 271.52230315342103
# MSE for XGB_2: 23.5501940708953
# RMSE for LSTM_1: 16.4779338253745
# RMSE for XGB_2: 4.852854219003008
# R2 for XGB_3: 0.9080844890532305
# EVS for XGB_3: 0.9081336420990285
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 15 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 357.4542285105746
# MSE for XGB_2: 19.662628833263728
# RMSE for LSTM_1: 18.906459967708777
# RMSE for XGB_2: 4.434256288631018
# R2 for XGB_3: 0.946246758521586
# EVS for XGB_3: 0.9462587082649594
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 15 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 683.4591492396693
# MSE for XGB_2: 26.160394152905532
# RMSE for LSTM_1: 26.143051643594887
# RMSE for XGB_2: 5.1147232723682645
# R2 for XGB_3: 0.959996593005912
# EVS for XGB_3: 0.9599965930187087
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 15 - AQI with Weighted Predictions:
# MSE for LSTM_1: 591.5715234500216
# MSE for XGB_2: 30.816109339268074
# RMSE for LSTM_1: 24.32224338851212
# RMSE for XGB_2: 5.551225931203672
# R2 for XGB_3: 0.9467091770200949
# EVS for XGB_3: 0.9467251498049081
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 15 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.4647116556472
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.791881747667883
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 15 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 51.347595753314266
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 7.165723672687516
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 5 - CO with Weighted Predictions:
# MSE for LSTM_1: 134.51718686060983
# MSE for XGB_2: 18.976083450593674
# RMSE for LSTM_1: 11.598154459249534
# RMSE for XGB_2: 4.356154663300383
# R2 for XGB_3: 0.8531497172153724
# EVS for XGB_3: 0.8532627606504046
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 5 - O3 with Weighted Predictions:
# MSE for LSTM_1: 408.1574483991665
# MSE for XGB_2: 21.134038580412792
# RMSE for LSTM_1: 20.202906929428906
# RMSE for XGB_2: 4.597177240482772
# R2 for XGB_3: 0.9448814838507963
# EVS for XGB_3: 0.9449282643877807
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 5 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 320.0977447112556
# MSE for XGB_2: 36.69136580102004
# RMSE for LSTM_1: 17.89127565913777
# RMSE for XGB_2: 6.057339828754867
# R2 for XGB_3: 0.8778547886353788
# EVS for XGB_3: 0.8778547886405387
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 5 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 299.94368475219903
# MSE for XGB_2: 19.038852847238765
# RMSE for LSTM_1: 17.318882318215543
# RMSE for XGB_2: 4.363353394722775
# R2 for XGB_3: 0.9345044947297525
# EVS for XGB_3: 0.9345598321523794
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 5 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 271.8494764465676
# MSE for XGB_2: 25.25348721002623
# RMSE for LSTM_1: 16.487858455438282
# RMSE for XGB_2: 5.0252847889474115
# R2 for XGB_3: 0.9005191797202311
# EVS for XGB_3: 0.9005191797527011
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 5 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 787.2587978675099
# MSE for XGB_2: 37.346205476369995
# RMSE for LSTM_1: 28.058132472912554
# RMSE for XGB_2: 6.111154185288569
# R2 for XGB_3: 0.9513740885277095
# EVS for XGB_3: 0.9513912149360229
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 5 - AQI with Weighted Predictions:
# MSE for LSTM_1: 477.1360387865402
# MSE for XGB_2: 34.58616095609227
# RMSE for LSTM_1: 21.843443839892558
# RMSE for XGB_2: 5.8809999962669846
# R2 for XGB_3: 0.9261367967565285
# EVS for XGB_3: 0.9261367967570913
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 5 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 119.10790483937392
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.913656804177686
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 5 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.783022881154565
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.984484439180502
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 4 - CO with Weighted Predictions:
# MSE for LSTM_1: 162.9446581342544
# MSE for XGB_2: 26.195421835039713
# RMSE for LSTM_1: 12.764977796073694
# RMSE for XGB_2: 5.118146328021475
# R2 for XGB_3: 0.8259736272808329
# EVS for XGB_3: 0.8260949509325126
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 4 - O3 with Weighted Predictions:
# MSE for LSTM_1: 509.8175370097892
# MSE for XGB_2: 27.673352218212806
# RMSE for LSTM_1: 22.579139421372755
# RMSE for XGB_2: 5.260546760386491
# R2 for XGB_3: 0.9450985677286006
# EVS for XGB_3: 0.9450985677465398
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 4 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 683.1340315548961
# MSE for XGB_2: 31.705543843486204
# RMSE for LSTM_1: 26.13683285241148
# RMSE for XGB_2: 5.630767606950779
# R2 for XGB_3: 0.9517010851670046
# EVS for XGB_3: 0.9517010851736663
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 4 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 58.247366326544814
# MSE for XGB_2: 16.50130982159493
# RMSE for LSTM_1: 7.6319962216018435
# RMSE for XGB_2: 4.062180427011451
# R2 for XGB_3: 0.7113367598142117
# EVS for XGB_3: 0.7113422220616841
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 4 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 346.3379664791141
# MSE for XGB_2: 23.967004009382627
# RMSE for LSTM_1: 18.610157615644045
# RMSE for XGB_2: 4.895610688094247
# R2 for XGB_3: 0.92952090932349
# EVS for XGB_3: 0.9295743608315052
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 4 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1535.5832396489732
# MSE for XGB_2: 36.083289374387135
# RMSE for LSTM_1: 39.186518595672325
# RMSE for XGB_2: 6.006936771299256
# R2 for XGB_3: 0.9755112426874776
# EVS for XGB_3: 0.9755112426878243
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 4 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1501.4002692596862
# MSE for XGB_2: 36.09436824980042
# RMSE for LSTM_1: 38.747906643581224
# RMSE for XGB_2: 6.007858873991667
# R2 for XGB_3: 0.9749892390679946
# EVS for XGB_3: 0.974989239068046
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 4 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 117.21631794123445
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.826648509175609
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 4 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 49.059646576815894
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 7.004259174018041
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 14 - CO with Weighted Predictions:
# MSE for LSTM_1: 81.22889874149516
# MSE for XGB_2: 25.057832064077417
# RMSE for LSTM_1: 9.012707625430615
# RMSE for XGB_2: 5.005779865722964
# R2 for XGB_3: 0.6867523644221253
# EVS for XGB_3: 0.6869806576272004
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 14 - O3 with Weighted Predictions:
# MSE for LSTM_1: 849.9021465992231
# MSE for XGB_2: 19.55992357963245
# RMSE for LSTM_1: 29.15308125394678
# RMSE for XGB_2: 4.422660237869562
# R2 for XGB_3: 0.9763869022427154
# EVS for XGB_3: 0.9764068725944317
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 14 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 468.0632168037085
# MSE for XGB_2: 23.35864351552321
# RMSE for LSTM_1: 21.63476870233903
# RMSE for XGB_2: 4.833078058082986
# R2 for XGB_3: 0.947896189682696
# EVS for XGB_3: 0.9479369256851385
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 14 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 226.35382658162746
# MSE for XGB_2: 18.94445735952005
# RMSE for LSTM_1: 15.045059872982476
# RMSE for XGB_2: 4.352523102698026
# R2 for XGB_3: 0.9134812069679815
# EVS for XGB_3: 0.9135317496201496
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 14 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 364.33084624513356
# MSE for XGB_2: 23.959481285930625
# RMSE for LSTM_1: 19.087452586585083
# RMSE for XGB_2: 4.894842314715626
# R2 for XGB_3: 0.9319280520331771
# EVS for XGB_3: 0.9319280520679142
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 14 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1518.1298325147802
# MSE for XGB_2: 31.150039116857204
# RMSE for LSTM_1: 38.96318560532211
# RMSE for XGB_2: 5.581222009278721
# R2 for XGB_3: 0.978790973859958
# EVS for XGB_3: 0.9787909738649306
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 14 - AQI with Weighted Predictions:
# MSE for LSTM_1: 563.968304149872
# MSE for XGB_2: 31.237117818133413
# RMSE for LSTM_1: 23.748016846673156
# RMSE for XGB_2: 5.589017607606315
# R2 for XGB_3: 0.9441770631647078
# EVS for XGB_3: 0.9441798609177703
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 14 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.870361556776
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.810659626349171
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 14 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.17587050269941
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.868469298373504
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 22 - CO with Weighted Predictions:
# MSE for LSTM_1: 149.84669753419402
# MSE for XGB_2: 20.057936980346494
# RMSE for LSTM_1: 12.241188567054836
# RMSE for XGB_2: 4.478608821983284
# R2 for XGB_3: 0.8608085598296856
# EVS for XGB_3: 0.8608085598821551
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 22 - O3 with Weighted Predictions:
# MSE for LSTM_1: 988.584100955523
# MSE for XGB_2: 20.501247856659276
# RMSE for LSTM_1: 31.441757281607575
# RMSE for XGB_2: 4.52783036968693
# R2 for XGB_3: 0.9793140999829311
# EVS for XGB_3: 0.9793319514973576
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 22 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 324.94145399864334
# MSE for XGB_2: 33.25966731123422
# RMSE for LSTM_1: 18.026132530264036
# RMSE for XGB_2: 5.767119498608834
# R2 for XGB_3: 0.8940410733100592
# EVS for XGB_3: 0.8940410733100592
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 22 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 284.0982871641836
# MSE for XGB_2: 19.279509267701936
# RMSE for LSTM_1: 16.855215429183442
# RMSE for XGB_2: 4.39084379905525
# R2 for XGB_3: 0.9314087251751995
# EVS for XGB_3: 0.9314625861524789
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 22 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 314.9448980866708
# MSE for XGB_2: 26.418912664260052
# RMSE for LSTM_1: 17.746686960857534
# RMSE for XGB_2: 5.1399331381118225
# R2 for XGB_3: 0.9150839075878763
# EVS for XGB_3: 0.9150839076242743
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 22 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 897.7655141838607
# MSE for XGB_2: 31.982813319468455
# RMSE for LSTM_1: 29.962735425589244
# RMSE for XGB_2: 5.655334943172549
# R2 for XGB_3: 0.9630578735466528
# EVS for XGB_3: 0.9630578735480625
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 22 - AQI with Weighted Predictions:
# MSE for LSTM_1: 732.293828642802
# MSE for XGB_2: 25.260538986448484
# RMSE for LSTM_1: 27.06092808169746
# RMSE for XGB_2: 5.025986369504844
# R2 for XGB_3: 0.9636259259753582
# EVS for XGB_3: 0.9636259259911115
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 22 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 115.61462557617627
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.752424172072839
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 22 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.43614209451614
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.95960789804398
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - CO with Weighted Predictions:
# MSE for LSTM_1: 82.06639540756309
# MSE for XGB_2: 20.019740481694893
# RMSE for LSTM_1: 9.059050469423553
# RMSE for XGB_2: 4.474342463613496
# R2 for XGB_3: 0.7362413182775321
# EVS for XGB_3: 0.7364819176709322
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1973.0882416511763
# MSE for XGB_2: 22.87195656667228
# RMSE for LSTM_1: 44.4194579171243
# RMSE for XGB_2: 4.7824634412269456
# R2 for XGB_3: 0.988141115736362
# EVS for XGB_3: 0.988146011969241
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 266.74782615820016
# MSE for XGB_2: 36.34278609112086
# RMSE for LSTM_1: 16.33241642128317
# RMSE for XGB_2: 6.028497830398619
# R2 for XGB_3: 0.8609796156958273
# EVS for XGB_3: 0.8609821014190995
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 231.07251639291118
# MSE for XGB_2: 14.053804699007422
# RMSE for LSTM_1: 15.201069580556204
# RMSE for XGB_2: 3.7488404472593153
# R2 for XGB_3: 0.9377630390481455
# EVS for XGB_3: 0.9377630391025729
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 292.79382658663206
# MSE for XGB_2: 28.23347674304631
# RMSE for LSTM_1: 17.111219319108503
# RMSE for XGB_2: 5.313518301751327
# R2 for XGB_3: 0.901206887916109
# EVS for XGB_3: 0.901270463830178
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 843.5220489526897
# MSE for XGB_2: 27.194166761594442
# RMSE for LSTM_1: 29.04345105101475
# RMSE for XGB_2: 5.21480265797225
# R2 for XGB_3: 0.9659266387665687
# EVS for XGB_3: 0.965949228311063
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - AQI with Weighted Predictions:
# MSE for LSTM_1: 922.5190043624391
# MSE for XGB_2: 35.94584051697025
# RMSE for LSTM_1: 30.37299794821774
# RMSE for XGB_2: 5.995485010987038
# R2 for XGB_3: 0.9611214232130346
# EVS for XGB_3: 0.9611410610257111
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 117.09531094886252
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.821058679670049
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 8 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.726363960848225
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.908427025079459
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - CO with Weighted Predictions:
# MSE for LSTM_1: 391.41266879972665
# MSE for XGB_2: 33.861238126792955
# RMSE for LSTM_1: 19.78415196059024
# RMSE for XGB_2: 5.819040997174101
# R2 for XGB_3: 0.9103136872903609
# EVS for XGB_3: 0.9103609454440331
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1801.5725786829064
# MSE for XGB_2: 28.49802330254355
# RMSE for LSTM_1: 42.44493584260561
# RMSE for XGB_2: 5.3383539881262605
# R2 for XGB_3: 0.9843727772999032
# EVS for XGB_3: 0.9843825780863694
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 511.9685781493122
# MSE for XGB_2: 29.86152236989489
# RMSE for LSTM_1: 22.62672265595069
# RMSE for XGB_2: 5.464569733281376
# R2 for XGB_3: 0.9434751832587618
# EVS for XGB_3: 0.9434751832778461
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 606.9468886180952
# MSE for XGB_2: 27.688178800664158
# RMSE for LSTM_1: 24.636292103685065
# RMSE for XGB_2: 5.261955796152621
# R2 for XGB_3: 0.952170204026916
# EVS for XGB_3: 0.9521982381480684
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 445.27056628275733
# MSE for XGB_2: 28.891031338360335
# RMSE for LSTM_1: 21.10143517116211
# RMSE for XGB_2: 5.375037798784334
# R2 for XGB_3: 0.9347658723900152
# EVS for XGB_3: 0.9347720241859206
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1095.728221126841
# MSE for XGB_2: 40.61988299712143
# RMSE for LSTM_1: 33.1017857694542
# RMSE for XGB_2: 6.373372968618848
# R2 for XGB_3: 0.9608981955684451
# EVS for XGB_3: 0.9608981955730829
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1089.0309536573175
# MSE for XGB_2: 42.292955943314055
# RMSE for LSTM_1: 33.000468991475216
# RMSE for XGB_2: 6.503303463880035
# R2 for XGB_3: 0.9596289076872427
# EVS for XGB_3: 0.9596289539810315
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.757932041148
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.805458437343045
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 18 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.37486225571917
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.955203969382866
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 13 - CO with Weighted Predictions:
# MSE for LSTM_1: 97.17198289733211
# MSE for XGB_2: 23.542418828267387
# RMSE for LSTM_1: 9.857585043880277
# RMSE for XGB_2: 4.852053052911456
# R2 for XGB_3: 0.7551811993936497
# EVS for XGB_3: 0.7553711099996977
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 13 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1457.1911107031199
# MSE for XGB_2: 20.26943143831933
# RMSE for LSTM_1: 38.17317265702603
# RMSE for XGB_2: 4.502158531007025
# R2 for XGB_3: 0.9862376827222267
# EVS for XGB_3: 0.986249545636058
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 13 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 229.705514751793
# MSE for XGB_2: 31.917994410182953
# RMSE for LSTM_1: 15.15603888724864
# RMSE for XGB_2: 5.649601261167283
# R2 for XGB_3: 0.8594593227589564
# EVS for XGB_3: 0.8594667650703459
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 13 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 116.30928439120466
# MSE for XGB_2: 18.07048277397863
# RMSE for LSTM_1: 10.78467822381385
# RMSE for XGB_2: 4.250939046137763
# R2 for XGB_3: 0.8407929143921982
# EVS for XGB_3: 0.8407938334494365
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 13 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 356.86982194728205
# MSE for XGB_2: 23.47445354169987
# RMSE for LSTM_1: 18.890998437014442
# RMSE for XGB_2: 4.845044224947784
# R2 for XGB_3: 0.9340949967012107
# EVS for XGB_3: 0.934094996713034
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 13 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 964.3641369905057
# MSE for XGB_2: 27.221549319846318
# RMSE for LSTM_1: 31.054212870245248
# RMSE for XGB_2: 5.21742746186723
# R2 for XGB_3: 0.9704506709102614
# EVS for XGB_3: 0.9704703929847871
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 13 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1196.6000237353837
# MSE for XGB_2: 30.285820000380866
# RMSE for LSTM_1: 34.59190691094354
# RMSE for XGB_2: 5.503255400250007
# R2 for XGB_3: 0.9743207418384596
# EVS for XGB_3: 0.9743361901121942
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 13 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.36400469047234
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.787214871804137
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 13 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.1111822748119
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.936222478756856
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 3 - CO with Weighted Predictions:
# MSE for LSTM_1: 94.12489289615883
# MSE for XGB_2: 20.427369977884215
# RMSE for LSTM_1: 9.701798436174544
# RMSE for XGB_2: 4.5196648081339195
# R2 for XGB_3: 0.7722637809225714
# EVS for XGB_3: 0.7722915243755369
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 3 - O3 with Weighted Predictions:
# MSE for LSTM_1: 991.8122958490297
# MSE for XGB_2: 22.938674467275128
# RMSE for LSTM_1: 31.493051548699274
# RMSE for XGB_2: 4.789433626982958
# R2 for XGB_3: 0.9770272366796321
# EVS for XGB_3: 0.9770447345078704
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 3 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 200.5492205594724
# MSE for XGB_2: 28.52529206672413
# RMSE for LSTM_1: 14.161540190229042
# RMSE for XGB_2: 5.340907419785904
# R2 for XGB_3: 0.8523102845886977
# EVS for XGB_3: 0.8523108085672639
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 3 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 169.56554758309574
# MSE for XGB_2: 15.328369134237523
# RMSE for LSTM_1: 13.021733662730771
# RMSE for XGB_2: 3.9151461191426207
# R2 for XGB_3: 0.9073300423198205
# EVS for XGB_3: 0.9074151385432178
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 3 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 235.25044430795168
# MSE for XGB_2: 25.461299641718615
# RMSE for LSTM_1: 15.337876134196406
# RMSE for XGB_2: 5.045919107726422
# R2 for XGB_3: 0.8869170456237002
# EVS for XGB_3: 0.8869542626514031
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 3 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 826.2263559652508
# MSE for XGB_2: 25.85098412829632
# RMSE for LSTM_1: 28.74415342230922
# RMSE for XGB_2: 5.084386307932976
# R2 for XGB_3: 0.9675727032496322
# EVS for XGB_3: 0.9675953907249307
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 3 - AQI with Weighted Predictions:
# MSE for LSTM_1: 703.1977525901789
# MSE for XGB_2: 25.92223392190864
# RMSE for LSTM_1: 26.517876095007665
# RMSE for XGB_2: 5.091388211667682
# R2 for XGB_3: 0.9618154168219644
# EVS for XGB_3: 0.9618411556474994
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 3 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.68957982135686
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.80229511823098
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 3 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.05180072242862
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.931940617347253
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 2 - CO with Weighted Predictions:
# MSE for LSTM_1: 172.0147207164352
# MSE for XGB_2: 25.95412771894022
# RMSE for LSTM_1: 13.115438258649048
# RMSE for XGB_2: 5.094519380563805
# R2 for XGB_3: 0.8446173252726467
# EVS for XGB_3: 0.8447158728903988
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 2 - O3 with Weighted Predictions:
# MSE for LSTM_1: 546.8451699285213
# MSE for XGB_2: 19.554797548512518
# RMSE for LSTM_1: 23.384720864883576
# RMSE for XGB_2: 4.4220806809139654
# R2 for XGB_3: 0.9628206149128055
# EVS for XGB_3: 0.9628310879931681
# 3/3 [==============================] - 0s 4ms/step
# Local Model Results for Node District 2 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 555.0343988294268
# MSE for XGB_2: 27.21007099009915
# RMSE for LSTM_1: 23.55916804196249
# RMSE for XGB_2: 5.216327346907894
# R2 for XGB_3: 0.9481445440248377
# EVS for XGB_3: 0.9481445446470156
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 2 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 200.8066827187181
# MSE for XGB_2: 18.506079503068676
# RMSE for LSTM_1: 14.170627463832295
# RMSE for XGB_2: 4.301869303345777
# R2 for XGB_3: 0.9045090517657995
# EVS for XGB_3: 0.9046032824392661
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 2 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 605.8286037932935
# MSE for XGB_2: 29.10785039075307
# RMSE for LSTM_1: 24.6135857565145
# RMSE for XGB_2: 5.395169171652829
# R2 for XGB_3: 0.9521434290487947
# EVS for XGB_3: 0.9521734321696536
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 2 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 805.9941048095792
# MSE for XGB_2: 27.820777848749923
# RMSE for LSTM_1: 28.390035308353866
# RMSE for XGB_2: 5.274540534373579
# R2 for XGB_3: 0.9642633943149127
# EVS for XGB_3: 0.9642868303542782
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 2 - AQI with Weighted Predictions:
# MSE for LSTM_1: 895.7984609864307
# MSE for XGB_2: 25.83938929205131
# RMSE for LSTM_1: 29.92989243192215
# RMSE for XGB_2: 5.083245940543435
# R2 for XGB_3: 0.9706611186615514
# EVS for XGB_3: 0.9706816754977524
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 2 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 117.20031249998593
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.825909315156206
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 2 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.870372198191134
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.918841824914856
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 12 - CO with Weighted Predictions:
# MSE for LSTM_1: 92.514027931225
# MSE for XGB_2: 23.497114456907944
# RMSE for LSTM_1: 9.618421280606553
# RMSE for XGB_2: 4.847382227234402
# R2 for XGB_3: 0.7383296866913058
# EVS for XGB_3: 0.738447775484101
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 12 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1032.6790207123072
# MSE for XGB_2: 25.808383928912416
# RMSE for LSTM_1: 32.135323566323514
# RMSE for XGB_2: 5.080195264840951
# R2 for XGB_3: 0.9750718240008143
# EVS for XGB_3: 0.9750793996220378
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 12 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 653.2749240348707
# MSE for XGB_2: 29.731593915457882
# RMSE for LSTM_1: 25.55924341671464
# RMSE for XGB_2: 5.452668513256412
# R2 for XGB_3: 0.9532565643447408
# EVS for XGB_3: 0.9532565643547675
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 12 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 111.6459077292245
# MSE for XGB_2: 16.937227003249507
# RMSE for LSTM_1: 10.566262713430161
# RMSE for XGB_2: 4.1154862414117614
# R2 for XGB_3: 0.8469765501633504
# EVS for XGB_3: 0.846981195986587
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 12 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 356.31451926639147
# MSE for XGB_2: 22.47060403484708
# RMSE for LSTM_1: 18.876295167918716
# RMSE for XGB_2: 4.7403168707215215
# R2 for XGB_3: 0.9369284043402241
# EVS for XGB_3: 0.9369284043606594
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 12 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1176.7379626289999
# MSE for XGB_2: 26.09317516958427
# RMSE for LSTM_1: 34.303614425144765
# RMSE for XGB_2: 5.10814791970478
# R2 for XGB_3: 0.977057724424898
# EVS for XGB_3: 0.9770630026951101
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 12 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1146.0295531959437
# MSE for XGB_2: 30.132404181780018
# RMSE for LSTM_1: 33.853058254697515
# RMSE for XGB_2: 5.4892990610623515
# R2 for XGB_3: 0.9728586091811562
# EVS for XGB_3: 0.9728739289500588
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 12 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.41999971932051
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.789809994588436
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 12 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.18092166242791
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.941247846203729
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 1 - CO with Weighted Predictions:
# MSE for LSTM_1: 83.06091258616858
# MSE for XGB_2: 26.858201952099517
# RMSE for LSTM_1: 9.113775978493688
# RMSE for XGB_2: 5.182489937481742
# R2 for XGB_3: 0.6674916521729484
# EVS for XGB_3: 0.6675152536240067
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 1 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1220.9022056917745
# MSE for XGB_2: 24.043527428772617
# RMSE for LSTM_1: 34.94141104322741
# RMSE for XGB_2: 4.903419972710131
# R2 for XGB_3: 0.9803066700037945
# EVS for XGB_3: 0.9803215199735952
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 1 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 626.3905672826369
# MSE for XGB_2: 32.68788225736516
# RMSE for LSTM_1: 25.02779589341892
# RMSE for XGB_2: 5.717331742811953
# R2 for XGB_3: 0.94621247344702
# EVS for XGB_3: 0.9462124734496268
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 1 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 74.70603065649517
# MSE for XGB_2: 14.186099354504567
# RMSE for LSTM_1: 8.643265046063043
# RMSE for XGB_2: 3.766443860527403
# R2 for XGB_3: 0.8080478801428433
# EVS for XGB_3: 0.8080769510850834
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 1 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 231.22222599346006
# MSE for XGB_2: 25.461299641718615
# RMSE for LSTM_1: 15.205993094614374
# RMSE for XGB_2: 5.045919107726422
# R2 for XGB_3: 0.8869170456237002
# EVS for XGB_3: 0.8869542626514031
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 1 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 845.7825777046658
# MSE for XGB_2: 30.315046560142473
# RMSE for LSTM_1: 29.082341338081186
# RMSE for XGB_2: 5.5059101482082395
# R2 for XGB_3: 0.9627260619976287
# EVS for XGB_3: 0.9627484289032189
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 1 - AQI with Weighted Predictions:
# MSE for LSTM_1: 785.086245655405
# MSE for XGB_2: 30.209083396049135
# RMSE for LSTM_1: 28.019390529692203
# RMSE for XGB_2: 5.4962790500527845
# R2 for XGB_3: 0.9590228216650172
# EVS for XGB_3: 0.9590317571146205
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 1 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.57105821207365
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.796807778786915
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 1 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.65539083806893
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.975341628771234
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 11 - CO with Weighted Predictions:
# MSE for LSTM_1: 383.4189755158639
# MSE for XGB_2: 21.63017067742032
# RMSE for LSTM_1: 19.58108718932286
# RMSE for XGB_2: 4.650824730885945
# R2 for XGB_3: 0.9399269132997412
# EVS for XGB_3: 0.9399776169845262
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 11 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1748.335141692156
# MSE for XGB_2: 23.55415993528669
# RMSE for LSTM_1: 41.81309772896713
# RMSE for XGB_2: 4.8532628133335916
# R2 for XGB_3: 0.9866003860525094
# EVS for XGB_3: 0.9866003860563588
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 11 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 425.8512325496584
# MSE for XGB_2: 36.55020021315106
# RMSE for LSTM_1: 20.63616322259684
# RMSE for XGB_2: 6.045676158474836
# R2 for XGB_3: 0.9124872175741621
# EVS for XGB_3: 0.912530698644312
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 11 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 30.846299201389524
# MSE for XGB_2: 8.063389793914885
# RMSE for LSTM_1: 5.5539444722998015
# RMSE for XGB_2: 2.8396108525491455
# R2 for XGB_3: 0.7285608300845143
# EVS for XGB_3: 0.7291755828449449
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 11 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 340.5170170647916
# MSE for XGB_2: 22.856085413953604
# RMSE for LSTM_1: 18.453103182521676
# RMSE for XGB_2: 4.7808038460026365
# R2 for XGB_3: 0.9324596513382627
# EVS for XGB_3: 0.9324596513724271
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 11 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1297.7827795275055
# MSE for XGB_2: 30.403563565519256
# RMSE for LSTM_1: 36.02475231736515
# RMSE for XGB_2: 5.513942651634967
# R2 for XGB_3: 0.9750107998479344
# EVS for XGB_3: 0.9750107998539673
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 11 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1213.856079000313
# MSE for XGB_2: 33.879215100746414
# RMSE for LSTM_1: 34.84043741115075
# RMSE for XGB_2: 5.820585460307787
# R2 for XGB_3: 0.9714124534390096
# EVS for XGB_3: 0.9714124534472567
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 11 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 117.28784585472793
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.829951332057218
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 11 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.239991017332734
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.945501495020553
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 10 - CO with Weighted Predictions:
# MSE for LSTM_1: 95.21107300422811
# MSE for XGB_2: 19.722266255088737
# RMSE for LSTM_1: 9.757616153765637
# RMSE for XGB_2: 4.440975822394075
# R2 for XGB_3: 0.7806694139398712
# EVS for XGB_3: 0.7808725051794894
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 10 - O3 with Weighted Predictions:
# MSE for LSTM_1: 992.0733562111574
# MSE for XGB_2: 21.861544728312175
# RMSE for LSTM_1: 31.497196005536072
# RMSE for XGB_2: 4.675633083156994
# R2 for XGB_3: 0.9780421055355618
# EVS for XGB_3: 0.9780421055480445
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 10 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 191.8211247308858
# MSE for XGB_2: 28.40627156619886
# RMSE for LSTM_1: 13.849950351206527
# RMSE for XGB_2: 5.3297534245215195
# R2 for XGB_3: 0.8463751988951318
# EVS for XGB_3: 0.8463759840756427
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 10 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 230.88538392027357
# MSE for XGB_2: 21.60447748027459
# RMSE for LSTM_1: 15.194913093541324
# RMSE for XGB_2: 4.648061690670057
# R2 for XGB_3: 0.9046005804481555
# EVS for XGB_3: 0.9046722833516785
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 10 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 341.0026380041475
# MSE for XGB_2: 22.907023559399466
# RMSE for LSTM_1: 18.46625674044817
# RMSE for XGB_2: 4.786128243099998
# R2 for XGB_3: 0.9322053272201914
# EVS for XGB_3: 0.9322053276377167
# 3/3 [==============================] - 0s 4ms/step
# Local Model Results for Node District 10 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1191.1462830127705
# MSE for XGB_2: 28.302837659720648
# RMSE for LSTM_1: 34.51298716443957
# RMSE for XGB_2: 5.320041133273374
# R2 for XGB_3: 0.9753558764485525
# EVS for XGB_3: 0.9753700590350599
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 10 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1324.7126167534711
# MSE for XGB_2: 31.298350726164465
# RMSE for LSTM_1: 36.39660171985114
# RMSE for XGB_2: 5.59449289267262
# R2 for XGB_3: 0.9760312459306774
# EVS for XGB_3: 0.9760449311031116
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 10 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.8374102198486
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.809135498264817
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 10 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.24425244345558
# ...
# MSE for LSTM_1: 116.29947977682679
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.784223652021817
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 21 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.03604194921413
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.930803845818617
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 7 - CO with Weighted Predictions:
# MSE for LSTM_1: 95.1795916612096
# MSE for XGB_2: 19.78449100416765
# RMSE for LSTM_1: 9.756002852665102
# RMSE for XGB_2: 4.447976057058721
# R2 for XGB_3: 0.7795134580321079
# EVS for XGB_3: 0.7797169779139449
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 7 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1262.1953129793699
# MSE for XGB_2: 26.22111739379139
# RMSE for LSTM_1: 35.52738820937123
# RMSE for XGB_2: 5.120655953468402
# R2 for XGB_3: 0.979432781746924
# EVS for XGB_3: 0.9794327817555158
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 7 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 272.7648563050584
# MSE for XGB_2: 36.52231724177793
# RMSE for LSTM_1: 16.515594337021554
# RMSE for XGB_2: 6.043369692628271
# R2 for XGB_3: 0.8640709685994932
# EVS for XGB_3: 0.8641389406419653
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 7 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 127.96769884822714
# MSE for XGB_2: 15.260020571731456
# RMSE for LSTM_1: 11.312280886197405
# RMSE for XGB_2: 3.9064076300011825
# R2 for XGB_3: 0.8787751897577721
# EVS for XGB_3: 0.8788020718752881
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 7 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 289.440373955507
# MSE for XGB_2: 21.971770913273893
# RMSE for LSTM_1: 17.012947244834066
# RMSE for XGB_2: 4.687405563131261
# R2 for XGB_3: 0.9208718830598057
# EVS for XGB_3: 0.9208718830971939
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 7 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1120.7267744767887
# MSE for XGB_2: 32.36191555144505
# RMSE for LSTM_1: 33.47725757102557
# RMSE for XGB_2: 5.68875342684538
# R2 for XGB_3: 0.9703714378189282
# EVS for XGB_3: 0.9703768313100284
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 7 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1033.1161868058348
# MSE for XGB_2: 36.02879717787319
# RMSE for LSTM_1: 32.14212480228765
# RMSE for XGB_2: 6.002399285108679
# R2 for XGB_3: 0.9645970323817352
# EVS for XGB_3: 0.9646149519903989
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 7 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 117.43283686504297
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.836643247105764
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 7 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.10667194660955
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.9358973425656725
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 17 - CO with Weighted Predictions:
# MSE for LSTM_1: 125.11848256667629
# MSE for XGB_2: 23.928301510025413
# RMSE for LSTM_1: 11.185637333950904
# RMSE for XGB_2: 4.891656315607773
# R2 for XGB_3: 0.7998569029226725
# EVS for XGB_3: 0.8000096541603353
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 17 - O3 with Weighted Predictions:
# MSE for LSTM_1: 984.2448716962201
# MSE for XGB_2: 20.46644851319969
# RMSE for LSTM_1: 31.37267715220077
# RMSE for XGB_2: 4.523985909924973
# R2 for XGB_3: 0.9793450895152507
# EVS for XGB_3: 0.9793629059016226
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 17 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 559.6512962863933
# MSE for XGB_2: 38.043349011633815
# RMSE for LSTM_1: 23.65695027442027
# RMSE for XGB_2: 6.167929069925644
# R2 for XGB_3: 0.9291748073862459
# EVS for XGB_3: 0.9291748073946645
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 17 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 1858.4337930634258
# MSE for XGB_2: 29.59906068867253
# RMSE for LSTM_1: 43.10955570477879
# RMSE for XGB_2: 5.4405018783814905
# R2 for XGB_3: 0.9834161143882361
# EVS for XGB_3: 0.9834161143921243
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 17 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 350.2338979372384
# MSE for XGB_2: 24.4654472618687
# RMSE for LSTM_1: 18.71453707515199
# RMSE for XGB_2: 4.946255883177567
# R2 for XGB_3: 0.9298014911409912
# EVS for XGB_3: 0.9298014911725311
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 17 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1125.954154553315
# MSE for XGB_2: 34.78115937875594
# RMSE for LSTM_1: 33.555240344144686
# RMSE for XGB_2: 5.8975553730979025
# R2 for XGB_3: 0.9678784142966476
# EVS for XGB_3: 0.9678819728926296
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 17 - AQI with Weighted Predictions:
# MSE for LSTM_1: 952.2374914230679
# MSE for XGB_2: 45.258111387771834
# RMSE for LSTM_1: 30.858345571709897
# RMSE for XGB_2: 6.727414911224952
# R2 for XGB_3: 0.9509187005114755
# EVS for XGB_3: 0.9509204284777797
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 17 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.85027332735596
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.809730492817847
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 17 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.766717091615746
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.983317055068869
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 16 - CO with Weighted Predictions:
# MSE for LSTM_1: 95.96724792502842
# MSE for XGB_2: 19.68169499707013
# RMSE for LSTM_1: 9.796287456226896
# RMSE for XGB_2: 4.436405639374079
# R2 for XGB_3: 0.7822307920078948
# EVS for XGB_3: 0.7824328536801537
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 16 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1003.2992166367842
# MSE for XGB_2: 20.501247856659276
# RMSE for LSTM_1: 31.674898841776656
# RMSE for XGB_2: 4.52783036968693
# R2 for XGB_3: 0.9793140999829311
# EVS for XGB_3: 0.9793319514973576
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 16 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 210.19301604792824
# MSE for XGB_2: 28.503944593107892
# RMSE for LSTM_1: 14.498034902976618
# RMSE for XGB_2: 5.338908558226849
# R2 for XGB_3: 0.8590880615701878
# EVS for XGB_3: 0.8590884078653099
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 16 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 174.83445457520688
# MSE for XGB_2: 16.358283045992113
# RMSE for LSTM_1: 13.222498045952092
# RMSE for XGB_2: 4.044537432883038
# R2 for XGB_3: 0.9024213637704525
# EVS for XGB_3: 0.9024213637966867
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 16 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 354.78173174456714
# MSE for XGB_2: 23.019204973504248
# RMSE for LSTM_1: 18.835650552730243
# RMSE for XGB_2: 4.79783336241519
# R2 for XGB_3: 0.9346005860895229
# EVS for XGB_3: 0.9346006605896834
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 16 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 858.8543758677755
# MSE for XGB_2: 25.243029316777804
# RMSE for LSTM_1: 29.306217358570443
# RMSE for XGB_2: 5.024244153778537
# R2 for XGB_3: 0.9694684313441511
# EVS for XGB_3: 0.9694736977084614
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 16 - AQI with Weighted Predictions:
# MSE for LSTM_1: 744.5928820772755
# MSE for XGB_2: 27.616132829293612
# RMSE for LSTM_1: 27.287229285460175
# RMSE for XGB_2: 5.255105406106867
# R2 for XGB_3: 0.9630500868966299
# EVS for XGB_3: 0.9630500868971976
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 16 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 117.98854143528597
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.862253055203878
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 16 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.165087694440885
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.940107181768945
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - CO with Weighted Predictions:
# MSE for LSTM_1: 244.96262073891185
# MSE for XGB_2: 23.455191227446853
# RMSE for LSTM_1: 15.65128176025567
# RMSE for XGB_2: 4.843055980209898
# R2 for XGB_3: 0.9026130762703906
# EVS for XGB_3: 0.9026889015634278
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - O3 with Weighted Predictions:
# MSE for LSTM_1: 2822.079137254084
# MSE for XGB_2: 22.42465722462679
# RMSE for LSTM_1: 53.12324479221957
# RMSE for XGB_2: 4.735468004815025
# R2 for XGB_3: 0.9920780299603946
# EVS for XGB_3: 0.9920843349683768
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 318.04652940545685
# MSE for XGB_2: 28.13995432682858
# RMSE for LSTM_1: 17.833859072154205
# RMSE for XGB_2: 5.3047105789881295
# R2 for XGB_3: 0.9072563443623303
# EVS for XGB_3: 0.9072563443823671
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 403.0998221581574
# MSE for XGB_2: 28.034725383384455
# RMSE for LSTM_1: 20.077345993884684
# RMSE for XGB_2: 5.294782845725068
# R2 for XGB_3: 0.9295495441790238
# EVS for XGB_3: 0.9295933738399434
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 374.0459907981129
# MSE for XGB_2: 26.81787144998831
# RMSE for LSTM_1: 19.340268633039017
# RMSE for XGB_2: 5.178597440426153
# R2 for XGB_3: 0.928721439322042
# EVS for XGB_3: 0.9287214393525774
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1067.5887524387492
# MSE for XGB_2: 31.026643416061628
# RMSE for LSTM_1: 32.6739766854105
# RMSE for XGB_2: 5.570156498345592
# R2 for XGB_3: 0.9696232550335298
# EVS for XGB_3: 0.9696305083413942
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1476.112028655111
# MSE for XGB_2: 35.31038100632599
# RMSE for LSTM_1: 38.42020339164163
# RMSE for XGB_2: 5.942253865859821
# R2 for XGB_3: 0.9760107202018911
# EVS for XGB_3: 0.9760230570808541
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.98212563086751
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.815827551827345
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 6 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.055440707359644
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.932203164027988
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 20 - CO with Weighted Predictions:
# MSE for LSTM_1: 307.58470035083263
# MSE for XGB_2: 33.4860959281936
# RMSE for LSTM_1: 17.538092836760576
# RMSE for XGB_2: 5.786717197875977
# R2 for XGB_3: 0.8890970565926816
# EVS for XGB_3: 0.8891575389909842
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 20 - O3 with Weighted Predictions:
# MSE for LSTM_1: 549.0015146303151
# MSE for XGB_2: 17.8186918555657
# RMSE for LSTM_1: 23.43078134912097
# RMSE for XGB_2: 4.221219238036055
# R2 for XGB_3: 0.9675720420365235
# EVS for XGB_3: 0.9676041368809676
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node District 20 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 333.43533444895303
# MSE for XGB_2: 41.89205821046922
# RMSE for LSTM_1: 18.260211785435377
# RMSE for XGB_2: 6.472407450900262
# R2 for XGB_3: 0.8676061253705767
# EVS for XGB_3: 0.867663738625568
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 20 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 511.5186038007585
# MSE for XGB_2: 25.5608996001158
# RMSE for LSTM_1: 22.616777042734416
# RMSE for XGB_2: 5.055778832199427
# R2 for XGB_3: 0.94848360553876
# EVS for XGB_3: 0.9484889609499033
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 20 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 453.45083223503144
# MSE for XGB_2: 26.568219371226405
# RMSE for LSTM_1: 21.294384993115706
# RMSE for XGB_2: 5.15443686266758
# R2 for XGB_3: 0.941085229855297
# EVS for XGB_3: 0.9411257280713734
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 20 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 933.3539381370448
# MSE for XGB_2: 30.288911331953443
# RMSE for LSTM_1: 30.55084185643736
# RMSE for XGB_2: 5.503536256985452
# R2 for XGB_3: 0.9668040941565242
# EVS for XGB_3: 0.9668057987587453
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 20 - AQI with Weighted Predictions:
# MSE for LSTM_1: 780.5122276740263
# MSE for XGB_2: 37.39670374468389
# RMSE for LSTM_1: 27.93764892889211
# RMSE for XGB_2: 6.1152844369402715
# R2 for XGB_3: 0.9509474142146733
# EVS for XGB_3: 0.9509713697764781
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 20 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.73013117169157
# MSE for XGB_2: 2.820346415806358
# RMSE for LSTM_1: 10.804171933641724
# RMSE for XGB_2: 1.6793887030126045
# R2 for XGB_3: 0.9763965384323334
# EVS for XGB_3: 0.9765489764667556
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node District 20 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.2026444765205
# MSE for XGB_2: 18.697867926936766
# RMSE for LSTM_1: 6.942812432762425
# RMSE for XGB_2: 4.324103135557333
# R2 for XGB_3: 0.6053075956459674
# EVS for XGB_3: 0.6053075958870838
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Global Model Results:
# Mean Squared Error (MSE) for Global Model: 7.0489082698894165
# Duration of the program execution: 227.20444989204407 seconds
