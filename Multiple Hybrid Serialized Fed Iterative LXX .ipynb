# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
# Import the time module
import time

# Record the start time
start_time = time.time()

# Read data from Excel file
file_path = ''
df = pd.read_excel(file_path)

# Convert 'iranidate' to datetime and drop rows with invalid dates
df['iranidate'] = pd.to_datetime(df['iranidate'], errors='coerce')
df = df.dropna(subset=['iranidate'])

# Function to convert date values to numeric representation
def convert_to_numeric_date(date):
    base_date = datetime(2000, 1, 1)
    return (date - base_date).days

df['iranidate'] = df['iranidate'].apply(convert_to_numeric_date)

# Encode 'node' column
label_encoder = LabelEncoder()
df['node_encoded'] = label_encoder.fit_transform(df['node'])

# Handling NaN values by finding the nearest non-empty cells in the same column 
for col in ['CO', 'O3', 'SO2', 'PM10', 'PM2.5', 'AQI']:
    for idx, value in df[col].items():
        if pd.isnull(value):
            upper_cell = df[col].iloc[:idx].last_valid_index()
            lower_cell = df[col].iloc[idx + 1:].first_valid_index()
            if upper_cell is not None and lower_cell is not None:
                avg = (df.at[upper_cell, col] + df.at[lower_cell, col]) / 2
                df.at[idx, col] = avg

# Check sample threshold
your_threshold_value = 100
if len(df) < your_threshold_value:
    print("Insufficient samples in the dataset.")
else:
    output_columns = ['CO', 'O3', 'NO2', 'SO2', 'PM10', 'PM2.5', 'AQI', 'Highest tempreture: 12pm', 'Wind:km/h']
    unique_nodes = df['node'].unique()  

    # Dictionary to store weighted predictions for each node and column
    weighted_predictions = {}

    for node_value in unique_nodes:
        node_df = df[df['node'] == node_value]  
        
        # Dictionary to store predictions and true values for each column
        columns_data = {}

        for output_column in output_columns:
            if node_df[output_column].isnull().any():
                print(f"NaN values found in {output_column} for Node {node_value}. Handle missing values before modeling.")
            else:
                # Modify X to include the 'node' column along with 'iranidate'
                X = node_df[['iranidate', 'node_encoded']]
                Y = node_df[[output_column]]  
                X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

                # Reshape the input data for LSTM
                X_train_lstm = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
                X_test_lstm = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))

                lstm_model = Sequential([
                  LSTM(50, activation='relu', input_shape=(2, 1)),
                  Dense(1)
                   ])
                lstm_model.compile(optimizer='adam', loss='mse')
                lstm_model.fit(X_train_lstm, Y_train, epochs=50, batch_size=32, verbose=0)

                Y1_pred_lstm = lstm_model.predict(X_test_lstm)

                # Flatten the LSTM predictions for input to XGBoost model
                Y1_pred_lstm_flat = Y1_pred_lstm.flatten()

                xgb_model_2 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.3, max_depth=10, alpha=10, n_estimators=200)
                xgb_model_2.fit(np.concatenate((X_test, Y1_pred_lstm_flat.reshape(-1, 1)), axis=1), Y_test)
                Y2_pred_xgb = xgb_model_2.predict(np.concatenate((X_test, Y1_pred_lstm_flat.reshape(-1, 1)), axis=1))

                xgb_model_3 = xgb.XGBRegressor(colsample_bytree=0.8, learning_rate=0.3, max_depth=10, alpha=10, n_estimators=200)
                xgb_model_3.fit(np.concatenate((X_test, Y2_pred_xgb.reshape(-1, 1)), axis=1), Y_test)
                Y3_pred_xgb = xgb_model_3.predict(np.concatenate((X_test, Y2_pred_xgb.reshape(-1, 1)), axis=1))

                # Calculate errors for the third XGBoost model
                mse_lstm_1 = mean_squared_error(Y_test, Y1_pred_lstm)
                mse_xgb_2 = mean_squared_error(Y_test, Y2_pred_xgb)
                mse_xgb_3 = mean_squared_error(Y_test, Y3_pred_xgb)
                rmse_xgb_3 = np.sqrt(mse_xgb_3)
                r2_xgb_3 = r2_score(Y_test, Y3_pred_xgb)
                evs_xgb_3 = explained_variance_score(Y_test, Y3_pred_xgb)

                # Store predictions and true values for each column in the dictionary
                columns_data[output_column] = (Y3_pred_xgb, Y_test)

                # Output results for the local model with weighted predictions
                print(f"Local Model Results for Node {node_value} - {output_column} with Weighted Predictions:")
                print(f"MSE for LSTM_1: {mse_lstm_1}")
                print(f"MSE for XGB_2: {mse_xgb_2}")
                print(f"MSE for XGB_3: {mse_xgb_3}")
                print(f"RMSE for XGB_3: {rmse_xgb_3}")
                print(f"R2 for XGB_3: {r2_xgb_3}")
                print(f"EVS for XGB_3: {evs_xgb_3}")
                    
                # Store predictions and true values for each column in the dictionary
                columns_data[output_column] = (Y3_pred_xgb, Y_test)

                
                # Store weighted predictions for each node and column
                if node_value not in weighted_predictions:
                    weighted_predictions[node_value] = {output_column: (Y3_pred_xgb, Y_test)}
                else:
                    weighted_predictions[node_value][output_column] = (Y3_pred_xgb, Y_test)

# Aggregate predictions for the global model using weighted average
global_X_test = []
global_Y_test = []

for node, columns in weighted_predictions.items():
    for column, (node_prediction, Y_test) in columns.items():
        global_X_test.extend(node_prediction * r2_xgb_3)  # Apply weights using the R2 score from the third XGBoost model
        global_Y_test.extend(Y_test.values)

# Create and train the global model (Random Forest)
global_model = RandomForestRegressor(random_state=42)
global_model.fit(np.array(global_X_test).reshape(-1, 1), global_Y_test)  # Reshape for RF

# Predict using the global model
global_Y_pred = global_model.predict(np.array(global_X_test).reshape(-1, 1))
global_mse = mean_squared_error(global_Y_test, global_Y_pred)

# Print results for the global model
print("Global Model Results:")
print(f"Mean Squared Error (MSE) for Global Model: {global_mse}")

# Record the end time
end_time = time.time()

# Calculate the duration of the program execution
duration_seconds = end_time - start_time

# Print the duration of the program execution
print(f"Duration of the program execution: {duration_seconds} seconds")
# Out:
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - CO with Weighted Predictions:
# MSE for LSTM_1: 97.72753484161258
# MSE for XGB_2: 26.858201952099517
# MSE for XGB_3: 12.290152910021364
# RMSE for XGB_3: 3.5057314372355113
# R2 for XGB_3: 0.8478461646114183
# EVS for XGB_3: 0.8478729982052665
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1425.6287942112624
# MSE for XGB_2: 24.043527428772617
# MSE for XGB_3: 11.485712948460998
# RMSE for XGB_3: 3.3890578260721664
# R2 for XGB_3: 0.990592398057822
# EVS for XGB_3: 0.9905924354038804
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اقدسیه.منطقه1 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 628.747931175808
# MSE for XGB_2: 32.68788225736516
# MSE for XGB_3: 10.232464376179001
# RMSE for XGB_3: 3.198822342078253
# R2 for XGB_3: 0.9831625999811554
# EVS for XGB_3: 0.9831626001505949
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 74.91560990339863
# MSE for XGB_2: 14.186099354504567
# MSE for XGB_3: 6.339556621812042
# RMSE for XGB_3: 2.5178476168767725
# R2 for XGB_3: 0.9142194551087158
# EVS for XGB_3: 0.9142196682773663
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 230.89927242656347
# MSE for XGB_2: 25.461299641718615
# MSE for XGB_3: 11.147613899025776
# RMSE for XGB_3: 3.338804261861689
# R2 for XGB_3: 0.9504893649700967
# EVS for XGB_3: 0.9504893848669163
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 842.3639142340411
# MSE for XGB_2: 30.315046560142473
# MSE for XGB_3: 12.182162298465743
# RMSE for XGB_3: 3.490295445727445
# R2 for XGB_3: 0.9850213932099037
# EVS for XGB_3: 0.9850214325434627
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اقدسیه.منطقه1 - AQI with Weighted Predictions:
# MSE for LSTM_1: 792.0123029633218
# MSE for XGB_2: 30.209083396049135
# MSE for XGB_3: 7.2576603350524245
# RMSE for XGB_3: 2.6940045165241324
# R2 for XGB_3: 0.9901553305029086
# EVS for XGB_3: 0.9901560947254067
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اقدسیه.منطقه1 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.64551867459542
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اقدسیه.منطقه1 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.62924634244042
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شریف.منطقه2 - CO with Weighted Predictions:
# MSE for LSTM_1: 167.86811683041972
# MSE for XGB_2: 25.95412771894022
# MSE for XGB_3: 9.174614871842955
# RMSE for XGB_3: 3.028962672573394
# R2 for XGB_3: 0.9450732379135213
# EVS for XGB_3: 0.9450734334721801
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شریف.منطقه2 - O3 with Weighted Predictions:
# MSE for LSTM_1: 692.7006903448237
# MSE for XGB_2: 19.554797548512518
# MSE for XGB_3: 7.51212223797975
# RMSE for XGB_3: 2.740825101676455
# R2 for XGB_3: 0.9857172601856381
# EVS for XGB_3: 0.9857173014566
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شریف.منطقه2 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 560.9643721748773
# MSE for XGB_2: 27.21007099009915
# MSE for XGB_3: 10.753338547698592
# RMSE for XGB_3: 3.2792283463794636
# R2 for XGB_3: 0.979506879131293
# EVS for XGB_3: 0.9795071504014967
# 3/3 [==============================] - 1s 2ms/step
# Local Model Results for Node شریف.منطقه2 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 200.38981601975456
# MSE for XGB_2: 18.506079503068676
# MSE for XGB_3: 6.160339382206985
# RMSE for XGB_3: 2.48200309875048
# R2 for XGB_3: 0.9682127892645285
# EVS for XGB_3: 0.9682127943341172
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شریف.منطقه2 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 603.1924914478786
# MSE for XGB_2: 29.10785039075307
# MSE for XGB_3: 12.147893959550169
# RMSE for XGB_3: 3.485382899991071
# R2 for XGB_3: 0.9800274997508021
# EVS for XGB_3: 0.9800275037757734
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شریف.منطقه2 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 802.4634011972411
# MSE for XGB_2: 27.820777848749923
# MSE for XGB_3: 10.839231682832768
# RMSE for XGB_3: 3.292298844703009
# R2 for XGB_3: 0.986076688772521
# EVS for XGB_3: 0.9860766901477722
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شریف.منطقه2 - AQI with Weighted Predictions:
# MSE for LSTM_1: 894.9944918411642
# MSE for XGB_2: 25.83938929205131
# MSE for XGB_3: 9.915007707331332
# RMSE for XGB_3: 3.1488105226150607
# R2 for XGB_3: 0.9887421784119068
# EVS for XGB_3: 0.9887421848270783
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شریف.منطقه2 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 118.53760709722397
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شریف.منطقه2 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.021059692426455
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - CO with Weighted Predictions:
# MSE for LSTM_1: 93.1953669282801
# MSE for XGB_2: 20.427369977884215
# MSE for XGB_3: 10.552378407069972
# RMSE for XGB_3: 3.2484424586361342
# R2 for XGB_3: 0.8823559389533648
# EVS for XGB_3: 0.8823565286045325
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پاسداران.منطقه3 - O3 with Weighted Predictions:
# MSE for LSTM_1: 984.1024890674167
# MSE for XGB_2: 22.938674467275128
# MSE for XGB_3: 8.241313546091668
# RMSE for XGB_3: 2.870768807495941
# R2 for XGB_3: 0.9917464391495942
# EVS for XGB_3: 0.9917468082212096
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پاسداران.منطقه3 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 200.8816730825715
# MSE for XGB_2: 28.52529206672413
# MSE for XGB_3: 9.9532367556646
# RMSE for XGB_3: 3.1548750776638683
# R2 for XGB_3: 0.9484671112068921
# EVS for XGB_3: 0.9484685595612427
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 169.60284815793204
# MSE for XGB_2: 15.328369134237523
# MSE for XGB_3: 6.824544969060848
# RMSE for XGB_3: 2.6123830058130544
# R2 for XGB_3: 0.9587411884505866
# EVS for XGB_3: 0.9587462646472074
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 235.92879864872776
# MSE for XGB_2: 25.461299641718615
# MSE for XGB_3: 11.147613899025776
# RMSE for XGB_3: 3.338804261861689
# R2 for XGB_3: 0.9504893649700967
# EVS for XGB_3: 0.9504893848669163
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پاسداران.منطقه3 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 829.3349960496507
# MSE for XGB_2: 25.85098412829632
# MSE for XGB_3: 6.415702631441097
# RMSE for XGB_3: 2.532923731864246
# R2 for XGB_3: 0.9919521867307121
# EVS for XGB_3: 0.9919521907688501
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - AQI with Weighted Predictions:
# MSE for LSTM_1: 708.7200084847541
# MSE for XGB_2: 25.92223392190864
# MSE for XGB_3: 9.740080150120699
# RMSE for XGB_3: 3.1209101477166397
# R2 for XGB_3: 0.9856524363689704
# EVS for XGB_3: 0.9856530471753385
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پاسداران.منطقه3 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 118.88283639650153
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پاسداران.منطقه3 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.13914570514728
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - CO with Weighted Predictions:
# MSE for LSTM_1: 179.54159431822234
# MSE for XGB_2: 26.195421835039713
# MSE for XGB_3: 11.818656903052203
# RMSE for XGB_3: 3.43782735212986
# R2 for XGB_3: 0.9214840667883675
# EVS for XGB_3: 0.9214844084702547
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - O3 with Weighted Predictions:
# MSE for LSTM_1: 538.2169134439155
# MSE for XGB_2: 27.673352218212806
# MSE for XGB_3: 8.64863062798036
# RMSE for XGB_3: 2.9408554245287815
# R2 for XGB_3: 0.9828418976884948
# EVS for XGB_3: 0.9828418993601281
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 662.6179295025797
# MSE for XGB_2: 31.705543843486204
# MSE for XGB_3: 8.793348999068632
# RMSE for XGB_3: 2.965358156963275
# R2 for XGB_3: 0.9866045756382735
# EVS for XGB_3: 0.9866056121268643
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 58.29569165789511
# MSE for XGB_2: 16.50130982159493
# MSE for XGB_3: 6.566513860086454
# RMSE for XGB_3: 2.5625209970040155
# R2 for XGB_3: 0.8851296540655926
# EVS for XGB_3: 0.8851297731495029
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 357.0810382380255
# MSE for XGB_2: 23.967004009382627
# MSE for XGB_3: 10.20355034740222
# RMSE for XGB_3: 3.1942996646216866
# R2 for XGB_3: 0.969994708146443
# EVS for XGB_3: 0.9699947338171139
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1537.8290863452107
# MSE for XGB_2: 36.083289374387135
# MSE for XGB_3: 10.076010927947433
# RMSE for XGB_3: 3.1742732913136877
# R2 for XGB_3: 0.9931616825801924
# EVS for XGB_3: 0.9931617221456261
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1551.7363858690653
# MSE for XGB_2: 36.09436824980042
# MSE for XGB_3: 11.311881586704779
# RMSE for XGB_3: 3.363314077915528
# R2 for XGB_3: 0.9921616922590745
# EVS for XGB_3: 0.992161805972198
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.10266050382901
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node دانشگاه.علم.وصنعت.منطقه4 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.22787005918006
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - CO with Weighted Predictions:
# MSE for LSTM_1: 133.58773196292557
# MSE for XGB_2: 18.976083450593674
# MSE for XGB_3: 10.692820169006076
# RMSE for XGB_3: 3.2699877934032227
# R2 for XGB_3: 0.9172514354886763
# EVS for XGB_3: 0.9172546370783816
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - O3 with Weighted Predictions:
# MSE for LSTM_1: 419.8419909878092
# MSE for XGB_2: 21.134038580412792
# MSE for XGB_3: 10.865150062413061
# RMSE for XGB_3: 3.296232707563752
# R2 for XGB_3: 0.9716632035614019
# EVS for XGB_3: 0.9716632875329929
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پونک - NO2 with Weighted Predictions:
# MSE for LSTM_1: 305.9737359252658
# MSE for XGB_2: 36.69136580102004
# MSE for XGB_3: 12.940708218553743
# RMSE for XGB_3: 3.5973195880479873
# R2 for XGB_3: 0.9569205041552529
# EVS for XGB_3: 0.95692085585921
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - SO2 with Weighted Predictions:
# MSE for LSTM_1: 306.2424065947015
# MSE for XGB_2: 19.038852847238765
# MSE for XGB_3: 6.483750828760029
# RMSE for XGB_3: 2.546321038039004
# R2 for XGB_3: 0.9776952666222423
# EVS for XGB_3: 0.9777053348758167
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - PM10 with Weighted Predictions:
# MSE for LSTM_1: 256.38448514902757
# MSE for XGB_2: 25.25348721002623
# MSE for XGB_3: 10.533711828150714
# RMSE for XGB_3: 3.245568028581548
# R2 for XGB_3: 0.958504649890923
# EVS for XGB_3: 0.9585056654753602
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 779.6356267880058
# MSE for XGB_2: 37.346205476369995
# MSE for XGB_3: 11.983080875837443
# RMSE for XGB_3: 3.461658688524541
# R2 for XGB_3: 0.9843976590820599
# EVS for XGB_3: 0.9843977098840342
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پونک - AQI with Weighted Predictions:
# MSE for LSTM_1: 477.7415536541712
# MSE for XGB_2: 34.58616095609227
# MSE for XGB_3: 13.312474946498119
# RMSE for XGB_3: 3.6486264465546645
# R2 for XGB_3: 0.9715694944028297
# EVS for XGB_3: 0.971569511499951
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پونک - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 109.70112340978449
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پونک - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.41863432366911
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - CO with Weighted Predictions:
# MSE for LSTM_1: 248.75945114054667
# MSE for XGB_2: 23.455191227446853
# MSE for XGB_3: 9.620361600258788
# RMSE for XGB_3: 3.1016707756076864
# R2 for XGB_3: 0.9600558608825442
# EVS for XGB_3: 0.9600558839706749
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - O3 with Weighted Predictions:
# MSE for LSTM_1: 2868.1298744203423
# MSE for XGB_2: 22.42465722462679
# MSE for XGB_3: 7.665577517274349
# RMSE for XGB_3: 2.7686779367189587
# R2 for XGB_3: 0.9972919775397311
# EVS for XGB_3: 0.9972919964928967
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 341.6026125676779
# MSE for XGB_2: 28.13995432682858
# MSE for XGB_3: 9.976479430792645
# RMSE for XGB_3: 3.158556542282035
# R2 for XGB_3: 0.9671195211598623
# EVS for XGB_3: 0.9671195448075466
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 402.77424269930555
# MSE for XGB_2: 28.034725383384455
# MSE for XGB_3: 9.452065197861737
# RMSE for XGB_3: 3.0744211158951105
# R2 for XGB_3: 0.976247232939417
# EVS for XGB_3: 0.9762479975127858
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 404.4267612506236
# MSE for XGB_2: 26.81787144998831
# MSE for XGB_3: 9.565207823954307
# RMSE for XGB_3: 3.092767017405984
# R2 for XGB_3: 0.9745768694749521
# EVS for XGB_3: 0.9745768747294218
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1053.0537009014608
# MSE for XGB_2: 31.026643416061628
# MSE for XGB_3: 8.347191475392538
# RMSE for XGB_3: 2.889150649480317
# R2 for XGB_3: 0.9918276526650307
# EVS for XGB_3: 0.9918276563306373
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1473.5157561333529
# MSE for XGB_2: 35.31038100632599
# MSE for XGB_3: 10.114649108916131
# RMSE for XGB_3: 3.1803536138165724
# R2 for XGB_3: 0.9931282772765887
# EVS for XGB_3: 0.9931282773205764
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.66042163289215
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node تربیت.مدرس.منطقه6 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 50.257126033570415
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node گلبرگ.منطقه8 - CO with Weighted Predictions:
# MSE for LSTM_1: 82.989968079059
# MSE for XGB_2: 20.019740481694893
# MSE for XGB_3: 8.898616372891533
# RMSE for XGB_3: 2.98305487259144
# R2 for XGB_3: 0.8827613511866497
# EVS for XGB_3: 0.882798227622664
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1908.6468076693716
# MSE for XGB_2: 22.87195656667228
# MSE for XGB_3: 9.10911725079333
# RMSE for XGB_3: 3.0181314170846387
# R2 for XGB_3: 0.9952770124013582
# EVS for XGB_3: 0.9952770124547253
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 266.68772144663683
# MSE for XGB_2: 36.34278609112086
# MSE for XGB_3: 12.6769315292802
# RMSE for XGB_3: 3.5604678806696457
# R2 for XGB_3: 0.9515075182023871
# EVS for XGB_3: 0.9515075235358441
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 236.6502809927451
# MSE for XGB_2: 14.053804699007422
# MSE for XGB_3: 5.963227960895179
# RMSE for XGB_3: 2.4419721458065773
# R2 for XGB_3: 0.9735919778524137
# EVS for XGB_3: 0.9735920331232043
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 291.96178648305795
# MSE for XGB_2: 28.23347674304631
# MSE for XGB_3: 13.602092893594198
# RMSE for XGB_3: 3.6881015297296518
# R2 for XGB_3: 0.9524042646237922
# EVS for XGB_3: 0.9524042839949521
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 830.0623624784466
# MSE for XGB_2: 27.194166761594442
# MSE for XGB_3: 11.392565580281163
# RMSE for XGB_3: 3.375287481131224
# R2 for XGB_3: 0.9857255048188975
# EVS for XGB_3: 0.9857255292267557
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node گلبرگ.منطقه8 - AQI with Weighted Predictions:
# MSE for LSTM_1: 925.8153820876091
# MSE for XGB_2: 35.94584051697025
# MSE for XGB_3: 11.835560548420913
# RMSE for XGB_3: 3.44028495163132
# R2 for XGB_3: 0.9871988040067856
# EVS for XGB_3: 0.9871988258707388
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node گلبرگ.منطقه8 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 117.32922435300713
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node گلبرگ.منطقه8 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 51.88052680573153
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - CO with Weighted Predictions:
# MSE for LSTM_1: 379.27625993341024
# MSE for XGB_2: 22.069914629058996
# MSE for XGB_3: 8.795939047201317
# RMSE for XGB_3: 2.965794842399136
# R2 for XGB_3: 0.9755940013672991
# EVS for XGB_3: 0.9755940347764531
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1206.0397885742968
# MSE for XGB_2: 19.938924799148555
# MSE for XGB_3: 6.442675008147421
# RMSE for XGB_3: 2.538242503809953
# R2 for XGB_3: 0.9943696356888367
# EVS for XGB_3: 0.9943698767561617
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 474.23016471998227
# MSE for XGB_2: 33.446616370873755
# MSE for XGB_3: 11.581794687419952
# RMSE for XGB_3: 3.4032035918263768
# R2 for XGB_3: 0.974442565908253
# EVS for XGB_3: 0.9744425989895146
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 323.57475138382387
# MSE for XGB_2: 24.08582366917911
# MSE for XGB_3: 11.179793376542374
# RMSE for XGB_3: 3.3436198014341247
# R2 for XGB_3: 0.9644855255218739
# EVS for XGB_3: 0.964486060635064
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 461.4126053391964
# MSE for XGB_2: 30.70816565464953
# MSE for XGB_3: 10.51317967324119
# RMSE for XGB_3: 3.2424033791681732
# R2 for XGB_3: 0.9769422707613438
# EVS for XGB_3: 0.9769422760359603
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 877.9624550565024
# MSE for XGB_2: 26.388368287200596
# MSE for XGB_3: 8.797644004650378
# RMSE for XGB_3: 2.9660822653207677
# R2 for XGB_3: 0.9895255655725228
# EVS for XGB_3: 0.9895268140932864
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - AQI with Weighted Predictions:
# MSE for LSTM_1: 566.954515894887
# MSE for XGB_2: 39.637849447119834
# MSE for XGB_3: 9.031669215074833
# RMSE for XGB_3: 3.0052735674269044
# R2 for XGB_3: 0.98407139162845
# EVS for XGB_3: 0.9840715143616329
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 126.6148525771805
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.فتح.منطقه9 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.90519399000176
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - CO with Weighted Predictions:
# MSE for LSTM_1: 98.20254599389685
# MSE for XGB_2: 19.722266255088737
# MSE for XGB_3: 9.661608635565273
# RMSE for XGB_3: 3.1083128278159635
# R2 for XGB_3: 0.8925536113895954
# EVS for XGB_3: 0.892558766446908
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1027.3448373828712
# MSE for XGB_2: 21.861544728312175
# MSE for XGB_3: 6.944170896406734
# RMSE for XGB_3: 2.635179480871604
# R2 for XGB_3: 0.9930252242656553
# EVS for XGB_3: 0.9930252449366246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 192.02880367639457
# MSE for XGB_2: 28.40627156619886
# MSE for XGB_3: 11.1899670595249
# RMSE for XGB_3: 3.345140813108605
# R2 for XGB_3: 0.9394832067318868
# EVS for XGB_3: 0.9394832456166486
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 228.9433604629753
# MSE for XGB_2: 21.60447748027459
# MSE for XGB_3: 9.048132408594302
# RMSE for XGB_3: 3.008011371087932
# R2 for XGB_3: 0.960045940449324
# EVS for XGB_3: 0.9600542975333147
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 341.4475958453401
# MSE for XGB_2: 22.907023559399466
# MSE for XGB_3: 9.522275406383601
# RMSE for XGB_3: 3.0858184338006023
# R2 for XGB_3: 0.971818270338745
# EVS for XGB_3: 0.9718182854094123
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1185.657563449541
# MSE for XGB_2: 28.302837659720648
# MSE for XGB_3: 8.901226996307797
# RMSE for XGB_3: 2.98349241599636
# R2 for XGB_3: 0.9922494365938198
# EVS for XGB_3: 0.9922496698705181
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه10 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1337.09391028978
# MSE for XGB_2: 31.298350726164465
# MSE for XGB_3: 8.362698546588478
# RMSE for XGB_3: 2.891833077234659
# R2 for XGB_3: 0.9935957179797498
# EVS for XGB_3: 0.9935963800507472
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 113.93691451986956
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه10 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.33822949223183
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه11 - CO with Weighted Predictions:
# MSE for LSTM_1: 385.66253195965965
# MSE for XGB_2: 21.63017067742032
# MSE for XGB_3: 9.973391268478707
# RMSE for XGB_3: 3.158067647862963
# R2 for XGB_3: 0.9723010785581845
# EVS for XGB_3: 0.9723011718317142
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1736.19785827731
# MSE for XGB_2: 23.55415993528669
# MSE for XGB_3: 9.38846283106837
# RMSE for XGB_3: 3.064059860882024
# R2 for XGB_3: 0.9946590420612618
# EVS for XGB_3: 0.994659049612367
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 430.2237692533328
# MSE for XGB_2: 36.55020021315106
# MSE for XGB_3: 11.714729512489026
# RMSE for XGB_3: 3.4226787042445315
# R2 for XGB_3: 0.9719512186246486
# EVS for XGB_3: 0.9719515043739384
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 30.69498470010065
# MSE for XGB_2: 8.063389793914885
# MSE for XGB_3: 5.568015980311668
# RMSE for XGB_3: 2.359664378743653
# R2 for XGB_3: 0.8125629946709839
# EVS for XGB_3: 0.8125772202460049
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 350.384842371852
# MSE for XGB_2: 22.856085413953604
# MSE for XGB_3: 9.909044269277166
# RMSE for XGB_3: 3.147863445144526
# R2 for XGB_3: 0.9707185070089479
# EVS for XGB_3: 0.9707186156278429
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1268.512954101049
# MSE for XGB_2: 30.403563565519256
# MSE for XGB_3: 10.519102571819365
# RMSE for XGB_3: 3.2433166006141563
# R2 for XGB_3: 0.9913541727100235
# EVS for XGB_3: 0.9913541743909984
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1312.5904878537062
# MSE for XGB_2: 33.879215100746414
# MSE for XGB_3: 9.42564134094255
# RMSE for XGB_3: 3.07012073719301
# R2 for XGB_3: 0.9920465701492756
# EVS for XGB_3: 0.9920465709790104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 118.54280625256315
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه11 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.71825672129548
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - CO with Weighted Predictions:
# MSE for LSTM_1: 95.40123382946089
# MSE for XGB_2: 23.497114456907944
# MSE for XGB_3: 10.184116338280786
# RMSE for XGB_3: 3.1912562320003053
# R2 for XGB_3: 0.8865868863218364
# EVS for XGB_3: 0.8865869179620841
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1028.3150959260474
# MSE for XGB_2: 25.808383928912416
# MSE for XGB_3: 8.542569919578256
# RMSE for XGB_3: 2.922767510353544
# R2 for XGB_3: 0.9917487787291465
# EVS for XGB_3: 0.9917488087796678
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 651.6753478708615
# MSE for XGB_2: 29.731593915457882
# MSE for XGB_3: 9.042499133100058
# RMSE for XGB_3: 3.0070748466075896
# R2 for XGB_3: 0.9857835581370885
# EVS for XGB_3: 0.9857846289995504
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 111.66457330724043
# MSE for XGB_2: 16.937227003249507
# MSE for XGB_3: 7.567134341738181
# RMSE for XGB_3: 2.750842478539653
# R2 for XGB_3: 0.931632905308053
# EVS for XGB_3: 0.9316329324590428
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 356.58256495489377
# MSE for XGB_2: 22.47060403484708
# MSE for XGB_3: 9.050900264215645
# RMSE for XGB_3: 3.0084714165528723
# R2 for XGB_3: 0.9745954883573091
# EVS for XGB_3: 0.9745956240026252
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1176.671826591463
# MSE for XGB_2: 26.09317516958427
# MSE for XGB_3: 10.299911189755138
# RMSE for XGB_3: 3.2093474710219736
# R2 for XGB_3: 0.990943861780766
# EVS for XGB_3: 0.9909439508809068
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1151.3555631163601
# MSE for XGB_2: 30.132404181780018
# MSE for XGB_3: 10.994447587580016
# RMSE for XGB_3: 3.315787627032228
# R2 for XGB_3: 0.9900968871580371
# EVS for XGB_3: 0.9900969468097086
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 118.72262633874561
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node میدان.امام.خمینی.منطقه12 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.27247570394753
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پیروزی.منطقه13 - CO with Weighted Predictions:
# MSE for LSTM_1: 97.80018825423112
# MSE for XGB_2: 23.542418828267387
# MSE for XGB_3: 9.854003311910976
# RMSE for XGB_3: 3.1391086811244646
# R2 for XGB_3: 0.8975277226358566
# EVS for XGB_3: 0.8975313471877265
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پیروزی.منطقه13 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1453.3707539993375
# MSE for XGB_2: 20.26943143831933
# MSE for XGB_3: 8.651973248304154
# RMSE for XGB_3: 2.9414236771169424
# R2 for XGB_3: 0.9941255776569605
# EVS for XGB_3: 0.9941255778979277
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پیروزی.منطقه13 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 236.35502456558706
# MSE for XGB_2: 31.917994410182953
# MSE for XGB_3: 9.954221910867023
# RMSE for XGB_3: 3.1550312060052628
# R2 for XGB_3: 0.9561697683512794
# EVS for XGB_3: 0.9561697883128369
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پیروزی.منطقه13 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 247.30425522338442
# MSE for XGB_2: 18.07048277397863
# MSE for XGB_3: 7.856483536594235
# RMSE for XGB_3: 2.8029419431365743
# R2 for XGB_3: 0.9307817138793879
# EVS for XGB_3: 0.9307820750878109
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 356.83429040893355
# MSE for XGB_2: 23.47445354169987
# MSE for XGB_3: 8.99923576415124
# RMSE for XGB_3: 2.9998726246544605
# R2 for XGB_3: 0.9747344635022324
# EVS for XGB_3: 0.9747345108217842
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 946.2026708356132
# MSE for XGB_2: 27.221549319846318
# MSE for XGB_3: 7.281888113650683
# RMSE for XGB_3: 2.6984973807010975
# R2 for XGB_3: 0.9920954202225352
# EVS for XGB_3: 0.9920954226452149
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1245.8293342345871
# MSE for XGB_2: 30.285820000380866
# MSE for XGB_3: 9.06640448227233
# RMSE for XGB_3: 3.011047074071133
# R2 for XGB_3: 0.9923126221679225
# EVS for XGB_3: 0.9923126745692439
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 178.852321344801
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پیروزی.منطقه13 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 48.7602642168181
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - CO with Weighted Predictions:
# MSE for LSTM_1: 81.64636895255575
# MSE for XGB_2: 25.057832064077417
# MSE for XGB_3: 12.52430074011756
# RMSE for XGB_3: 3.538968880919633
# R2 for XGB_3: 0.8434338779158668
# EVS for XGB_3: 0.8434338855036104
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - O3 with Weighted Predictions:
# MSE for LSTM_1: 828.8285665950195
# MSE for XGB_2: 19.55992357963245
# MSE for XGB_3: 8.273618015812657
# RMSE for XGB_3: 2.8763897538081755
# R2 for XGB_3: 0.9900119368964586
# EVS for XGB_3: 0.9900119407593375
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 482.2368725559956
# MSE for XGB_2: 23.35864351552321
# MSE for XGB_3: 10.92044613681637
# RMSE for XGB_3: 3.3046098312533614
# R2 for XGB_3: 0.9756408434541636
# EVS for XGB_3: 0.975640864955776
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 221.37645975421992
# MSE for XGB_2: 18.94445735952005
# MSE for XGB_3: 8.005223204602801
# RMSE for XGB_3: 2.8293503149314687
# R2 for XGB_3: 0.9634403753841969
# EVS for XGB_3: 0.9634405244068966
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 372.7801363907569
# MSE for XGB_2: 23.959481285930625
# MSE for XGB_3: 9.910705601834927
# RMSE for XGB_3: 3.148127316649523
# R2 for XGB_3: 0.9718424189575938
# EVS for XGB_3: 0.9718424194685402
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1513.3328628289921
# MSE for XGB_2: 31.150039116857204
# MSE for XGB_3: 10.402566623986559
# RMSE for XGB_3: 3.225301012926787
# R2 for XGB_3: 0.9929172381895256
# EVS for XGB_3: 0.9929172422329454
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - AQI with Weighted Predictions:
# MSE for LSTM_1: 581.329541774662
# MSE for XGB_2: 31.237117818133413
# MSE for XGB_3: 11.588218616554371
# RMSE for XGB_3: 3.404147267166092
# R2 for XGB_3: 0.9792910344791814
# EVS for XGB_3: 0.9792911232131989
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 115.33275564862295
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node اتوبان.محلاتی.منطقه14 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.320667916593045
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - CO with Weighted Predictions:
# MSE for LSTM_1: 54.97667424356563
# MSE for XGB_2: 15.944261195352198
# MSE for XGB_3: 8.954113497448402
# RMSE for XGB_3: 2.9923424766307085
# R2 for XGB_3: 0.8372311216885231
# EVS for XGB_3: 0.8372328625409868
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node مسعودیه.منطقه15 - O3 with Weighted Predictions:
# MSE for LSTM_1: 974.7830944180548
# MSE for XGB_2: 21.724928487884576
# MSE for XGB_3: 7.4679218414315125
# RMSE for XGB_3: 2.7327498680690687
# R2 for XGB_3: 0.9923869582540029
# EVS for XGB_3: 0.9923869604522477
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 298.873835607514
# MSE for XGB_2: 42.148850230364125
# MSE for XGB_3: 15.638806168978206
# RMSE for XGB_3: 3.9545930472019757
# R2 for XGB_3: 0.9482873777849206
# EVS for XGB_3: 0.9482892714473896
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 258.42749342888544
# MSE for XGB_2: 23.5501940708953
# MSE for XGB_3: 8.587460280210452
# RMSE for XGB_3: 2.93043687531577
# R2 for XGB_3: 0.966483469434924
# EVS for XGB_3: 0.9664834751251145
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 358.2161920545005
# MSE for XGB_2: 19.662628833263728
# MSE for XGB_3: 6.826233790423032
# RMSE for XGB_3: 2.6127062196931043
# R2 for XGB_3: 0.9813385994092524
# EVS for XGB_3: 0.9813391506023187
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 671.1607993023852
# MSE for XGB_2: 26.160394152905532
# MSE for XGB_3: 9.975024349089846
# RMSE for XGB_3: 3.1583261942189957
# R2 for XGB_3: 0.9847465998990592
# EVS for XGB_3: 0.9847484948319766
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node مسعودیه.منطقه15 - AQI with Weighted Predictions:
# MSE for LSTM_1: 599.1530724605128
# MSE for XGB_2: 30.816109339268074
# MSE for XGB_3: 9.509522515087943
# RMSE for XGB_3: 3.083751370504429
# R2 for XGB_3: 0.9835550206745531
# EVS for XGB_3: 0.9835556609519978
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node مسعودیه.منطقه15 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 115.35295312168957
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node مسعودیه.منطقه15 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 287.4555129537386
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - CO with Weighted Predictions:
# MSE for LSTM_1: 94.06709186872628
# MSE for XGB_2: 19.68169499707013
# MSE for XGB_3: 9.415525585020593
# RMSE for XGB_3: 3.068472842477279
# R2 for XGB_3: 0.8958213939508479
# EVS for XGB_3: 0.8958320343879735
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - O3 with Weighted Predictions:
# MSE for LSTM_1: 991.062352616721
# MSE for XGB_2: 20.501247856659276
# MSE for XGB_3: 7.02673244436887
# RMSE for XGB_3: 2.6507984541207334
# R2 for XGB_3: 0.9929099786604602
# EVS for XGB_3: 0.992910205543827
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 210.47932932250583
# MSE for XGB_2: 28.503944593107892
# MSE for XGB_3: 10.399408689374154
# RMSE for XGB_3: 3.224811419195571
# R2 for XGB_3: 0.9485895423295949
# EVS for XGB_3: 0.9485909595685762
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه16 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 176.58767954611153
# MSE for XGB_2: 16.358283045992113
# MSE for XGB_3: 7.459549033500994
# RMSE for XGB_3: 2.7312175002187202
# R2 for XGB_3: 0.9555031160953774
# EVS for XGB_3: 0.955503472620024
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه16 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 346.22459399889163
# MSE for XGB_2: 23.019204973504248
# MSE for XGB_3: 8.961603955676875
# RMSE for XGB_3: 2.993593819421211
# R2 for XGB_3: 0.9745393619339295
# EVS for XGB_3: 0.9745396367388753
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه16 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 860.1983102514383
# MSE for XGB_2: 25.243029316777804
# MSE for XGB_3: 8.316367664995303
# RMSE for XGB_3: 2.883811308840317
# R2 for XGB_3: 0.9899413122274384
# EVS for XGB_3: 0.9899416695219205
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه16 - AQI with Weighted Predictions:
# MSE for LSTM_1: 723.3596252795987
# MSE for XGB_2: 27.616132829293612
# MSE for XGB_3: 8.136984767359166
# RMSE for XGB_3: 2.8525400553470175
# R2 for XGB_3: 0.9891128536375504
# EVS for XGB_3: 0.9891128641153097
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه16 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 118.12349786413866
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه16 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.43903743295399
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - CO with Weighted Predictions:
# MSE for LSTM_1: 123.10080710067609
# MSE for XGB_2: 23.928301510025413
# MSE for XGB_3: 10.189457524107707
# RMSE for XGB_3: 3.1920929692143534
# R2 for XGB_3: 0.9147724887385612
# EVS for XGB_3: 0.914772976715463
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - O3 with Weighted Predictions:
# MSE for LSTM_1: 985.9210262862687
# MSE for XGB_2: 20.46644851319969
# MSE for XGB_3: 7.339052311466768
# RMSE for XGB_3: 2.709068532072743
# R2 for XGB_3: 0.9925933672156909
# EVS for XGB_3: 0.9925933688212893
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 555.5423881249867
# MSE for XGB_2: 38.043349011633815
# MSE for XGB_3: 8.435989750773258
# RMSE for XGB_3: 2.904477534905935
# R2 for XGB_3: 0.9842947423266164
# EVS for XGB_3: 0.9842947514940685
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 1827.9312123561685
# MSE for XGB_2: 29.59906068867253
# MSE for XGB_3: 8.243612682988184
# RMSE for XGB_3: 2.871169218800624
# R2 for XGB_3: 0.995381234181709
# EVS for XGB_3: 0.9953812345009444
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 349.44784090493795
# MSE for XGB_2: 24.4654472618687
# MSE for XGB_3: 10.441990045960669
# RMSE for XGB_3: 3.2314068214882306
# R2 for XGB_3: 0.9700388828824108
# EVS for XGB_3: 0.9700390125442303
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1131.5208755215679
# MSE for XGB_2: 34.78115937875594
# MSE for XGB_3: 10.561307821692726
# RMSE for XGB_3: 3.2498165827770533
# R2 for XGB_3: 0.990246272395934
# EVS for XGB_3: 0.9902463798144299
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - AQI with Weighted Predictions:
# MSE for LSTM_1: 955.7758779304789
# MSE for XGB_2: 45.258111387771834
# MSE for XGB_3: 9.88501136496831
# RMSE for XGB_3: 3.1440437918337447
# R2 for XGB_3: 0.9892799503033932
# EVS for XGB_3: 0.9892801354879559
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 115.55624597890956
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node پارک.سلامت.منطقه17 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 46.24310542402547
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - CO with Weighted Predictions:
# MSE for LSTM_1: 396.92386401502733
# MSE for XGB_2: 33.861238126792955
# MSE for XGB_3: 9.609680766426054
# RMSE for XGB_3: 3.0999485102862683
# R2 for XGB_3: 0.9745473915918171
# EVS for XGB_3: 0.974547402351755
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1820.762044439337
# MSE for XGB_2: 28.49802330254355
# MSE for XGB_3: 8.13296089768739
# RMSE for XGB_3: 2.8518346546893967
# R2 for XGB_3: 0.9955401962511555
# EVS for XGB_3: 0.9955402276450117
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 532.1116853719174
# MSE for XGB_2: 29.86152236989489
# MSE for XGB_3: 9.706778211119703
# RMSE for XGB_3: 3.115570286660165
# R2 for XGB_3: 0.9816260586873315
# EVS for XGB_3: 0.9816275942121464
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شادآباد.منطقه18 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 617.3435874600154
# MSE for XGB_2: 27.688178800664158
# MSE for XGB_3: 9.521960380904918
# RMSE for XGB_3: 3.0857673893060893
# R2 for XGB_3: 0.9835513406077995
# EVS for XGB_3: 0.9835518284199384
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 444.7299076820424
# MSE for XGB_2: 28.891031338360335
# MSE for XGB_3: 13.796657738766436
# RMSE for XGB_3: 3.714385243720209
# R2 for XGB_3: 0.9688480165009903
# EVS for XGB_3: 0.9688481993846486
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1088.6626537697975
# MSE for XGB_2: 40.61988299712143
# MSE for XGB_3: 10.56850699322707
# RMSE for XGB_3: 3.2509240214479127
# R2 for XGB_3: 0.9898264676534896
# EVS for XGB_3: 0.9898264692459642
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1110.9461157962107
# MSE for XGB_2: 42.292955943314055
# MSE for XGB_3: 9.823590668417452
# RMSE for XGB_3: 3.1342607850045683
# R2 for XGB_3: 0.990622809948565
# EVS for XGB_3: 0.9906234652072896
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شادآباد.منطقه18 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.42165857038934
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شادآباد.منطقه18 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 46.91047855098911
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - CO with Weighted Predictions:
# MSE for LSTM_1: 267.24459789939357
# MSE for XGB_2: 31.704891663599568
# MSE for XGB_3: 7.926464099276976
# RMSE for XGB_3: 2.8153976804844065
# R2 for XGB_3: 0.9676946991643405
# EVS for XGB_3: 0.9676947429506557
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه19 - O3 with Weighted Predictions:
# MSE for LSTM_1: 1098.797946233883
# MSE for XGB_2: 18.741009798795158
# MSE for XGB_3: 5.881247048767563
# RMSE for XGB_3: 2.425128254086279
# R2 for XGB_3: 0.9946942884601402
# EVS for XGB_3: 0.9946943139468417
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 300.22311928163805
# MSE for XGB_2: 22.656403919641807
# MSE for XGB_3: 9.434332741458103
# RMSE for XGB_3: 3.0715358929138534
# R2 for XGB_3: 0.9678201177267479
# EVS for XGB_3: 0.9678214581307744
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه19 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 160.79774000551555
# MSE for XGB_2: 24.46372762477046
# MSE for XGB_3: 8.134933641272724
# RMSE for XGB_3: 2.852180506432355
# R2 for XGB_3: 0.9469684763056996
# EVS for XGB_3: 0.9469689784455078
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه19 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 1026.4483577203496
# MSE for XGB_2: 31.172252358038122
# MSE for XGB_3: 11.078229989973847
# RMSE for XGB_3: 3.3283975108111483
# R2 for XGB_3: 0.9890757408443688
# EVS for XGB_3: 0.9890757708213109
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه19 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1496.2792833704377
# MSE for XGB_2: 38.78219164546814
# MSE for XGB_3: 9.868155851901331
# RMSE for XGB_3: 3.141362101366433
# R2 for XGB_3: 0.9926764721083183
# EVS for XGB_3: 0.9926764742830196
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه19 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1412.2669423635457
# MSE for XGB_2: 39.64890723542332
# MSE for XGB_3: 11.02870322155681
# RMSE for XGB_3: 3.320949144680901
# R2 for XGB_3: 0.9919164262087784
# EVS for XGB_3: 0.9919164305427466
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه19 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.92864516746172
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه19 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 49.08381134699684
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - CO with Weighted Predictions:
# MSE for LSTM_1: 310.90791358161914
# MSE for XGB_2: 33.4860959281936
# MSE for XGB_3: 12.783571017467695
# RMSE for XGB_3: 3.5754120066738735
# R2 for XGB_3: 0.9576619604705846
# EVS for XGB_3: 0.9576620107258309
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - O3 with Weighted Predictions:
# MSE for LSTM_1: 545.565146087802
# MSE for XGB_2: 17.8186918555657
# MSE for XGB_3: 7.898091275637413
# RMSE for XGB_3: 2.8103542971727626
# R2 for XGB_3: 0.9856263875062147
# EVS for XGB_3: 0.985626836596767
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 333.7111932406791
# MSE for XGB_2: 41.89205821046922
# MSE for XGB_3: 13.932539861793359
# RMSE for XGB_3: 3.7326317608080974
# R2 for XGB_3: 0.9559681950582525
# EVS for XGB_3: 0.9559685913717518
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 505.9997832997212
# MSE for XGB_2: 25.5608996001158
# MSE for XGB_3: 9.190004085862231
# RMSE for XGB_3: 3.031501952145542
# R2 for XGB_3: 0.9814781215452393
# EVS for XGB_3: 0.981478487175837
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 452.67517524862694
# MSE for XGB_2: 26.568219371226405
# MSE for XGB_3: 9.519811661506987
# RMSE for XGB_3: 3.0854192035292365
# R2 for XGB_3: 0.9788899094808755
# EVS for XGB_3: 0.9788900660752121
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 935.3151789639793
# MSE for XGB_2: 30.288911331953443
# MSE for XGB_3: 8.214506754944495
# RMSE for XGB_3: 2.8660960826435136
# R2 for XGB_3: 0.9909971015531331
# EVS for XGB_3: 0.9909971224672656
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - AQI with Weighted Predictions:
# MSE for LSTM_1: 779.572183163777
# MSE for XGB_2: 37.39670374468389
# MSE for XGB_3: 12.566076642770872
# RMSE for XGB_3: 3.544866237641538
# R2 for XGB_3: 0.983517302575307
# EVS for XGB_3: 0.9835173092778001
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 116.62173545904119
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهر.ری.منطقه20 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 46.83565950876201
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - CO with Weighted Predictions:
# MSE for LSTM_1: 213.81499479916124
# MSE for XGB_2: 26.62868519772501
# MSE for XGB_3: 9.547213006810415
# RMSE for XGB_3: 3.089856470260458
# R2 for XGB_3: 0.9533632676448307
# EVS for XGB_3: 0.9533673726230814
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه21 - O3 with Weighted Predictions:
# MSE for LSTM_1: 884.9435399854974
# MSE for XGB_2: 27.808500858703393
# MSE for XGB_3: 8.559011105608027
# RMSE for XGB_3: 2.925578764211968
# R2 for XGB_3: 0.9903967670040063
# EVS for XGB_3: 0.9903967700421108
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 323.9353578892727
# MSE for XGB_2: 34.533236778786524
# MSE for XGB_3: 11.275167185030774
# RMSE for XGB_3: 3.3578515728112186
# R2 for XGB_3: 0.9613036617572518
# EVS for XGB_3: 0.9613040743585414
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه21 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 516.5286915250744
# MSE for XGB_2: 25.5491805321137
# MSE for XGB_3: 10.36666324343098
# RMSE for XGB_3: 3.219730306008716
# R2 for XGB_3: 0.979687331720784
# EVS for XGB_3: 0.979687472074421
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه21 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 753.3684299557767
# MSE for XGB_2: 29.316465390147833
# MSE for XGB_3: 10.548947542491069
# RMSE for XGB_3: 3.2479143373080315
# R2 for XGB_3: 0.9860341453631363
# EVS for XGB_3: 0.9860341457755787
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه21 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 1063.4135486701755
# MSE for XGB_2: 27.186489199840242
# MSE for XGB_3: 10.158048533188845
# RMSE for XGB_3: 3.1871693606064997
# R2 for XGB_3: 0.9897990305129327
# EVS for XGB_3: 0.9897990503489907
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه21 - AQI with Weighted Predictions:
# MSE for LSTM_1: 1276.8206457392969
# MSE for XGB_2: 35.9875422331454
# MSE for XGB_3: 12.236652081363678
# RMSE for XGB_3: 3.498092634760217
# R2 for XGB_3: 0.9898779246385447
# EVS for XGB_3: 0.9898779814400265
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه21 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 119.12730159726709
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه21 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 50.75689993539197
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - CO with Weighted Predictions:
# MSE for LSTM_1: 149.4838691772173
# MSE for XGB_2: 20.057936980346494
# MSE for XGB_3: 8.954623934813837
# RMSE for XGB_3: 2.992427766014384
# R2 for XGB_3: 0.9378596610961745
# EVS for XGB_3: 0.9378599135479956
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه22 - O3 with Weighted Predictions:
# MSE for LSTM_1: 997.9836139910864
# MSE for XGB_2: 20.501247856659276
# MSE for XGB_3: 7.02673244436887
# RMSE for XGB_3: 2.6507984541207334
# R2 for XGB_3: 0.9929099786604602
# EVS for XGB_3: 0.992910205543827
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - NO2 with Weighted Predictions:
# MSE for LSTM_1: 330.94884240396505
# MSE for XGB_2: 33.25966731123422
# MSE for XGB_3: 11.500342480795627
# RMSE for XGB_3: 3.3912154872251374
# R2 for XGB_3: 0.9633621126023639
# EVS for XGB_3: 0.9633623632720559
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه22 - SO2 with Weighted Predictions:
# MSE for LSTM_1: 287.30481304073635
# MSE for XGB_2: 19.279509267701936
# MSE for XGB_3: 9.135663334451717
# RMSE for XGB_3: 3.0225259857363866
# R2 for XGB_3: 0.9674977829684706
# EVS for XGB_3: 0.9674990792452747
# 3/3 [==============================] - 0s 3ms/step
# Local Model Results for Node شهرداری.منطقه22 - PM10 with Weighted Predictions:
# MSE for LSTM_1: 315.14408989767816
# MSE for XGB_2: 26.418912664260052
# MSE for XGB_3: 9.838834044747319
# RMSE for XGB_3: 3.1366915762866006
# R2 for XGB_3: 0.9683758619596197
# EVS for XGB_3: 0.9683759569158866
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - PM2.5 with Weighted Predictions:
# MSE for LSTM_1: 898.7760359242659
# MSE for XGB_2: 31.982813319468455
# MSE for XGB_3: 9.904618758080582
# RMSE for XGB_3: 3.1471604277635072
# R2 for XGB_3: 0.9885595530643804
# EVS for XGB_3: 0.9885595614852021
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - AQI with Weighted Predictions:
# MSE for LSTM_1: 727.5132211398969
# MSE for XGB_2: 25.260538986448484
# MSE for XGB_3: 10.407579363340659
# RMSE for XGB_3: 3.226078015693461
# R2 for XGB_3: 0.9850135397988706
# EVS for XGB_3: 0.9850135562287118
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - Highest tempreture: 12pm with Weighted Predictions:
# MSE for LSTM_1: 124.07245694437104
# MSE for XGB_2: 2.820346415806358
# MSE for XGB_3: 2.3145870837076283
# RMSE for XGB_3: 1.521376706706011
# R2 for XGB_3: 0.9806292351290149
# EVS for XGB_3: 0.980629426003104
# 3/3 [==============================] - 0s 2ms/step
# Local Model Results for Node شهرداری.منطقه22 - Wind:km/h with Weighted Predictions:
# MSE for LSTM_1: 47.54293593701624
# MSE for XGB_2: 18.697867926936766
# MSE for XGB_3: 10.591444469833068
# RMSE for XGB_3: 3.254449948890452
# R2 for XGB_3: 0.7764257026675074
# EVS for XGB_3: 0.7764265710843246
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Global Model Results:
# Mean Squared Error (MSE) for Global Model: 2.921247092446546
# Duration of the program execution: 484.122700214386 seconds
